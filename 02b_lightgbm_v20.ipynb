# %% [markdown]
# # Changelog
#
# ## Version 20
#
# * Tuning LightGBM parameter from version 18 result
# * Stop using validation data
#
# ## Version 18
#
# * Tuning LightGBM parameter from version 16 result
#     * num_leaves : 63
#     * min_data_in_leaf : 20, 50
#     * bagging_fraction : **no diff**
#     * feature_fraction : 0.9, 1.0
#     * max_bin : 16, 102, 255
#     * min_data_per_group : 1
# * Use validation data to reduce overfit
#
# ## Version 16
#
# * Tuning LightGBM parameter from version 15 result
#     * boosting_type : gbdt
#     * n_estimators : 100
#     * LR : 0.01
#     * num_leaves : 31, 63
#     * min_data_in_leaf : 20, 50
#
# ## Version 15
#
# * Make submission for all mode
# * Fix dump `df_model`
# * Remove `age` from category feature
#
# ## Version 13
#
# * Tuning LightGBM parameter
# * Add additional preprocessing
# * Add EDA
#
# ## Version 10
#
# * Add additional preprocessing
#
# ## Version 9
#
# * Use StratifiedKFold 3, 5, 10
# * Combine parameter from verison 4 & 5
# * Use mean and mode to predict data
#
# ## Version 5
#
# * Use MCC score
# * Visualize LightGBM tree
# * Use different processed dataset
# * Specify categorical feature
# * Tweak parameter
#
# ## Version 4
#
# * Attempt fix overfit
# * Tweak class weight
#
# ## Version 2
#
# * Fix wrong row
# * Lower `max_bin` 255 -> 64
# * Increase `num_iterations` 5000 -> 10000
#
# ## Version 1
#
# * Initial Code

# %% [markdown]
# # Library

# %%
import os
import random
import platform
import itertools

import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import lightgbm as lgbm
import scipy

# %%
# !pip freeze > requirements.txt

# %%
print('Python version:', platform.python_version())
print('Numpy version:', np.__version__)
print('Pandas version:', pd.__version__)
print('Matplotlib version:', matplotlib.__version__)
print('Seaborn version:', sns.__version__)
print('Scikit-Learn version:', sklearn.__version__)
print('LightGBM version:', lgbm.__version__)
print('Scipy version:', scipy.__version__)
# Out:
# Python version: 3.7.6
# Numpy version: 1.18.5
# Pandas version: 1.0.3
# Matplotlib version: 3.2.1
# Seaborn version: 0.10.0
# Scikit-Learn version: 0.23.1
# LightGBM version: 2.3.1
# Scipy version: 1.4.1

# %%
SEED = 42

os.environ['PYTHONHASHSEED']=str(SEED)
random.seed(SEED)
np.random.seed(SEED)

# %%
pd.set_option('display.width', None)
pd.set_option('display.max_column', None)

# %% [markdown]
# # Processed Dataset

# %%
df_train = pd.read_parquet('/kaggle/input/shopee-marketing-data/train_processed.parquet')
df_train
# Out:
#        country_code                 grass_date  subject_line_length  \
# 0                 4  2019-07-16 00:00:00+08:00                   44
# 1                 4  2019-07-16 00:00:00+08:00                   44
# 2                 6  2019-07-16 00:00:00+08:00                   49
# 3                 1  2019-07-16 00:00:00+08:00                   49
# 4                 6  2019-07-16 00:00:00+08:00                   49
# ...             ...                        ...                  ...
# 73534             6  2019-09-02 00:00:00+08:00                   39
# 73535             2  2019-09-02 00:00:00+08:00                   38
# 73536             2  2019-09-02 00:00:00+08:00                   32
# 73537             2  2019-09-02 00:00:00+08:00                   38
# 73538             6  2019-09-02 00:00:00+08:00                   39
#
#        last_open_day  last_login_day  last_checkout_day  \
# 0               19.0             6.0               18.0
# 1                9.0             4.0                8.0
# 2               14.0             5.0                5.0
# 3               49.0             9.0               53.0
# 4              227.0             6.0              221.0
# ...              ...             ...                ...
# 73534           24.0            36.0              279.0
# 73535           46.0            10.0               51.0
# 73536            NaN             NaN                NaN
# 73537            5.0            34.0                NaN
# 73538            1.0             3.0                NaN
#
#        open_count_last_10_days  open_count_last_30_days  \
# 0                            0                        2
# 1                            2                        9
# 2                            0                        4
# 3                            0                        0
# 4                            0                        0
# ...                        ...                      ...
# 73534                        0                        1
# 73535                        0                        0
# 73536                        0                        0
# 73537                        2                        4
# 73538                        2                        2
#
#        open_count_last_60_days  login_count_last_10_days  \
# 0                            4                        12
# 1                           17                        18
# 2                           12                        24
# 3                            1                         9
# 4                            0                         2
# ...                        ...                       ...
# 73534                        1                         0
# 73535                        1                         0
# 73536                        0                         0
# 73537                        4                         0
# 73538                        3                         0
#
#        login_count_last_30_days  login_count_last_60_days  \
# 0                            43                        99
# 1                            48                        90
# 2                            69                       119
# 3                            23                        69
# 4                             5                         5
# ...                         ...                       ...
# 73534                         0                         0
# 73535                         0                         0
# 73536                         0                         0
# 73537                         0                         0
# 73538                         0                         0
#
#        checkout_count_last_10_days  checkout_count_last_30_days  \
# 0                                0                            5
# 1                                1                            1
# 2                                5                           19
# 3                                1                            3
# 4                                0                            0
# ...                            ...                          ...
# 73534                            0                            0
# 73535                            0                            0
# 73536                            0                            0
# 73537                            0                            0
# 73538                            0                            0
#
#        checkout_count_last_60_days  open_flag  attr_1  attr_2  attr_3   age  \
# 0                               10          0     1.0     1.0     2.0  47.0
# 1                                4          1     1.0     1.0     2.0  25.0
# 2                               27          0     NaN     1.0     0.0   NaN
# 3                                6          0     1.0     1.0     2.0  24.0
# 4                                0          0     NaN     1.0     0.0   NaN
# ...                            ...        ...     ...     ...     ...   ...
# 73534                            0          0     1.0     1.0     1.0  37.0
# 73535                            0          0     NaN     1.0     0.0   NaN
# 73536                            0          0     NaN     1.0     0.0   NaN
# 73537                            0          1     NaN     1.0     0.0   NaN
# 73538                            0          0     NaN     1.0     0.0   NaN
#
#        domain
# 0         0.0
# 1         3.0
# 2         2.0
# 3         2.0
# 4         3.0
# ...       ...
# 73534     0.0
# 73535     0.0
# 73536     9.0
# 73537     0.0
# 73538     0.0
#
# [73539 rows x 21 columns]

# %%
df_test = pd.read_parquet('/kaggle/input/shopee-marketing-data/test_processed.parquet')
df_test
# Out:
#        country_code                 grass_date  subject_line_length  \
# 0                 6  2019-09-03 00:00:00+08:00                   35
# 1                 6  2019-09-03 00:00:00+08:00                   35
# 2                 5  2019-09-03 00:00:00+08:00                   25
# 3                 1  2019-09-03 00:00:00+08:00                   36
# 4                 5  2019-09-03 00:00:00+08:00                   23
# ...             ...                        ...                  ...
# 55965             6  2019-09-29 00:00:00+08:00                   53
# 55966             6  2019-09-29 00:00:00+08:00                   53
# 55967             6  2019-09-29 00:00:00+08:00                   43
# 55968             6  2019-09-29 00:00:00+08:00                   43
# 55969             6  2019-09-29 00:00:00+08:00                   53
#
#        last_open_day  last_login_day  last_checkout_day  \
# 0               27.0             2.0               13.0
# 1                7.0             5.0              383.0
# 2               34.0             1.0                3.0
# 3               63.0             5.0                5.0
# 4                6.0             5.0               54.0
# ...              ...             ...                ...
# 55965            NaN             4.0                8.0
# 55966           59.0           802.0             1207.0
# 55967            NaN             7.0                NaN
# 55968            5.0             5.0                6.0
# 55969            5.0             3.0               20.0
#
#        open_count_last_10_days  open_count_last_30_days  \
# 0                            2                        3
# 1                            1                        1
# 2                            0                        0
# 3                            0                        0
# 4                            0                        0
# ...                        ...                      ...
# 55965                        0                        0
# 55966                        0                        0
# 55967                        0                        0
# 55968                        2                        5
# 55969                        2                       14
#
#        open_count_last_60_days  login_count_last_10_days  \
# 0                            4                        10
# 1                            1                         5
# 2                            0                        13
# 3                            0                        43
# 4                            0                         4
# ...                        ...                       ...
# 55965                        0                         0
# 55966                        1                         0
# 55967                        0                         0
# 55968                       14                         0
# 55969                       27                         0
#
#        login_count_last_30_days  login_count_last_60_days  \
# 0                            34                       134
# 1                             5                         5
# 2                            19                        38
# 3                           110                       173
# 4                            12                        39
# ...                         ...                       ...
# 55965                         0                         0
# 55966                         0                         0
# 55967                         0                         0
# 55968                         0                         0
# 55969                         0                         0
#
#        checkout_count_last_10_days  checkout_count_last_30_days  \
# 0                                0                            6
# 1                                0                            0
# 2                                2                            2
# 3                                2                            5
# 4                                0                            0
# ...                            ...                          ...
# 55965                            0                            0
# 55966                            0                            0
# 55967                            0                            0
# 55968                            0                            0
# 55969                            0                            0
#
#        checkout_count_last_60_days  attr_1  attr_2  attr_3   age  domain
# 0                               18     NaN     1.0     0.0   NaN     0.0
# 1                                0     NaN     1.0     0.0   NaN     0.0
# 2                                2     1.0     1.0     2.0  33.0     0.0
# 3                                5     1.0     1.0     2.0  22.0     2.0
# 4                                2     NaN     1.0     0.0   NaN     0.0
# ...                            ...     ...     ...     ...   ...     ...
# 55965                            0     NaN     1.0     0.0   NaN     3.0
# 55966                            0     NaN     1.0     0.0   NaN     0.0
# 55967                            0     NaN     1.0     0.0   NaN     0.0
# 55968                            0     NaN     NaN     NaN   NaN     NaN
# 55969                            0     NaN     NaN     NaN   NaN     NaN
#
# [55970 rows x 20 columns]

# %% [markdown]
# # EDA

# %%
df_train.describe()
# Out:
#        country_code  subject_line_length  last_open_day  last_login_day  \
# count  73539.000000         73539.000000    66021.00000    73260.000000
# mean       2.533159            43.656373       32.75323       53.335695
# std        1.675251            11.219323       55.16675      345.223999
# min        1.000000            10.000000        1.00000        0.000000
# 25%        1.000000            34.000000        5.00000        3.000000
# 50%        2.000000            43.000000       14.00000        8.000000
# 75%        3.000000            52.000000       38.00000       26.000000
# max        7.000000            75.000000      808.00000    18141.000000
#
#        last_checkout_day  open_count_last_10_days  open_count_last_30_days  \
# count       56634.000000             73539.000000             73539.000000
# mean           73.645725                 0.911829                 2.780457
# std           129.415239                 1.754052                 4.570239
# min             1.000000                 0.000000                 0.000000
# 25%             7.000000                 0.000000                 0.000000
# 50%            22.000000                 0.000000                 1.000000
# 75%            77.000000                 1.000000                 3.000000
# max          1445.000000                31.000000                92.000000
#
#        open_count_last_60_days  login_count_last_10_days  \
# count             73539.000000              73539.000000
# mean                  5.019364                  8.382287
# std                   7.902313                 13.424436
# min                   0.000000                  0.000000
# 25%                   0.000000                  0.000000
# 50%                   2.000000                  3.000000
# 75%                   6.000000                 12.000000
# max                 135.000000                254.000000
#
#        login_count_last_30_days  login_count_last_60_days  \
# count              73539.000000              73539.000000
# mean                  25.284053                 49.010430
# std                   37.853189                 71.819327
# min                    0.000000                  0.000000
# 25%                    1.000000                  3.000000
# 50%                   11.000000                 22.000000
# 75%                   35.000000                 69.000000
# max                  735.000000               1260.000000
#
#        checkout_count_last_10_days  checkout_count_last_30_days  \
# count                 73539.000000                 73539.000000
# mean                      0.909898                     2.796040
# std                       2.887416                     7.686064
# min                       0.000000                     0.000000
# 25%                       0.000000                     0.000000
# 50%                       0.000000                     0.000000
# 75%                       1.000000                     3.000000
# max                     157.000000                   531.000000
#
#        checkout_count_last_60_days     open_flag        attr_1        attr_2  \
# count                 73539.000000  73539.000000  45758.000000  73287.000000
# mean                      5.420960      0.155781      0.999847      0.997912
# std                      13.980182      0.362650      0.012368      0.045644
# min                       0.000000      0.000000      0.000000      0.000000
# 25%                       0.000000      0.000000      1.000000      1.000000
# 50%                       1.000000      0.000000      1.000000      1.000000
# 75%                       6.000000      0.000000      1.000000      1.000000
# max                     783.000000      1.000000      1.000000      1.000000
#
#              attr_3           age        domain
# count  73518.000000  45758.000000  73518.000000
# mean       1.087230     31.348464      0.434166
# std        1.033832     11.584066      1.259629
# min        0.000000    -16.000000      0.000000
# 25%        0.000000     24.000000      0.000000
# 50%        1.000000     29.000000      0.000000
# 75%        2.000000     36.000000      0.000000
# max        4.000000    118.000000     10.000000

# %%
df_test.describe()
# Out:
#        country_code  subject_line_length  last_open_day  last_login_day  \
# count  55970.000000         55970.000000   48381.000000    55801.000000
# mean       2.835215            42.212703      32.641078       47.723607
# std        1.728489            12.276136      52.263247      276.075845
# min        1.000000            11.000000       1.000000        0.000000
# 25%        1.000000            35.000000       6.000000        2.000000
# 50%        3.000000            41.000000      18.000000        8.000000
# 75%        4.000000            48.000000      40.000000       23.000000
# max        7.000000            79.000000     812.000000    18165.000000
#
#        last_checkout_day  open_count_last_10_days  open_count_last_30_days  \
# count       44567.000000             55970.000000             55970.000000
# mean           69.409743                 0.774272                 2.441880
# std           126.579497                 1.752984                 4.786883
# min             1.000000                 0.000000                 0.000000
# 25%             6.000000                 0.000000                 0.000000
# 50%            19.000000                 0.000000                 0.000000
# 75%            69.000000                 1.000000                 3.000000
# max          1462.000000                30.000000                79.000000
#
#        open_count_last_60_days  login_count_last_10_days  \
# count             55970.000000              55970.000000
# mean                  5.323530                  8.978899
# std                   9.053473                 13.975840
# min                   0.000000                  0.000000
# 25%                   0.000000                  0.000000
# 50%                   2.000000                  4.000000
# 75%                   6.000000                 13.000000
# max                 120.000000                329.000000
#
#        login_count_last_30_days  login_count_last_60_days  \
# count              55970.000000              55970.000000
# mean                  26.289459                 50.713882
# std                   38.572656                 73.289199
# min                    0.000000                  0.000000
# 25%                    2.000000                  4.000000
# 50%                   13.000000                 25.000000
# 75%                   36.000000                 70.000000
# max                  746.000000               1300.000000
#
#        checkout_count_last_10_days  checkout_count_last_30_days  \
# count                 55970.000000                 55970.000000
# mean                      1.124674                     3.219385
# std                       3.500704                     8.197445
# min                       0.000000                     0.000000
# 25%                       0.000000                     0.000000
# 50%                       0.000000                     1.000000
# 75%                       1.000000                     3.000000
# max                     252.000000                   404.000000
#
#        checkout_count_last_60_days        attr_1        attr_2        attr_3  \
# count                 55970.000000  34254.000000  55731.000000  55951.000000
# mean                      5.933893      0.999796      0.998152      1.070347
# std                      14.233715      0.014294      0.042951      1.036071
# min                       0.000000      0.000000      0.000000      0.000000
# 25%                       0.000000      1.000000      1.000000      0.000000
# 50%                       2.000000      1.000000      1.000000      1.000000
# 75%                       7.000000      1.000000      1.000000      2.000000
# max                     609.000000      1.000000      1.000000      4.000000
#
#                 age        domain
# count  34254.000000  55951.000000
# mean      31.404099      0.444407
# std       11.609694      1.298730
# min      -17.000000      0.000000
# 25%       24.000000      0.000000
# 50%       29.000000      0.000000
# 75%       36.000000      0.000000
# max      118.000000     10.000000

# %%
df_train.isnull().sum()
# Out:
# country_code                       0
# grass_date                         0
# subject_line_length                0
# last_open_day                   7518
# last_login_day                   279
# last_checkout_day              16905
# open_count_last_10_days            0
# open_count_last_30_days            0
# open_count_last_60_days            0
# login_count_last_10_days           0
# login_count_last_30_days           0
# login_count_last_60_days           0
# checkout_count_last_10_days        0
# checkout_count_last_30_days        0
# checkout_count_last_60_days        0
# open_flag                          0
# attr_1                         27781
# attr_2                           252
# attr_3                            21
# age                            27781
# domain                            21
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# country_code                       0
# grass_date                         0
# subject_line_length                0
# last_open_day                   7589
# last_login_day                   169
# last_checkout_day              11403
# open_count_last_10_days            0
# open_count_last_30_days            0
# open_count_last_60_days            0
# login_count_last_10_days           0
# login_count_last_30_days           0
# login_count_last_60_days           0
# checkout_count_last_10_days        0
# checkout_count_last_30_days        0
# checkout_count_last_60_days        0
# attr_1                         21716
# attr_2                           239
# attr_3                            19
# age                            21716
# domain                            19
# dtype: int64

# %% [markdown]
# ## Age

# %%
print('Train dataset!')
print('Total data with age below 13:', df_train['age'][df_train['age'] < 13].count())
print('Total data with age below 18:', df_train['age'][df_train['age'] < 18].count())
print('Total data with age 70 or more:', df_train['age'][df_train['age'] >= 70].count())
print('Total data with age 100 or more:', df_train['age'][df_train['age'] >= 100].count())

print('Test dataset!')
print('Total data with age below 13:', df_test['age'][df_test['age'] < 13].count())
print('Total data with age below 18:', df_test['age'][df_test['age'] < 18].count())
print('Total data with age 70 or more:', df_test['age'][df_test['age'] >= 70].count())
print('Total data with age 100 or more:', df_test['age'][df_test['age'] >= 100].count())
# Out:
# Train dataset!
# Total data with age below 13: 326
# Total data with age below 18: 962
# Total data with age 70 or more: 343
# Total data with age 100 or more: 286
# Test dataset!
# Total data with age below 13: 215
# Total data with age below 18: 758
# Total data with age 70 or more: 253
# Total data with age 100 or more: 217

# %% [markdown]
# ## last_login_day & last_checkout_day

# %%
df_train[ df_train['last_login_day'].isnull() & ~df_train['last_checkout_day'].isnull() ]
# Out:
#        country_code                 grass_date  subject_line_length  \
# 7022              1  2019-07-21 00:00:00+08:00                   40
# 12170             4  2019-07-24 00:00:00+08:00                   53
# 12173             4  2019-07-24 00:00:00+08:00                   53
# 12175             4  2019-07-24 00:00:00+08:00                   53
# 12177             4  2019-07-24 00:00:00+08:00                   53
# ...             ...                        ...                  ...
# 42788             4  2019-08-14 00:00:00+08:00                   33
# 50177             7  2019-08-19 00:00:00+08:00                   69
# 52770             1  2019-08-20 00:00:00+08:00                   68
# 54478             3  2019-08-21 00:00:00+08:00                   23
# 67568             1  2019-09-01 00:00:00+08:00                   40
#
#        last_open_day  last_login_day  last_checkout_day  \
# 7022             NaN             NaN               66.0
# 12170            NaN             NaN               43.0
# 12173            NaN             NaN              443.0
# 12175            NaN             NaN                5.0
# 12177            NaN             NaN                1.0
# ...              ...             ...                ...
# 42788            NaN             NaN              101.0
# 50177            NaN             NaN               73.0
# 52770            NaN             NaN               14.0
# 54478            NaN             NaN               55.0
# 67568            NaN             NaN                9.0
#
#        open_count_last_10_days  open_count_last_30_days  \
# 7022                         0                        0
# 12170                        0                        0
# 12173                        0                        0
# 12175                        0                        0
# 12177                        2                        2
# ...                        ...                      ...
# 42788                        1                        1
# 50177                        0                        0
# 52770                        0                        0
# 54478                        0                        4
# 67568                        0                        0
#
#        open_count_last_60_days  login_count_last_10_days  \
# 7022                         0                        37
# 12170                        0                         1
# 12173                        0                         0
# 12175                        0                        18
# 12177                        3                         9
# ...                        ...                       ...
# 42788                        1                        42
# 50177                        0                         0
# 52770                        1                        52
# 54478                        7                         0
# 67568                        0                         2
#
#        login_count_last_30_days  login_count_last_60_days  \
# 7022                         92                       122
# 12170                         2                         7
# 12173                         1                         6
# 12175                        47                        93
# 12177                        29                        62
# ...                         ...                       ...
# 42788                       142                       289
# 50177                         3                        18
# 52770                       153                       277
# 54478                         0                        15
# 67568                         2                         3
#
#        checkout_count_last_10_days  checkout_count_last_30_days  \
# 7022                             0                            0
# 12170                            0                            0
# 12173                            0                            0
# 12175                            3                           13
# 12177                            4                           11
# ...                            ...                          ...
# 42788                            0                            0
# 50177                            0                            0
# 52770                            0                            2
# 54478                            0                            0
# 67568                            1                            1
#
#        checkout_count_last_60_days  open_flag  attr_1  attr_2  attr_3   age  \
# 7022                             0          0     1.0     1.0     4.0  43.0
# 12170                            1          0     1.0     NaN     2.0  28.0
# 12173                            0          0     1.0     NaN     2.0  29.0
# 12175                           18          0     1.0     NaN     2.0  27.0
# 12177                           17          1     1.0     NaN     2.0  22.0
# ...                            ...        ...     ...     ...     ...   ...
# 42788                            0          0     1.0     1.0     1.0  31.0
# 50177                            0          0     1.0     1.0     2.0  31.0
# 52770                            3          0     1.0     1.0     1.0  25.0
# 54478                            1          0     NaN     1.0     0.0   NaN
# 67568                            1          0     1.0     1.0     1.0  23.0
#
#        domain
# 7022      3.0
# 12170     2.0
# 12173     0.0
# 12175     2.0
# 12177     0.0
# ...       ...
# 42788     0.0
# 50177     0.0
# 52770     0.0
# 54478     0.0
# 67568     0.0
#
# [253 rows x 21 columns]

# %%
df_test[ df_test['last_login_day'].isnull() & ~df_test['last_checkout_day'].isnull() ]
# Out:
#        country_code                 grass_date  subject_line_length  \
# 20896             3  2019-09-09 00:00:00+08:00                   41
# 38884             6  2019-09-16 00:00:00+08:00                   20
# 48025             6  2019-09-23 00:00:00+08:00                   30
# 49559             6  2019-09-24 00:00:00+08:00                   20
# 51541             6  2019-09-25 00:00:00+08:00                   54
#
#        last_open_day  last_login_day  last_checkout_day  \
# 20896            NaN             NaN                3.0
# 38884            NaN             NaN               16.0
# 48025            NaN             NaN                3.0
# 49559            NaN             NaN               54.0
# 51541            NaN             NaN               36.0
#
#        open_count_last_10_days  open_count_last_30_days  \
# 20896                        0                        0
# 38884                        1                        2
# 48025                        0                        0
# 49559                        0                        0
# 51541                        1                        4
#
#        open_count_last_60_days  login_count_last_10_days  \
# 20896                        1                         8
# 38884                        6                        54
# 48025                        2                         0
# 49559                        0                        17
# 51541                        6                         0
#
#        login_count_last_30_days  login_count_last_60_days  \
# 20896                        28                        48
# 38884                       151                       309
# 48025                         0                         0
# 49559                        82                       225
# 51541                         0                         0
#
#        checkout_count_last_10_days  checkout_count_last_30_days  \
# 20896                            3                            7
# 38884                            0                            0
# 48025                            0                            0
# 49559                            0                            0
# 51541                            0                            0
#
#        checkout_count_last_60_days  attr_1  attr_2  attr_3   age  domain
# 20896                           11     1.0     1.0     1.0  36.0     2.0
# 38884                            0     NaN     1.0     0.0   NaN     0.0
# 48025                            0     1.0     1.0     2.0  29.0     2.0
# 49559                            1     1.0     1.0     2.0  19.0     0.0
# 51541                            0     1.0     0.0     1.0  26.0     0.0

# %% [markdown]
# ## last_open_day && open_count_last_{}_days

# %%
df_train[ df_train['last_open_day'].isnull() & ((df_train['open_count_last_10_days'] > 0) | (df_train['open_count_last_30_days'] > 0) | (df_train['open_count_last_60_days'] > 0)) ]
# Out:
#        country_code                 grass_date  subject_line_length  \
# 667               1  2019-07-16 00:00:00+08:00                   58
# 1011              2  2019-07-16 00:00:00+08:00                   36
# 1132              2  2019-07-16 00:00:00+08:00                   36
# 1287              5  2019-07-16 00:00:00+08:00                   43
# 1321              2  2019-07-16 00:00:00+08:00                   36
# ...             ...                        ...                  ...
# 73228             1  2019-09-02 00:00:00+08:00                   33
# 73269             1  2019-09-02 00:00:00+08:00                   33
# 73363             1  2019-09-02 00:00:00+08:00                   33
# 73415             3  2019-09-02 00:00:00+08:00                   49
# 73451             1  2019-09-02 00:00:00+08:00                   33
#
#        last_open_day  last_login_day  last_checkout_day  \
# 667              NaN            14.0               19.0
# 1011             NaN           196.0               45.0
# 1132             NaN            15.0               15.0
# 1287             NaN            94.0              197.0
# 1321             NaN           348.0                NaN
# ...              ...             ...                ...
# 73228            NaN            27.0                NaN
# 73269            NaN            27.0                NaN
# 73363            NaN            14.0                NaN
# 73415            NaN             3.0                NaN
# 73451            NaN             3.0                NaN
#
#        open_count_last_10_days  open_count_last_30_days  \
# 667                          1                        1
# 1011                         0                        2
# 1132                         1                        1
# 1287                         2                        2
# 1321                         0                        2
# ...                        ...                      ...
# 73228                        2                        2
# 73269                        2                        2
# 73363                        0                        1
# 73415                        1                        1
# 73451                        1                        1
#
#        open_count_last_60_days  login_count_last_10_days  \
# 667                          1                         0
# 1011                         2                         0
# 1132                         1                         0
# 1287                         2                         0
# 1321                         2                         0
# ...                        ...                       ...
# 73228                        2                         0
# 73269                        2                         0
# 73363                        1                         0
# 73415                        1                         8
# 73451                        1                         2
#
#        login_count_last_30_days  login_count_last_60_days  \
# 667                          15                        18
# 1011                          0                         2
# 1132                          0                         0
# 1287                          0                         0
# 1321                          0                         0
# ...                         ...                       ...
# 73228                         2                         2
# 73269                         1                         1
# 73363                         5                         5
# 73415                        17                        17
# 73451                         3                         3
#
#        checkout_count_last_10_days  checkout_count_last_30_days  \
# 667                              0                            1
# 1011                             0                            0
# 1132                             0                            0
# 1287                             0                            0
# 1321                             0                            0
# ...                            ...                          ...
# 73228                            0                            0
# 73269                            0                            0
# 73363                            0                            0
# 73415                            0                            0
# 73451                            0                            0
#
#        checkout_count_last_60_days  open_flag  attr_1  attr_2  attr_3   age  \
# 667                              1          0     NaN     1.0     0.0   NaN
# 1011                             4          0     1.0     1.0     1.0  29.0
# 1132                             0          1     1.0     1.0     2.0  27.0
# 1287                             0          0     1.0     1.0     2.0  31.0
# 1321                             0          0     1.0     1.0     2.0  27.0
# ...                            ...        ...     ...     ...     ...   ...
# 73228                            0          1     NaN     1.0     0.0   NaN
# 73269                            0          0     NaN     1.0     0.0   NaN
# 73363                            0          0     NaN     1.0     0.0   NaN
# 73415                            0          0     1.0     1.0     1.0   1.0
# 73451                            0          1     NaN     1.0     0.0   NaN
#
#        domain
# 667       0.0
# 1011      0.0
# 1132      0.0
# 1287      0.0
# 1321      0.0
# ...       ...
# 73228     0.0
# 73269     0.0
# 73363     0.0
# 73415     0.0
# 73451     0.0
#
# [377 rows x 21 columns]

# %%
df_test[ df_test['last_open_day'].isnull() & ((df_test['open_count_last_10_days'] > 0) | (df_test['open_count_last_30_days'] > 0) | (df_test['open_count_last_60_days'] > 0)) ]
# Out:
#        country_code                 grass_date  subject_line_length  \
# 3080              1  2019-09-03 00:00:00+08:00                   36
# 3085              6  2019-09-03 00:00:00+08:00                   35
# 3106              1  2019-09-03 00:00:00+08:00                   43
# 3133              1  2019-09-03 00:00:00+08:00                   43
# 3215              1  2019-09-03 00:00:00+08:00                   43
# ...             ...                        ...                  ...
# 54302             6  2019-09-27 00:00:00+08:00                   21
# 55202             3  2019-09-28 00:00:00+08:00                   38
# 55916             3  2019-09-29 00:00:00+08:00                   50
# 55924             3  2019-09-29 00:00:00+08:00                   43
# 55954             6  2019-09-29 00:00:00+08:00                   41
#
#        last_open_day  last_login_day  last_checkout_day  \
# 3080             NaN             2.0                2.0
# 3085             NaN             1.0                7.0
# 3106             NaN            13.0                NaN
# 3133             NaN            11.0               26.0
# 3215             NaN            11.0               14.0
# ...              ...             ...                ...
# 54302            NaN             NaN                NaN
# 55202            NaN             2.0                4.0
# 55916            NaN            15.0                NaN
# 55924            NaN             5.0                NaN
# 55954            NaN             NaN                NaN
#
#        open_count_last_10_days  open_count_last_30_days  \
# 3080                         0                        1
# 3085                         1                        1
# 3106                         1                        1
# 3133                         2                        2
# 3215                         1                        1
# ...                        ...                      ...
# 54302                        3                        7
# 55202                        1                        1
# 55916                        3                        6
# 55924                        2                        2
# 55954                        1                        1
#
#        open_count_last_60_days  login_count_last_10_days  \
# 3080                         1                        42
# 3085                         1                         4
# 3106                         1                         1
# 3133                         2                         3
# 3215                         1                         2
# ...                        ...                       ...
# 54302                        8                         0
# 55202                        1                        37
# 55916                        6                         0
# 55924                        2                         1
# 55954                        1                        39
#
#        login_count_last_30_days  login_count_last_60_days  \
# 3080                         77                        77
# 3085                          5                         5
# 3106                         17                        17
# 3133                         21                        21
# 3215                         10                        10
# ...                         ...                       ...
# 54302                         0                         0
# 55202                        56                        56
# 55916                         6                         6
# 55924                         8                         8
# 55954                        41                        41
#
#        checkout_count_last_10_days  checkout_count_last_30_days  \
# 3080                            11                           13
# 3085                             2                            2
# 3106                             0                            0
# 3133                             0                            1
# 3215                             0                            3
# ...                            ...                          ...
# 54302                            0                            0
# 55202                            1                            2
# 55916                            0                            0
# 55924                            0                            0
# 55954                            0                            0
#
#        checkout_count_last_60_days  attr_1  attr_2  attr_3   age  domain
# 3080                            13     1.0     1.0     1.0  20.0     0.0
# 3085                             2     1.0     1.0     2.0  22.0     0.0
# 3106                             0     NaN     1.0     0.0   NaN     0.0
# 3133                             1     NaN     1.0     0.0   NaN     0.0
# 3215                             3     1.0     1.0     2.0  31.0     0.0
# ...                            ...     ...     ...     ...   ...     ...
# 54302                            0     1.0     1.0     1.0  29.0     0.0
# 55202                            2     NaN     1.0     0.0   NaN     0.0
# 55916                            0     NaN     1.0     0.0   NaN     0.0
# 55924                            0     1.0     1.0     3.0  30.0     0.0
# 55954                            0     NaN     1.0     0.0   NaN     0.0
#
# [281 rows x 20 columns]

# %% [markdown]
# ## last_login_day && login_count_last_{}_days

# %%
df_train[ df_train['last_login_day'].isnull() & ((df_train['login_count_last_10_days'] > 0) | (df_train['login_count_last_30_days'] > 0) | (df_train['login_count_last_60_days'] > 0)) ]
# Out:
#        country_code                 grass_date  subject_line_length  \
# 7022              1  2019-07-21 00:00:00+08:00                   40
# 11759             3  2019-07-23 00:00:00+08:00                   47
# 12170             4  2019-07-24 00:00:00+08:00                   53
# 12173             4  2019-07-24 00:00:00+08:00                   53
# 12175             4  2019-07-24 00:00:00+08:00                   53
# ...             ...                        ...                  ...
# 50177             7  2019-08-19 00:00:00+08:00                   69
# 52770             1  2019-08-20 00:00:00+08:00                   68
# 53971             2  2019-08-21 00:00:00+08:00                   38
# 54478             3  2019-08-21 00:00:00+08:00                   23
# 67568             1  2019-09-01 00:00:00+08:00                   40
#
#        last_open_day  last_login_day  last_checkout_day  \
# 7022             NaN             NaN               66.0
# 11759            NaN             NaN                NaN
# 12170            NaN             NaN               43.0
# 12173            NaN             NaN              443.0
# 12175            NaN             NaN                5.0
# ...              ...             ...                ...
# 50177            NaN             NaN               73.0
# 52770            NaN             NaN               14.0
# 53971            NaN             NaN                NaN
# 54478            NaN             NaN               55.0
# 67568            NaN             NaN                9.0
#
#        open_count_last_10_days  open_count_last_30_days  \
# 7022                         0                        0
# 11759                        0                        0
# 12170                        0                        0
# 12173                        0                        0
# 12175                        0                        0
# ...                        ...                      ...
# 50177                        0                        0
# 52770                        0                        0
# 53971                        0                        1
# 54478                        0                        4
# 67568                        0                        0
#
#        open_count_last_60_days  login_count_last_10_days  \
# 7022                         0                        37
# 11759                        0                         0
# 12170                        0                         1
# 12173                        0                         0
# 12175                        0                        18
# ...                        ...                       ...
# 50177                        0                         0
# 52770                        1                        52
# 53971                        6                         2
# 54478                        7                         0
# 67568                        0                         2
#
#        login_count_last_30_days  login_count_last_60_days  \
# 7022                         92                       122
# 11759                         0                         2
# 12170                         2                         7
# 12173                         1                         6
# 12175                        47                        93
# ...                         ...                       ...
# 50177                         3                        18
# 52770                       153                       277
# 53971                        17                        25
# 54478                         0                        15
# 67568                         2                         3
#
#        checkout_count_last_10_days  checkout_count_last_30_days  \
# 7022                             0                            0
# 11759                            0                            0
# 12170                            0                            0
# 12173                            0                            0
# 12175                            3                           13
# ...                            ...                          ...
# 50177                            0                            0
# 52770                            0                            2
# 53971                            0                           17
# 54478                            0                            0
# 67568                            1                            1
#
#        checkout_count_last_60_days  open_flag  attr_1  attr_2  attr_3   age  \
# 7022                             0          0     1.0     1.0     4.0  43.0
# 11759                            0          1     NaN     1.0     0.0   NaN
# 12170                            1          0     1.0     NaN     2.0  28.0
# 12173                            0          0     1.0     NaN     2.0  29.0
# 12175                           18          0     1.0     NaN     2.0  27.0
# ...                            ...        ...     ...     ...     ...   ...
# 50177                            0          0     1.0     1.0     2.0  31.0
# 52770                            3          0     1.0     1.0     1.0  25.0
# 53971                           18          0     NaN     1.0     0.0   NaN
# 54478                            1          0     NaN     1.0     0.0   NaN
# 67568                            1          0     1.0     1.0     1.0  23.0
#
#        domain
# 7022      3.0
# 11759     2.0
# 12170     2.0
# 12173     0.0
# 12175     2.0
# ...       ...
# 50177     0.0
# 52770     0.0
# 53971     0.0
# 54478     0.0
# 67568     0.0
#
# [259 rows x 21 columns]

# %%
df_test[ df_test['last_login_day'].isnull() & ((df_test['login_count_last_10_days'] > 0) | (df_test['login_count_last_30_days'] > 0) | (df_test['login_count_last_60_days'] > 0)) ]
# Out:
#        country_code                 grass_date  subject_line_length  \
# 20896             3  2019-09-09 00:00:00+08:00                   41
# 30797             6  2019-09-11 00:00:00+08:00                   20
# 31043             6  2019-09-11 00:00:00+08:00                   20
# 31332             6  2019-09-11 00:00:00+08:00                   20
# 31765             6  2019-09-11 00:00:00+08:00                   20
# ...             ...                        ...                  ...
# 54095             6  2019-09-27 00:00:00+08:00                   21
# 54147             6  2019-09-27 00:00:00+08:00                   21
# 54155             6  2019-09-27 00:00:00+08:00                   21
# 54293             6  2019-09-27 00:00:00+08:00                   21
# 55954             6  2019-09-29 00:00:00+08:00                   41
#
#        last_open_day  last_login_day  last_checkout_day  \
# 20896            NaN             NaN                3.0
# 30797            NaN             NaN                NaN
# 31043            NaN             NaN                NaN
# 31332            NaN             NaN                NaN
# 31765            NaN             NaN                NaN
# ...              ...             ...                ...
# 54095            NaN             NaN                NaN
# 54147            NaN             NaN                NaN
# 54155            NaN             NaN                NaN
# 54293            NaN             NaN                NaN
# 55954            NaN             NaN                NaN
#
#        open_count_last_10_days  open_count_last_30_days  \
# 20896                        0                        0
# 30797                        0                        0
# 31043                        0                        0
# 31332                        0                        0
# 31765                        0                        0
# ...                        ...                      ...
# 54095                        0                        1
# 54147                        1                        2
# 54155                        0                        0
# 54293                        2                        2
# 55954                        1                        1
#
#        open_count_last_60_days  login_count_last_10_days  \
# 20896                        1                         8
# 30797                        0                         1
# 31043                        0                        13
# 31332                        0                         0
# 31765                        1                        21
# ...                        ...                       ...
# 54095                        3                        13
# 54147                        7                         5
# 54155                        0                         0
# 54293                        2                        13
# 55954                        1                        39
#
#        login_count_last_30_days  login_count_last_60_days  \
# 20896                        28                        48
# 30797                         1                         1
# 31043                        41                        76
# 31332                         1                         2
# 31765                        69                       142
# ...                         ...                       ...
# 54095                        40                        93
# 54147                        23                        57
# 54155                         0                         7
# 54293                        13                        13
# 55954                        41                        41
#
#        checkout_count_last_10_days  checkout_count_last_30_days  \
# 20896                            3                            7
# 30797                            0                            0
# 31043                            0                            0
# 31332                            0                            0
# 31765                            0                            0
# ...                            ...                          ...
# 54095                            0                            0
# 54147                            0                            0
# 54155                            0                            0
# 54293                            0                            0
# 55954                            0                            0
#
#        checkout_count_last_60_days  attr_1  attr_2  attr_3   age  domain
# 20896                           11     1.0     1.0     1.0  36.0     2.0
# 30797                            0     1.0     1.0     1.0  33.0     0.0
# 31043                            0     NaN     1.0     0.0   NaN     0.0
# 31332                            0     1.0     1.0     1.0  22.0     0.0
# 31765                            0     NaN     1.0     0.0   NaN     0.0
# ...                            ...     ...     ...     ...   ...     ...
# 54095                            0     1.0     1.0     2.0  22.0     3.0
# 54147                            0     NaN     1.0     0.0   NaN     3.0
# 54155                            0     NaN     1.0     0.0   NaN     9.0
# 54293                            0     1.0     1.0     1.0  29.0     0.0
# 55954                            0     NaN     1.0     0.0   NaN     0.0
#
# [103 rows x 20 columns]

# %% [markdown]
# ## last_login_day && login_count_last_{}_days

# %%
df_train[ df_train['last_checkout_day'].isnull() & ((df_train['checkout_count_last_10_days'] > 0) | (df_train['checkout_count_last_30_days'] > 0) | (df_train['checkout_count_last_60_days'] > 0)) ]
# Out:
#        country_code                 grass_date  subject_line_length  \
# 405               1  2019-07-16 00:00:00+08:00                   58
# 688               1  2019-07-16 00:00:00+08:00                   64
# 705               2  2019-07-16 00:00:00+08:00                   36
# 738               3  2019-07-16 00:00:00+08:00                   33
# 841               1  2019-07-16 00:00:00+08:00                   49
# ...             ...                        ...                  ...
# 73371             1  2019-09-02 00:00:00+08:00                   33
# 73412             1  2019-09-02 00:00:00+08:00                   33
# 73449             2  2019-09-02 00:00:00+08:00                   38
# 73454             1  2019-09-02 00:00:00+08:00                   33
# 73475             6  2019-09-02 00:00:00+08:00                   39
#
#        last_open_day  last_login_day  last_checkout_day  \
# 405              4.0            38.0                NaN
# 688             83.0             4.0                NaN
# 705              3.0            95.0                NaN
# 738              7.0            37.0                NaN
# 841             22.0             6.0                NaN
# ...              ...             ...                ...
# 73371            NaN            14.0                NaN
# 73412            NaN             2.0                NaN
# 73449           14.0             2.0                NaN
# 73454           13.0             1.0                NaN
# 73475            6.0             8.0                NaN
#
#        open_count_last_10_days  open_count_last_30_days  \
# 405                          6                       15
# 688                          0                        0
# 705                         11                       18
# 738                          1                        5
# 841                          0                        1
# ...                        ...                      ...
# 73371                        0                        0
# 73412                        0                        0
# 73449                        0                        0
# 73454                        0                        0
# 73475                        1                        1
#
#        open_count_last_60_days  login_count_last_10_days  \
# 405                         29                         4
# 688                          0                        35
# 705                         23                         1
# 738                         10                         1
# 841                          2                         7
# ...                        ...                       ...
# 73371                        0                         1
# 73412                        0                        17
# 73449                        0                         7
# 73454                        0                        11
# 73475                        1                         1
#
#        login_count_last_30_days  login_count_last_60_days  \
# 405                          25                        52
# 688                         126                       273
# 705                           8                        54
# 738                           1                         6
# 841                          19                        48
# ...                         ...                       ...
# 73371                         7                         7
# 73412                        29                        29
# 73449                        20                        20
# 73454                        20                        20
# 73475                         4                         4
#
#        checkout_count_last_10_days  checkout_count_last_30_days  \
# 405                              0                            0
# 688                              0                            3
# 705                              0                            0
# 738                              0                            0
# 841                              2                           10
# ...                            ...                          ...
# 73371                            0                            2
# 73412                            0                            1
# 73449                            0                            1
# 73454                           26                           49
# 73475                            0                            1
#
#        checkout_count_last_60_days  open_flag  attr_1  attr_2  attr_3   age  \
# 405                              3          0     1.0     1.0     2.0  24.0
# 688                             14          0     1.0     1.0     1.0  33.0
# 705                              7          1     NaN     1.0     0.0   NaN
# 738                              1          0     1.0     1.0     2.0  27.0
# 841                             24          0     1.0     1.0     2.0  25.0
# ...                            ...        ...     ...     ...     ...   ...
# 73371                            2          0     NaN     1.0     0.0   NaN
# 73412                            1          0     NaN     1.0     0.0   NaN
# 73449                            1          0     1.0     1.0     1.0  29.0
# 73454                           49          0     1.0     1.0     2.0  50.0
# 73475                            1          0     NaN     1.0     0.0   NaN
#
#        domain
# 405       0.0
# 688       0.0
# 705       0.0
# 738       0.0
# 841       0.0
# ...       ...
# 73371     0.0
# 73412     0.0
# 73449     0.0
# 73454     2.0
# 73475     0.0
#
# [813 rows x 21 columns]

# %%
df_test[ df_test['last_checkout_day'].isnull() & ((df_test['checkout_count_last_10_days'] > 0) | (df_test['checkout_count_last_30_days'] > 0) | (df_test['checkout_count_last_60_days'] > 0)) ]
# Out:
#        country_code                 grass_date  subject_line_length  \
# 863               1  2019-09-03 00:00:00+08:00                   43
# 1528              2  2019-09-03 00:00:00+08:00                   43
# 1980              1  2019-09-03 00:00:00+08:00                   43
# 2239              3  2019-09-03 00:00:00+08:00                   28
# 2242              3  2019-09-03 00:00:00+08:00                   46
# ...             ...                        ...                  ...
# 55895             6  2019-09-29 00:00:00+08:00                   43
# 55901             3  2019-09-29 00:00:00+08:00                   43
# 55923             3  2019-09-29 00:00:00+08:00                   43
# 55936             1  2019-09-29 00:00:00+08:00                   48
# 55944             3  2019-09-29 00:00:00+08:00                   50
#
#        last_open_day  last_login_day  last_checkout_day  \
# 863            201.0             9.0                NaN
# 1528             4.0             9.0                NaN
# 1980            10.0            22.0                NaN
# 2239             NaN             9.0                NaN
# 2242            18.0             3.0                NaN
# ...              ...             ...                ...
# 55895           11.0             7.0                NaN
# 55901            NaN             4.0                NaN
# 55923            NaN             7.0                NaN
# 55936            NaN            17.0                NaN
# 55944            NaN            15.0                NaN
#
#        open_count_last_10_days  open_count_last_30_days  \
# 863                          0                        0
# 1528                         1                        3
# 1980                         0                        0
# 2239                         0                        0
# 2242                         0                        2
# ...                        ...                      ...
# 55895                        0                        3
# 55901                        0                        0
# 55923                        0                        0
# 55936                        0                        0
# 55944                        0                        0
#
#        open_count_last_60_days  login_count_last_10_days  \
# 863                          0                         1
# 1528                         9                         2
# 1980                         2                         0
# 2239                         0                        11
# 2242                         3                         4
# ...                        ...                       ...
# 55895                        3                         7
# 55901                        0                         4
# 55923                        0                        22
# 55936                        0                         4
# 55944                        0                         0
#
#        login_count_last_30_days  login_count_last_60_days  \
# 863                           4                         4
# 1528                          5                        19
# 1980                          5                        18
# 2239                         40                        64
# 2242                         13                        16
# ...                         ...                       ...
# 55895                        26                        28
# 55901                         9                         9
# 55923                        41                        41
# 55936                        15                        15
# 55944                         2                         2
#
#        checkout_count_last_10_days  checkout_count_last_30_days  \
# 863                              0                            1
# 1528                             0                            0
# 1980                             0                            0
# 2239                             0                            1
# 2242                             0                            0
# ...                            ...                          ...
# 55895                            0                            3
# 55901                            1                            1
# 55923                            1                            2
# 55936                            0                            1
# 55944                            0                            1
#
#        checkout_count_last_60_days  attr_1  attr_2  attr_3   age  domain
# 863                              1     1.0     1.0     1.0  31.0     0.0
# 1528                             7     1.0     1.0     2.0  50.0     0.0
# 1980                             1     1.0     1.0     1.0  19.0     0.0
# 2239                             2     NaN     1.0     0.0   NaN     0.0
# 2242                             1     NaN     1.0     0.0   NaN     0.0
# ...                            ...     ...     ...     ...   ...     ...
# 55895                            3     NaN     1.0     0.0   NaN     0.0
# 55901                            1     1.0     1.0     1.0  20.0     0.0
# 55923                            2     NaN     1.0     0.0   NaN     0.0
# 55936                            1     NaN     1.0     0.0   NaN     0.0
# 55944                            1     NaN     1.0     0.0   NaN     9.0
#
# [569 rows x 20 columns]

# %% [markdown]
# # Additional preprocessing

# %% [markdown]
# ## 1. Timedate

# %%
df_train['day'] = pd.to_datetime(df_train['grass_date']).dt.dayofweek.astype('category')
df_test['day'] = pd.to_datetime(df_test['grass_date']).dt.dayofweek.astype('category')

# %%
del df_train['grass_date']
del df_test['grass_date']

# %% [markdown]
# ## 2. ~~Normalization~~ Standardization

# %%
# from sklearn.preprocessing import StandardScaler

# cont_feature = [
#     'subject_line_length', 'last_open_day', 'last_login_day', 'last_checkout_day',
#     'open_count_last_10_days', 'open_count_last_30_days', 'open_count_last_60_days',
#     'login_count_last_10_days', 'login_count_last_30_days', 'login_count_last_60_days',
#     'checkout_count_last_10_days', 'checkout_count_last_30_days',
#     'checkout_count_last_60_days', 'age'
# ]

# scaler = StandardScaler()
# df_train[cont_feature] = scaler.fit_transform(df_train[cont_feature])
# df_test[cont_feature] = scaler.transform(df_test[cont_feature])

# %% [markdown]
# ## 3. Anomaly

# %%
def fix_age(age):
    if age < 18 or age >= 100:
        return np.nan
    else:
        return age
    
df_train['age'] = df_train['age'].apply(fix_age)
df_test['age'] = df_test['age'].apply(fix_age)

# %% [markdown]
# ## 4. NaN

# %%
# # last_open_day
# df_train['last_open_day_nan'] = df_train['last_open_day'].isnull()
# df_train['last_open_day'] = df_train['last_open_day'].fillna(-1)

# df_test['last_open_day_nan'] = df_test['last_open_day'].isnull()
# df_test['last_open_day'] = df_test['last_open_day'].fillna(-1)

# # last_login_day
# df_train['last_login_day_nan'] = df_train['last_login_day'].isnull()
# df_train['last_login_day'] = df_train['last_login_day'].fillna(-1)

# df_test['last_login_day_nan'] = df_test['last_login_day'].isnull()
# df_test['last_login_day'] = df_test['last_login_day'].fillna(-1)

# # last_checkout_day
# df_train['last_checkout_day_nan'] = df_train['last_checkout_day'].isnull()
# df_train['last_checkout_day'] = df_train['last_checkout_day'].fillna(-1)

# df_test['last_checkout_day_nan'] = df_test['last_checkout_day'].isnull()
# df_test['last_checkout_day'] = df_test['last_checkout_day'].fillna(-1)

# # attr_1
# df_train['attr_1_nan'] = df_train['attr_1'].isnull()
# df_train['attr_1'] = df_train['attr_1'].fillna(-1)

# df_test['attr_1_nan'] = df_test['attr_1'].isnull()
# df_test['attr_1'] = df_test['attr_1'].fillna(-1)

# # attr_2
# df_train['attr_2_nan'] = df_train['attr_2'].isnull()
# df_train['attr_2'] = df_train['attr_2'].fillna(-1)

# df_test['attr_2_nan'] = df_test['attr_2'].isnull()
# df_test['attr_2'] = df_test['attr_2'].fillna(-1)

# # attr_3
# df_train['attr_3_nan'] = df_train['attr_3'].isnull()
# df_train['attr_3'] = df_train['attr_3'].fillna(-1)

# df_test['attr_3_nan'] = df_test['attr_3'].isnull()
# df_test['attr_3'] = df_test['attr_3'].fillna(-1)

# # age
# df_train['age_nan'] = df_train['age'].isnull()
# df_train['age'] = df_train['age'].fillna(-1)

# df_test['age_nan'] = df_test['age'].isnull()
# df_test['age'] = df_test['age'].fillna(-1)

# %%
# domain
# 1 -> 'other' domain from previous preprocessing
# df_train['domain_nan'] = df_train['domain'].isnull()
df_train['domain'] = df_train['domain'].fillna(1)

# df_test['domain_nan'] = df_test['domain'].isnull()
df_test['domain'] = df_test['domain'].fillna(1)

# %% [markdown]
# ## 5. Misc

# %%
X = df_train.copy()
del X['open_flag']

X_test = df_test.copy()

y = df_train['open_flag'].to_numpy()

# %%
cat_feature = [
    'country_code','attr_1', 'attr_2', 'attr_3',
    'domain','day',
#     'last_open_day_nan', 'last_login_day_nan',
#     'last_checkout_day_nan', 'attr_1_nan', 'attr_2_nan',
#     'attr_3_nan', 'age_nan', 'domain_nan',
    
]
cat_feature_idx = [X.columns.get_loc(ct) for ct in cat_feature]
cat_feature_idx
# Out:
# [0, 14, 15, 16, 18, 19]

# %% [markdown]
# # KFold Model

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import matthews_corrcoef

K = 5

# %%
param_dict = {
    'min_data_in_leaf': [20, 50],
    'feature_fraction': [0.9, 1.0],
    'max_bin': [16, 102, 255],
    'lambda_l1': [0.0, 1e-4, 1e-3, 1e-2, 1e-1, 1e-0],
    'lambda_l2': [0.0, 1e-3, 1e-2, 1e-1, 1e-0, 1e1],
#     'path_smooth': [0.0, 0.1, 0.3],
#     'min_gain_to_split': [0.0, 3e-2, 1e-1, 3e-1],
    
}
param_key = list(param_dict.keys())
param_item = list(param_dict.values())
param_item
# Out:
# [[20, 50],
#  [0.9, 1.0],
#  [16, 102, 255],
#  [0.0, 0.0001, 0.001, 0.01, 0.1, 1.0],
#  [0.0, 0.001, 0.01, 0.1, 1.0, 10.0]]

# %%
param_list = list(itertools.product(*param_item))
param_list[:10]
# Out:
# [(20, 0.9, 16, 0.0, 0.0),
#  (20, 0.9, 16, 0.0, 0.001),
#  (20, 0.9, 16, 0.0, 0.01),
#  (20, 0.9, 16, 0.0, 0.1),
#  (20, 0.9, 16, 0.0, 1.0),
#  (20, 0.9, 16, 0.0, 10.0),
#  (20, 0.9, 16, 0.0001, 0.0),
#  (20, 0.9, 16, 0.0001, 0.001),
#  (20, 0.9, 16, 0.0001, 0.01),
#  (20, 0.9, 16, 0.0001, 0.1)]

# %%
len(param_list)
# Out:
# 432

# %%
df_model = pd.DataFrame(columns=[*param_key, *[f'model_{i}' for i in range(K)], *[f'model_{i}_mcc' for i in range(K)], 'average_mcc'])
df_model
# Out:
# Empty DataFrame
# Columns: [min_data_in_leaf, feature_fraction, max_bin, lambda_l1, lambda_l2, model_0, model_1, model_2, model_3, model_4, model_0_mcc, model_1_mcc, model_2_mcc, model_3_mcc, model_4_mcc, average_mcc]
# Index: []

# %%
skf = StratifiedKFold(n_splits=K, shuffle=True, random_state=SEED)

for param in param_list:
    ctr = 0
    model = []
    mcc_score = []
    for train_idx, val_idx in skf.split(X, y):
        X_train, X_val = X.loc[train_idx], X.loc[val_idx]
        y_train, y_val = y[train_idx], y[val_idx]

        model.append(
            lgbm.LGBMClassifier(
                # fixed
                is_unbalance=True,
                seed=SEED,
                extra_trees=True,
                
                boosting_type='gbdt',
                n_estimators=100,
                learning_rate=0.01,
                num_leaves=63,
                min_data_per_group=1,
                # variable
                min_data_in_leaf=param[0],
                feature_fraction=param[1],
                max_bin=param[2],       
                lambda_l1=param[3],
                lambda_l2=param[4],
            )
        )
        model[ctr].fit(
            X_train, y_train,
            categorical_feature=cat_feature_idx
        )

        y_val_pred = model[ctr].predict(X_val)
        mcc_score.append(matthews_corrcoef(y_val, y_val_pred))

        ctr += 1
    df_model.loc[ df_model.shape[0] ] = [
        *param,
        *model,
        *mcc_score,
        sum(mcc_score) / len(mcc_score)
    ]
# Out:
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# ...
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))

# %% [markdown]
# # Evaluate

# %%
df_model = df_model.sort_values(by=['average_mcc', 'max_bin', 'feature_fraction', 'min_data_in_leaf', 'lambda_l1', 'lambda_l2'], ascending=[False, True, False, False, True, True]).reset_index(drop=True)
df_model.loc[:1000].to_pickle('model.pkl')
# !ls -lah
# Out:
# total 1.4G
# drwxr-xr-x 2 root root 4.0K Aug  7 07:26 .
# drwxr-xr-x 6 root root 4.0K Aug  7 06:42 ..
# ---------- 1 root root  22K Aug  7 06:42 __notebook__.ipynb
# -rw-r--r-- 1 root root 1.4G Aug  7 07:26 model.pkl
# -rw-r--r-- 1 root root  14K Aug  7 06:42 requirements.txt

# %%
pd.set_option('display.max_row', df_model.shape[0])

# %%
df_model
# Out:
#     min_data_in_leaf  feature_fraction max_bin  lambda_l1  lambda_l2  \
# 0                 20               1.0      16     0.0100      1.000
# 1                 20               0.9     255     1.0000      0.010
# 2                 20               0.9     102     0.0100      0.100
# 3                 20               0.9     255     0.0000      0.000
# 4                 50               0.9     102     1.0000      0.010
# 5                 50               0.9     102     0.1000      0.100
# 6                 20               0.9     102     0.0010      0.100
# 7                 50               0.9      16     0.0010      1.000
# 8                 20               0.9     255     0.0010      0.000
# 9                 50               0.9      16     0.0000      1.000
# 10                50               0.9      16     0.0001      1.000
# 11                20               0.9     255     0.0010      0.010
# 12                20               0.9     102     0.0010      1.000
# 13                50               0.9     102     1.0000      1.000
# 14                50               1.0      16     0.0100      0.001
# 15                50               0.9     102     0.1000      1.000
# 16                20               1.0      16     0.0100      0.010
# 17                20               1.0      16     0.0010      0.001
# 18                50               1.0      16     0.0100      0.100
# 19                20               0.9     255     0.0100      0.001
# 20                50               0.9     102     0.0010      1.000
# 21                50               1.0      16     0.0000      0.010
# 22                50               1.0      16     0.0001      0.010
# 23                20               0.9     102     1.0000      0.010
# 24                20               0.9     102     0.1000      0.100
# 25                20               0.9     255     0.0001      0.000
# 26                50               0.9     255     1.0000      0.000
# 27                20               0.9     102     0.1000      1.000
# 28                50               0.9      16     1.0000      1.000
# 29                50               1.0      16     0.0010      0.010
# 30                50               1.0      16     0.0010      0.100
# 31                20               0.9     102     1.0000      0.100
# 32                50               1.0      16     0.0100      0.000
# 33                20               0.9     102     0.0000      0.100
# 34                20               0.9     102     0.0100      1.000
# 35                20               1.0      16     0.0000      0.001
# 36                20               1.0      16     0.0001      0.001
# 37                20               0.9     255     0.0010      0.001
# 38                20               0.9     102     0.1000      0.010
# 39                20               0.9     102     0.1000      0.000
# 40                20               0.9     255     0.0000      0.010
# 41                20               0.9     255     0.0001      0.010
# 42                20               0.9     255     0.1000      0.010
# 43                20               0.9     255     0.0000      0.001
# 44                20               0.9     255     0.0001      0.001
# 45                20               0.9     102     0.0001      0.100
# 46                50               0.9     255     1.0000      0.001
# 47                20               1.0      16     1.0000      0.001
# 48                20               0.9     102     0.0001      1.000
# 49                20               0.9     255     0.1000      0.001
# 50                20               0.9     255     1.0000      0.100
# 51                50               0.9     255     1.0000      0.010
# 52                50               0.9     102     1.0000      0.000
# 53                20               0.9     102     0.0000      1.000
# 54                50               0.9     102     0.0100      0.000
# 55                20               0.9     255     0.0100      0.010
# 56                20               1.0      16     0.0000      1.000
# 57                20               1.0      16     0.0001      1.000
# 58                20               1.0      16     0.0010      0.000
# 59                50               0.9      16     0.0100      0.010
# 60                20               0.9     255     1.0000      0.000
# 61                50               1.0      16     0.0001      0.001
# 62                50               1.0      16     0.0010      0.000
# 63                50               1.0      16     1.0000      0.010
# 64                50               1.0      16     0.0000      0.100
# 65                20               0.9     102     1.0000      0.000
# 66                20               1.0      16     0.0000      0.000
# 67                50               1.0      16     0.0000      0.000
# 68                50               1.0      16     0.0000      0.001
# 69                50               1.0      16     0.0001      0.000
# 70                20               1.0      16     0.1000      0.000
# 71                50               1.0      16     0.0001      0.100
# 72                20               0.9     255     0.0100      0.000
# 73                50               0.9     102     0.0000      0.010
# 74                50               0.9     102     0.0001      0.010
# 75                20               0.9     102     0.0001      0.010
# 76                20               1.0      16     0.0001      0.000
# 77                20               0.9     255     0.0000      0.100
# 78                20               0.9     255     0.0001      0.100
# 79                20               1.0      16     0.0100      0.100
# 80                50               0.9      16     1.0000      0.001
# 81                20               0.9     102     1.0000      0.001
# 82                50               1.0      16     0.0010      0.001
# 83                50               0.9     102     0.0010      0.001
# 84                20               0.9     255     0.0010      0.100
# 85                50               0.9     102     0.0000      0.100
# 86                50               0.9     102     0.0001      0.100
# 87                50               0.9     102     1.0000      0.001
# 88                20               0.9     255     0.1000      0.000
# 89                20               1.0      16     0.1000      0.001
# 90                20               0.9      16     0.1000      0.100
# 91                20               0.9      16     0.0000      1.000
# 92                20               0.9      16     0.0001      1.000
# 93                20               0.9      16     0.0100      0.100
# 94                20               1.0      16     0.0010      1.000
# 95                50               1.0      16     0.0100      0.010
# 96                50               0.9     102     0.0010      0.010
# 97                50               0.9     102     1.0000      0.100
# 98                20               0.9     255     0.0100      0.100
# 99                20               0.9     102     0.1000      0.001
# 100               20               0.9     102     0.0000      0.000
# 101               20               0.9     102     0.0001      0.000
# 102               50               1.0      16     0.1000      0.100
# 103               20               0.9     102     0.0000      0.010
# 104               50               0.9     102     0.0100      0.100
# 105               20               0.9      16     0.0100      0.001
# 106               20               1.0      16     0.1000      0.100
# 107               20               0.9     102     0.0100      0.010
# 108               50               1.0     102     0.0000      0.001
# 109               50               1.0     102     0.0001      0.001
# 110               50               0.9     255     0.0000      0.100
# 111               50               0.9     255     0.0001      0.100
# 112               50               0.9      16     1.0000      0.100
# 113               20               0.9      16     0.0010      0.000
# 114               20               1.0      16     0.0100      0.000
# 115               20               1.0      16     1.0000      0.100
# 116               20               1.0     102     1.0000      0.000
# 117               20               1.0     102     1.0000      0.001
# 118               20               0.9     102     0.0000      0.001
# 119               20               0.9     102     0.0001      0.001
# 120               20               0.9      16     0.0100      1.000
# 121               20               1.0     102     1.0000      0.010
# 122               50               0.9     102     0.0000      1.000
# 123               50               0.9     102     0.0001      1.000
# 124               50               1.0      16     0.1000      0.001
# 125               50               0.9     255     0.1000      0.100
# 126               20               0.9      16     0.0010      1.000
# 127               50               1.0     102     0.0010      0.001
# 128               50               1.0      16     1.0000      0.001
# 129               50               0.9     102     0.0100      0.010
# 130               20               0.9     255     1.0000      0.001
# 131               20               0.9      16     0.0100      0.000
# 132               50               1.0      16     0.1000      0.010
# 133               50               0.9      16     1.0000      0.000
# 134               50               0.9      16     0.0100      0.100
# 135               20               0.9      16     0.0000      0.001
# 136               20               0.9      16     0.0001      0.001
# 137               20               0.9     255     0.1000      0.100
# 138               50               0.9     255     0.0100      0.010
# 139               50               0.9     255     0.0100      1.000
# 140               50               0.9     255     0.1000      1.000
# 141               20               0.9     102     0.0010      0.010
# 142               20               0.9     255     0.0100      1.000
# 143               50               0.9     255     0.1000      0.010
# 144               50               0.9     102     0.0010      0.100
# 145               50               0.9     255     0.0100      0.100
# 146               50               0.9     102     0.0100      0.001
# 147               50               0.9     102     0.1000      0.000
# 148               20               1.0      16     0.0000      0.010
# 149               50               0.9     102     0.1000      0.010
# 150               50               0.9      16     0.0010      0.000
# 151               50               0.9      16     0.1000      0.010
# 152               50               0.9     102     0.0100      1.000
# 153               20               1.0      16     0.0000      0.100
# 154               20               1.0      16     0.0001      0.100
# 155               50               1.0      16     1.0000      0.000
# 156               50               0.9      16     0.0001      0.000
# 157               50               0.9     255     0.1000      0.000
# 158               20               1.0      16     0.0100      0.001
# 159               20               0.9      16     0.0010      0.001
# 160               20               1.0      16     0.0010      0.100
# 161               20               0.9     102     1.0000      1.000
# 162               20               0.9      16     0.1000      0.010
# 163               50               0.9      16     0.0000      0.001
# 164               50               0.9      16     0.0001      0.001
# 165               50               0.9      16     0.0010      0.001
# 166               50               0.9      16     1.0000      0.010
# 167               50               1.0      16     0.1000      0.000
# 168               20               1.0      16     0.0010      0.010
# 169               20               0.9      16     0.0000      0.100
# 170               20               0.9      16     0.0001      0.100
# 171               20               0.9      16     1.0000      0.010
# 172               20               1.0     255     0.0100      0.100
# 173               20               0.9     255     0.0000      1.000
# 174               20               0.9     255     0.0001      1.000
# 175               50               1.0     102     1.0000      1.000
# 176               20               1.0      16     0.0001      0.010
# 177               50               1.0     102     0.1000      0.100
# 178               50               0.9      16     0.1000      0.000
# 179               50               1.0     255     0.0010      0.010
# 180               50               0.9     255     0.0010      0.100
# 181               50               1.0     102     1.0000      0.100
# 182               50               0.9     102     0.1000      0.001
# 183               50               1.0      16     0.0010      1.000
# 184               50               1.0     255     0.1000      0.010
# 185               50               0.9     255     0.1000      0.001
# 186               20               0.9     102     0.0100      0.000
# 187               50               0.9     255     1.0000      0.100
# 188               50               0.9      16     0.1000      0.001
# 189               50               1.0     255     0.0000      0.010
# 190               50               1.0     255     0.0001      0.010
# 191               50               0.9      16     0.0100      1.000
# 192               50               1.0      16     1.0000      0.100
# 193               50               0.9      16     0.0000      0.000
# 194               20               1.0     102     1.0000      0.100
# 195               20               0.9      16     0.1000      1.000
# 196               50               1.0     102     0.0010      0.000
# 197               50               1.0     102     0.0100      0.000
# 198               20               1.0     102     1.0000      1.000
# 199               20               0.9     102     0.0010      0.001
# 200               20               1.0      16     0.1000      1.000
# 201               50               0.9      16     0.1000      1.000
# 202               20               1.0     102     0.0000      1.000
# 203               20               1.0     102     0.0001      1.000
# 204               20               1.0     255     1.0000      0.010
# 205               20               0.9      16     0.1000      0.000
# 206               20               0.9     102     0.0100      0.001
# 207               20               1.0     255     0.0100      1.000
# 208               20               0.9      16     0.0000      0.010
# 209               20               0.9      16     0.0001      0.010
# 210               20               0.9     255     0.0010      1.000
# 211               20               0.9      16     1.0000      1.000
# 212               20               0.9     255     1.0000      1.000
# 213               20               0.9      16     1.0000      0.100
# 214               20               0.9      16     0.0100      0.010
# 215               50               0.9     255     1.0000      1.000
# 216               20               1.0     255     1.0000      1.000
# 217               50               1.0     102     0.0000      0.000
# 218               50               1.0     102     0.0001      0.000
# 219               50               0.9     255     0.0100      0.000
# 220               50               1.0     102     1.0000      0.010
# 221               20               0.9      16     0.0000      0.000
# 222               20               0.9      16     0.0001      0.000
# 223               50               0.9     255     0.0100      0.001
# 224               50               0.9     255     0.0010      1.000
# 225               50               0.9      16     0.0100      0.001
# 226               20               1.0     255     0.0010      1.000
# 227               20               1.0     102     0.0010      0.010
# 228               50               0.9      16     0.0000      0.100
# 229               50               0.9      16     0.0001      0.100
# 230               20               1.0     255     0.0010      0.000
# 231               20               1.0      16     1.0000      0.010
# 232               50               1.0      16     0.0100      1.000
# 233               50               0.9     255     0.0000      1.000
# 234               50               0.9     255     0.0001      1.000
# 235               20               1.0      16     0.1000      0.010
# 236               20               1.0      16     1.0000      1.000
# 237               50               0.9     102     0.0000      0.001
# 238               50               0.9     102     0.0001      0.001
# 239               20               1.0     102     0.1000      0.010
# 240               20               1.0     255     0.1000      0.000
# 241               20               0.9     102     0.0010      0.000
# 242               50               0.9      16     0.0010      0.100
# 243               20               1.0      16     1.0000      0.000
# 244               20               1.0     102     0.0100      0.000
# 245               50               1.0     102     0.0010      0.100
# 246               50               1.0     102     0.0100      0.001
# 247               50               1.0     102     0.0010      0.010
# 248               20               1.0     255     0.0000      0.001
# 249               20               1.0     255     0.0001      0.001
# 250               20               1.0     102     0.1000      0.000
# 251               50               1.0     102     1.0000      0.000
# 252               20               0.9      16     0.0010      0.100
# 253               20               0.9      16     0.1000      0.001
# 254               20               0.9      16     1.0000      0.001
# 255               50               1.0     102     0.0000      0.010
# 256               20               1.0     102     0.0001      0.010
# 257               50               1.0     102     0.0001      0.100
# 258               20               1.0     255     1.0000      0.100
# 259               50               1.0     255     0.1000      0.000
# 260               20               1.0     255     0.0000      0.000
# 261               20               1.0     255     0.0001      0.000
# 262               20               1.0     255     0.0010      0.100
# 263               50               0.9     255     0.0000      0.010
# 264               50               0.9     255     0.0001      0.010
# 265               50               1.0      16     0.1000      1.000
# 266               50               1.0     255     0.0000      0.000
# 267               20               1.0     255     0.0010      0.001
# 268               50               1.0     102     0.0100      1.000
# 269               20               1.0     255     0.1000      1.000
# 270               50               0.9     102     0.0000      0.000
# 271               50               0.9     102     0.0001      0.000
# 272               50               1.0     102     0.0001      1.000
# 273               20               1.0     255     0.0000      0.100
# 274               20               1.0     255     0.0001      0.100
# 275               50               0.9      16     0.0100      0.000
# 276               20               1.0     255     0.0000      1.000
# 277               50               1.0     255     1.0000      1.000
# 278               50               1.0     102     0.0100      0.100
# 279               50               1.0     102     0.1000      0.010
# 280               50               0.9      16     0.0000      0.010
# 281               50               0.9      16     0.0001      0.010
# 282               50               1.0     255     0.0010      0.001
# 283               20               1.0     255     0.1000      0.001
# 284               20               1.0     255     1.0000      0.000
# 285               50               1.0      16     0.0000      1.000
# 286               50               1.0      16     0.0001      1.000
# 287               50               0.9     102     0.0010      0.000
# 288               20               1.0     255     0.0001      1.000
# 289               50               1.0      16     1.0000      1.000
# 290               50               0.9     255     0.0010      0.010
# 291               50               1.0     255     1.0000      0.100
# 292               20               1.0     102     0.0000      0.010
# 293               50               0.9      16     0.1000      0.100
# 294               50               1.0     102     0.0010      1.000
# 295               50               1.0     255     1.0000      0.010
# 296               20               1.0     255     0.1000      0.010
# 297               50               1.0     255     0.0100      1.000
# 298               50               1.0     255     0.0000      0.100
# 299               50               1.0     255     0.0001      0.100
# 300               50               1.0     102     1.0000      0.001
# 301               20               1.0     255     0.0100      0.001
# 302               50               1.0     255     0.0001      0.000
# 303               50               1.0     102     0.0001      0.010
# 304               20               1.0     255     0.0001      0.010
# 305               20               1.0     102     0.1000      0.100
# 306               50               1.0     255     0.0100      0.100
# 307               20               1.0     102     0.1000      0.001
# 308               20               0.9     255     0.1000      1.000
# 309               50               0.9      16     0.0010      0.010
# 310               20               1.0     255     0.0100      0.000
# 311               20               1.0     102     0.0010      1.000
# 312               50               1.0     102     0.0000      1.000
# 313               50               1.0     255     0.0010      0.100
# 314               50               1.0     255     0.0000      0.001
# 315               50               1.0     255     0.0001      0.001
# 316               50               1.0     102     0.1000      0.000
# 317               20               1.0     255     1.0000      0.001
# 318               20               0.9      16     0.0010      0.010
# 319               20               0.9      16     1.0000      0.000
# 320               20               1.0     255     0.1000      0.100
# 321               20               1.0     255     0.0000      0.010
# 322               20               1.0     102     0.0000      0.000
# 323               20               1.0     102     0.0001      0.000
# 324               20               1.0     102     0.0100      0.010
# 325               20               1.0     102     0.0100      1.000
# 326               50               1.0     255     1.0000      0.000
# 327               20               1.0     102     0.0000      0.100
# 328               20               1.0     102     0.0001      0.100
# 329               50               1.0     102     0.0000      0.100
# 330               50               1.0     255     0.0010      0.000
# 331               20               1.0     102     0.0010      0.001
# 332               20               1.0     102     0.0010      0.100
# 333               50               1.0     255     0.1000      0.001
# 334               20               1.0     255     0.0100      0.010
# 335               50               1.0     255     0.0100      0.001
# 336               20               1.0     255     0.0010      0.010
# 337               50               1.0     102     0.1000      1.000
# 338               50               1.0     102     0.0100      0.010
# 339               50               1.0     255     1.0000      0.001
# 340               50               0.9     255     0.0010      0.001
# 341               50               0.9      16     0.0010     10.000
# 342               50               1.0     255     0.1000      0.100
# 343               20               1.0     102     0.0100      0.001
# 344               50               1.0     255     0.1000      1.000
# 345               50               0.9     255     0.0000      0.001
# 346               50               0.9     255     0.0001      0.001
# 347               50               1.0     102     0.1000      0.001
# 348               50               1.0     255     0.0100      0.010
# 349               50               0.9     255     0.0010      0.000
# 350               20               1.0     102     0.0000      0.001
# 351               20               1.0     102     0.0001      0.001
# 352               20               1.0     102     0.0010      0.000
# 353               50               1.0     255     0.0010      1.000
# 354               20               1.0     102     0.1000      1.000
# 355               50               0.9     255     0.0000      0.000
# 356               50               0.9     255     0.0001      0.000
# 357               20               1.0     102     0.0100      0.100
# 358               50               1.0     255     0.0000      1.000
# 359               50               0.9      16     0.0100     10.000
# 360               50               0.9     102     0.1000     10.000
# 361               20               0.9      16     0.0001     10.000
# 362               20               0.9      16     0.0010     10.000
# 363               50               0.9      16     0.0000     10.000
# 364               50               0.9      16     0.0001     10.000
# 365               20               0.9      16     0.0100     10.000
# 366               20               0.9      16     0.0000     10.000
# 367               50               1.0     255     0.0100      0.000
# 368               50               0.9      16     0.1000     10.000
# 369               20               0.9      16     0.1000     10.000
# 370               50               1.0     255     0.0001      1.000
# 371               50               0.9     102     0.0001     10.000
# 372               50               0.9     102     0.0010     10.000
# 373               20               1.0     102     0.0100     10.000
# 374               50               0.9     102     0.0000     10.000
# 375               50               0.9     255     0.0100     10.000
# 376               20               0.9      16     1.0000     10.000
# 377               20               0.9     102     0.0010     10.000
# 378               50               0.9     255     1.0000     10.000
# 379               50               1.0     255     0.1000     10.000
# 380               20               0.9     102     0.0000     10.000
# 381               20               0.9     102     0.0001     10.000
# 382               50               1.0     255     0.0010     10.000
# 383               20               1.0     102     0.0010     10.000
# 384               50               1.0     102     0.0000     10.000
# 385               50               1.0     102     0.0001     10.000
# 386               50               0.9     102     0.0100     10.000
# 387               50               0.9     255     0.1000     10.000
# 388               20               0.9     102     1.0000     10.000
# 389               20               1.0      16     0.0100     10.000
# 390               50               1.0      16     0.0010     10.000
# 391               20               0.9     102     0.1000     10.000
# 392               50               1.0     255     0.0000     10.000
# 393               50               1.0     255     0.0001     10.000
# 394               20               1.0      16     0.1000     10.000
# 395               50               1.0     255     0.0100     10.000
# 396               20               1.0     255     0.0010     10.000
# 397               50               1.0      16     0.0000     10.000
# 398               50               1.0      16     0.0001     10.000
# 399               20               1.0     102     0.0000     10.000
# 400               20               1.0     102     0.0001     10.000
# 401               50               1.0     102     0.0010     10.000
# 402               20               0.9     102     0.0100     10.000
# 403               20               0.9     255     1.0000     10.000
# 404               20               1.0     255     0.0100     10.000
# 405               50               1.0      16     0.0100     10.000
# 406               20               1.0      16     0.0000     10.000
# 407               20               1.0      16     0.0001     10.000
# 408               50               1.0      16     0.1000     10.000
# 409               50               0.9      16     1.0000     10.000
# 410               20               1.0     255     0.0000     10.000
# 411               20               1.0     255     0.0001     10.000
# 412               50               0.9     255     0.0000     10.000
# 413               50               0.9     255     0.0001     10.000
# 414               50               1.0      16     1.0000     10.000
# 415               20               0.9     255     0.1000     10.000
# 416               50               1.0     102     1.0000     10.000
# 417               20               1.0      16     1.0000     10.000
# 418               50               1.0     102     0.0100     10.000
# 419               50               0.9     255     0.0010     10.000
# 420               50               1.0     255     1.0000     10.000
# 421               20               1.0     102     0.1000     10.000
# 422               50               1.0     102     0.1000     10.000
# 423               20               1.0      16     0.0010     10.000
# 424               20               0.9     255     0.0010     10.000
# 425               20               1.0     255     0.1000     10.000
# 426               20               0.9     255     0.0000     10.000
# 427               20               0.9     255     0.0001     10.000
# 428               20               1.0     255     1.0000     10.000
# 429               50               0.9     102     1.0000     10.000
# 430               20               1.0     102     1.0000     10.000
# 431               20               0.9     255     0.0100     10.000
#
#                                                model_0  \
# 0    LGBMClassifier(extra_trees=True, feature_fract...
# 1    LGBMClassifier(extra_trees=True, feature_fract...
# 2    LGBMClassifier(extra_trees=True, feature_fract...
# 3    LGBMClassifier(extra_trees=True, feature_fract...
# 4    LGBMClassifier(extra_trees=True, feature_fract...
# 5    LGBMClassifier(extra_trees=True, feature_fract...
# 6    LGBMClassifier(extra_trees=True, feature_fract...
# 7    LGBMClassifier(extra_trees=True, feature_fract...
# 8    LGBMClassifier(extra_trees=True, feature_fract...
# 9    LGBMClassifier(extra_trees=True, feature_fract...
# 10   LGBMClassifier(extra_trees=True, feature_fract...
# 11   LGBMClassifier(extra_trees=True, feature_fract...
# 12   LGBMClassifier(extra_trees=True, feature_fract...
# 13   LGBMClassifier(extra_trees=True, feature_fract...
# 14   LGBMClassifier(extra_trees=True, feature_fract...
# 15   LGBMClassifier(extra_trees=True, feature_fract...
# 16   LGBMClassifier(extra_trees=True, feature_fract...
# 17   LGBMClassifier(extra_trees=True, feature_fract...
# 18   LGBMClassifier(extra_trees=True, feature_fract...
# 19   LGBMClassifier(extra_trees=True, feature_fract...
# 20   LGBMClassifier(extra_trees=True, feature_fract...
# 21   LGBMClassifier(extra_trees=True, feature_fract...
# 22   LGBMClassifier(extra_trees=True, feature_fract...
# 23   LGBMClassifier(extra_trees=True, feature_fract...
# 24   LGBMClassifier(extra_trees=True, feature_fract...
# 25   LGBMClassifier(extra_trees=True, feature_fract...
# 26   LGBMClassifier(extra_trees=True, feature_fract...
# 27   LGBMClassifier(extra_trees=True, feature_fract...
# 28   LGBMClassifier(extra_trees=True, feature_fract...
# 29   LGBMClassifier(extra_trees=True, feature_fract...
# 30   LGBMClassifier(extra_trees=True, feature_fract...
# 31   LGBMClassifier(extra_trees=True, feature_fract...
# 32   LGBMClassifier(extra_trees=True, feature_fract...
# 33   LGBMClassifier(extra_trees=True, feature_fract...
# 34   LGBMClassifier(extra_trees=True, feature_fract...
# 35   LGBMClassifier(extra_trees=True, feature_fract...
# 36   LGBMClassifier(extra_trees=True, feature_fract...
# 37   LGBMClassifier(extra_trees=True, feature_fract...
# 38   LGBMClassifier(extra_trees=True, feature_fract...
# 39   LGBMClassifier(extra_trees=True, feature_fract...
# 40   LGBMClassifier(extra_trees=True, feature_fract...
# 41   LGBMClassifier(extra_trees=True, feature_fract...
# 42   LGBMClassifier(extra_trees=True, feature_fract...
# 43   LGBMClassifier(extra_trees=True, feature_fract...
# 44   LGBMClassifier(extra_trees=True, feature_fract...
# 45   LGBMClassifier(extra_trees=True, feature_fract...
# 46   LGBMClassifier(extra_trees=True, feature_fract...
# 47   LGBMClassifier(extra_trees=True, feature_fract...
# 48   LGBMClassifier(extra_trees=True, feature_fract...
# 49   LGBMClassifier(extra_trees=True, feature_fract...
# 50   LGBMClassifier(extra_trees=True, feature_fract...
# 51   LGBMClassifier(extra_trees=True, feature_fract...
# 52   LGBMClassifier(extra_trees=True, feature_fract...
# 53   LGBMClassifier(extra_trees=True, feature_fract...
# 54   LGBMClassifier(extra_trees=True, feature_fract...
# 55   LGBMClassifier(extra_trees=True, feature_fract...
# 56   LGBMClassifier(extra_trees=True, feature_fract...
# 57   LGBMClassifier(extra_trees=True, feature_fract...
# 58   LGBMClassifier(extra_trees=True, feature_fract...
# 59   LGBMClassifier(extra_trees=True, feature_fract...
# 60   LGBMClassifier(extra_trees=True, feature_fract...
# 61   LGBMClassifier(extra_trees=True, feature_fract...
# 62   LGBMClassifier(extra_trees=True, feature_fract...
# 63   LGBMClassifier(extra_trees=True, feature_fract...
# 64   LGBMClassifier(extra_trees=True, feature_fract...
# 65   LGBMClassifier(extra_trees=True, feature_fract...
# 66   LGBMClassifier(extra_trees=True, feature_fract...
# 67   LGBMClassifier(extra_trees=True, feature_fract...
# 68   LGBMClassifier(extra_trees=True, feature_fract...
# 69   LGBMClassifier(extra_trees=True, feature_fract...
# 70   LGBMClassifier(extra_trees=True, feature_fract...
# 71   LGBMClassifier(extra_trees=True, feature_fract...
# 72   LGBMClassifier(extra_trees=True, feature_fract...
# 73   LGBMClassifier(extra_trees=True, feature_fract...
# 74   LGBMClassifier(extra_trees=True, feature_fract...
# 75   LGBMClassifier(extra_trees=True, feature_fract...
# 76   LGBMClassifier(extra_trees=True, feature_fract...
# 77   LGBMClassifier(extra_trees=True, feature_fract...
# 78   LGBMClassifier(extra_trees=True, feature_fract...
# 79   LGBMClassifier(extra_trees=True, feature_fract...
# 80   LGBMClassifier(extra_trees=True, feature_fract...
# 81   LGBMClassifier(extra_trees=True, feature_fract...
# 82   LGBMClassifier(extra_trees=True, feature_fract...
# 83   LGBMClassifier(extra_trees=True, feature_fract...
# 84   LGBMClassifier(extra_trees=True, feature_fract...
# 85   LGBMClassifier(extra_trees=True, feature_fract...
# 86   LGBMClassifier(extra_trees=True, feature_fract...
# 87   LGBMClassifier(extra_trees=True, feature_fract...
# 88   LGBMClassifier(extra_trees=True, feature_fract...
# 89   LGBMClassifier(extra_trees=True, feature_fract...
# 90   LGBMClassifier(extra_trees=True, feature_fract...
# 91   LGBMClassifier(extra_trees=True, feature_fract...
# 92   LGBMClassifier(extra_trees=True, feature_fract...
# 93   LGBMClassifier(extra_trees=True, feature_fract...
# 94   LGBMClassifier(extra_trees=True, feature_fract...
# 95   LGBMClassifier(extra_trees=True, feature_fract...
# 96   LGBMClassifier(extra_trees=True, feature_fract...
# 97   LGBMClassifier(extra_trees=True, feature_fract...
# 98   LGBMClassifier(extra_trees=True, feature_fract...
# 99   LGBMClassifier(extra_trees=True, feature_fract...
# 100  LGBMClassifier(extra_trees=True, feature_fract...
# 101  LGBMClassifier(extra_trees=True, feature_fract...
# 102  LGBMClassifier(extra_trees=True, feature_fract...
# 103  LGBMClassifier(extra_trees=True, feature_fract...
# 104  LGBMClassifier(extra_trees=True, feature_fract...
# 105  LGBMClassifier(extra_trees=True, feature_fract...
# 106  LGBMClassifier(extra_trees=True, feature_fract...
# 107  LGBMClassifier(extra_trees=True, feature_fract...
# 108  LGBMClassifier(extra_trees=True, feature_fract...
# 109  LGBMClassifier(extra_trees=True, feature_fract...
# 110  LGBMClassifier(extra_trees=True, feature_fract...
# 111  LGBMClassifier(extra_trees=True, feature_fract...
# 112  LGBMClassifier(extra_trees=True, feature_fract...
# 113  LGBMClassifier(extra_trees=True, feature_fract...
# 114  LGBMClassifier(extra_trees=True, feature_fract...
# 115  LGBMClassifier(extra_trees=True, feature_fract...
# 116  LGBMClassifier(extra_trees=True, feature_fract...
# 117  LGBMClassifier(extra_trees=True, feature_fract...
# 118  LGBMClassifier(extra_trees=True, feature_fract...
# 119  LGBMClassifier(extra_trees=True, feature_fract...
# 120  LGBMClassifier(extra_trees=True, feature_fract...
# 121  LGBMClassifier(extra_trees=True, feature_fract...
# 122  LGBMClassifier(extra_trees=True, feature_fract...
# 123  LGBMClassifier(extra_trees=True, feature_fract...
# 124  LGBMClassifier(extra_trees=True, feature_fract...
# 125  LGBMClassifier(extra_trees=True, feature_fract...
# 126  LGBMClassifier(extra_trees=True, feature_fract...
# 127  LGBMClassifier(extra_trees=True, feature_fract...
# 128  LGBMClassifier(extra_trees=True, feature_fract...
# 129  LGBMClassifier(extra_trees=True, feature_fract...
# 130  LGBMClassifier(extra_trees=True, feature_fract...
# 131  LGBMClassifier(extra_trees=True, feature_fract...
# 132  LGBMClassifier(extra_trees=True, feature_fract...
# 133  LGBMClassifier(extra_trees=True, feature_fract...
# 134  LGBMClassifier(extra_trees=True, feature_fract...
# 135  LGBMClassifier(extra_trees=True, feature_fract...
# 136  LGBMClassifier(extra_trees=True, feature_fract...
# 137  LGBMClassifier(extra_trees=True, feature_fract...
# 138  LGBMClassifier(extra_trees=True, feature_fract...
# 139  LGBMClassifier(extra_trees=True, feature_fract...
# 140  LGBMClassifier(extra_trees=True, feature_fract...
# 141  LGBMClassifier(extra_trees=True, feature_fract...
# 142  LGBMClassifier(extra_trees=True, feature_fract...
# 143  LGBMClassifier(extra_trees=True, feature_fract...
# 144  LGBMClassifier(extra_trees=True, feature_fract...
# 145  LGBMClassifier(extra_trees=True, feature_fract...
# 146  LGBMClassifier(extra_trees=True, feature_fract...
# 147  LGBMClassifier(extra_trees=True, feature_fract...
# 148  LGBMClassifier(extra_trees=True, feature_fract...
# 149  LGBMClassifier(extra_trees=True, feature_fract...
# 150  LGBMClassifier(extra_trees=True, feature_fract...
# 151  LGBMClassifier(extra_trees=True, feature_fract...
# 152  LGBMClassifier(extra_trees=True, feature_fract...
# 153  LGBMClassifier(extra_trees=True, feature_fract...
# 154  LGBMClassifier(extra_trees=True, feature_fract...
# 155  LGBMClassifier(extra_trees=True, feature_fract...
# 156  LGBMClassifier(extra_trees=True, feature_fract...
# 157  LGBMClassifier(extra_trees=True, feature_fract...
# 158  LGBMClassifier(extra_trees=True, feature_fract...
# 159  LGBMClassifier(extra_trees=True, feature_fract...
# 160  LGBMClassifier(extra_trees=True, feature_fract...
# 161  LGBMClassifier(extra_trees=True, feature_fract...
# 162  LGBMClassifier(extra_trees=True, feature_fract...
# 163  LGBMClassifier(extra_trees=True, feature_fract...
# 164  LGBMClassifier(extra_trees=True, feature_fract...
# 165  LGBMClassifier(extra_trees=True, feature_fract...
# 166  LGBMClassifier(extra_trees=True, feature_fract...
# 167  LGBMClassifier(extra_trees=True, feature_fract...
# 168  LGBMClassifier(extra_trees=True, feature_fract...
# 169  LGBMClassifier(extra_trees=True, feature_fract...
# 170  LGBMClassifier(extra_trees=True, feature_fract...
# 171  LGBMClassifier(extra_trees=True, feature_fract...
# 172  LGBMClassifier(extra_trees=True, feature_fract...
# 173  LGBMClassifier(extra_trees=True, feature_fract...
# 174  LGBMClassifier(extra_trees=True, feature_fract...
# 175  LGBMClassifier(extra_trees=True, feature_fract...
# 176  LGBMClassifier(extra_trees=True, feature_fract...
# 177  LGBMClassifier(extra_trees=True, feature_fract...
# 178  LGBMClassifier(extra_trees=True, feature_fract...
# 179  LGBMClassifier(extra_trees=True, feature_fract...
# 180  LGBMClassifier(extra_trees=True, feature_fract...
# 181  LGBMClassifier(extra_trees=True, feature_fract...
# 182  LGBMClassifier(extra_trees=True, feature_fract...
# 183  LGBMClassifier(extra_trees=True, feature_fract...
# 184  LGBMClassifier(extra_trees=True, feature_fract...
# 185  LGBMClassifier(extra_trees=True, feature_fract...
# 186  LGBMClassifier(extra_trees=True, feature_fract...
# 187  LGBMClassifier(extra_trees=True, feature_fract...
# 188  LGBMClassifier(extra_trees=True, feature_fract...
# 189  LGBMClassifier(extra_trees=True, feature_fract...
# 190  LGBMClassifier(extra_trees=True, feature_fract...
# 191  LGBMClassifier(extra_trees=True, feature_fract...
# 192  LGBMClassifier(extra_trees=True, feature_fract...
# 193  LGBMClassifier(extra_trees=True, feature_fract...
# 194  LGBMClassifier(extra_trees=True, feature_fract...
# 195  LGBMClassifier(extra_trees=True, feature_fract...
# 196  LGBMClassifier(extra_trees=True, feature_fract...
# 197  LGBMClassifier(extra_trees=True, feature_fract...
# 198  LGBMClassifier(extra_trees=True, feature_fract...
# 199  LGBMClassifier(extra_trees=True, feature_fract...
# 200  LGBMClassifier(extra_trees=True, feature_fract...
# 201  LGBMClassifier(extra_trees=True, feature_fract...
# 202  LGBMClassifier(extra_trees=True, feature_fract...
# 203  LGBMClassifier(extra_trees=True, feature_fract...
# 204  LGBMClassifier(extra_trees=True, feature_fract...
# 205  LGBMClassifier(extra_trees=True, feature_fract...
# 206  LGBMClassifier(extra_trees=True, feature_fract...
# 207  LGBMClassifier(extra_trees=True, feature_fract...
# 208  LGBMClassifier(extra_trees=True, feature_fract...
# 209  LGBMClassifier(extra_trees=True, feature_fract...
# 210  LGBMClassifier(extra_trees=True, feature_fract...
# 211  LGBMClassifier(extra_trees=True, feature_fract...
# 212  LGBMClassifier(extra_trees=True, feature_fract...
# 213  LGBMClassifier(extra_trees=True, feature_fract...
# 214  LGBMClassifier(extra_trees=True, feature_fract...
# 215  LGBMClassifier(extra_trees=True, feature_fract...
# 216  LGBMClassifier(extra_trees=True, feature_fract...
# 217  LGBMClassifier(extra_trees=True, feature_fract...
# 218  LGBMClassifier(extra_trees=True, feature_fract...
# 219  LGBMClassifier(extra_trees=True, feature_fract...
# 220  LGBMClassifier(extra_trees=True, feature_fract...
# 221  LGBMClassifier(extra_trees=True, feature_fract...
# 222  LGBMClassifier(extra_trees=True, feature_fract...
# 223  LGBMClassifier(extra_trees=True, feature_fract...
# 224  LGBMClassifier(extra_trees=True, feature_fract...
# 225  LGBMClassifier(extra_trees=True, feature_fract...
# 226  LGBMClassifier(extra_trees=True, feature_fract...
# 227  LGBMClassifier(extra_trees=True, feature_fract...
# 228  LGBMClassifier(extra_trees=True, feature_fract...
# 229  LGBMClassifier(extra_trees=True, feature_fract...
# 230  LGBMClassifier(extra_trees=True, feature_fract...
# 231  LGBMClassifier(extra_trees=True, feature_fract...
# 232  LGBMClassifier(extra_trees=True, feature_fract...
# 233  LGBMClassifier(extra_trees=True, feature_fract...
# 234  LGBMClassifier(extra_trees=True, feature_fract...
# 235  LGBMClassifier(extra_trees=True, feature_fract...
# 236  LGBMClassifier(extra_trees=True, feature_fract...
# 237  LGBMClassifier(extra_trees=True, feature_fract...
# 238  LGBMClassifier(extra_trees=True, feature_fract...
# 239  LGBMClassifier(extra_trees=True, feature_fract...
# 240  LGBMClassifier(extra_trees=True, feature_fract...
# 241  LGBMClassifier(extra_trees=True, feature_fract...
# 242  LGBMClassifier(extra_trees=True, feature_fract...
# 243  LGBMClassifier(extra_trees=True, feature_fract...
# 244  LGBMClassifier(extra_trees=True, feature_fract...
# 245  LGBMClassifier(extra_trees=True, feature_fract...
# 246  LGBMClassifier(extra_trees=True, feature_fract...
# 247  LGBMClassifier(extra_trees=True, feature_fract...
# 248  LGBMClassifier(extra_trees=True, feature_fract...
# 249  LGBMClassifier(extra_trees=True, feature_fract...
# 250  LGBMClassifier(extra_trees=True, feature_fract...
# 251  LGBMClassifier(extra_trees=True, feature_fract...
# 252  LGBMClassifier(extra_trees=True, feature_fract...
# 253  LGBMClassifier(extra_trees=True, feature_fract...
# 254  LGBMClassifier(extra_trees=True, feature_fract...
# 255  LGBMClassifier(extra_trees=True, feature_fract...
# 256  LGBMClassifier(extra_trees=True, feature_fract...
# 257  LGBMClassifier(extra_trees=True, feature_fract...
# 258  LGBMClassifier(extra_trees=True, feature_fract...
# 259  LGBMClassifier(extra_trees=True, feature_fract...
# 260  LGBMClassifier(extra_trees=True, feature_fract...
# 261  LGBMClassifier(extra_trees=True, feature_fract...
# 262  LGBMClassifier(extra_trees=True, feature_fract...
# 263  LGBMClassifier(extra_trees=True, feature_fract...
# 264  LGBMClassifier(extra_trees=True, feature_fract...
# 265  LGBMClassifier(extra_trees=True, feature_fract...
# 266  LGBMClassifier(extra_trees=True, feature_fract...
# 267  LGBMClassifier(extra_trees=True, feature_fract...
# 268  LGBMClassifier(extra_trees=True, feature_fract...
# 269  LGBMClassifier(extra_trees=True, feature_fract...
# 270  LGBMClassifier(extra_trees=True, feature_fract...
# 271  LGBMClassifier(extra_trees=True, feature_fract...
# 272  LGBMClassifier(extra_trees=True, feature_fract...
# 273  LGBMClassifier(extra_trees=True, feature_fract...
# 274  LGBMClassifier(extra_trees=True, feature_fract...
# 275  LGBMClassifier(extra_trees=True, feature_fract...
# 276  LGBMClassifier(extra_trees=True, feature_fract...
# 277  LGBMClassifier(extra_trees=True, feature_fract...
# 278  LGBMClassifier(extra_trees=True, feature_fract...
# 279  LGBMClassifier(extra_trees=True, feature_fract...
# 280  LGBMClassifier(extra_trees=True, feature_fract...
# 281  LGBMClassifier(extra_trees=True, feature_fract...
# 282  LGBMClassifier(extra_trees=True, feature_fract...
# 283  LGBMClassifier(extra_trees=True, feature_fract...
# 284  LGBMClassifier(extra_trees=True, feature_fract...
# 285  LGBMClassifier(extra_trees=True, feature_fract...
# 286  LGBMClassifier(extra_trees=True, feature_fract...
# 287  LGBMClassifier(extra_trees=True, feature_fract...
# 288  LGBMClassifier(extra_trees=True, feature_fract...
# ...
# 207     0.519237     0.523206     0.523035     0.514607     0.520171
# 208     0.518931     0.523144     0.521161     0.514407     0.520155
# 209     0.518931     0.523144     0.521161     0.514407     0.520155
# 210     0.517083     0.522976     0.525719     0.512494     0.520154
# 211     0.520912     0.521801     0.521305     0.512359     0.520149
# 212     0.518407     0.522478     0.524693     0.512317     0.520137
# 213     0.518749     0.523501     0.521335     0.513749     0.520120
# 214     0.519076     0.522131     0.522153     0.513720     0.520110
# 215     0.517039     0.525350     0.522849     0.512450     0.520105
# 216     0.519368     0.523910     0.521880     0.514987     0.520102
# 217     0.519766     0.523539     0.522911     0.513253     0.520102
# 218     0.519766     0.523539     0.522911     0.513253     0.520102
# 219     0.517103     0.522986     0.526221     0.511963     0.520099
# 220     0.519906     0.523018     0.522762     0.514127     0.520094
# 221     0.519106     0.523490     0.519483     0.514588     0.520089
# 222     0.519106     0.523490     0.519483     0.514588     0.520089
# 223     0.517103     0.522986     0.526389     0.511963     0.520065
# 224     0.516917     0.522819     0.525385     0.512793     0.520050
# 225     0.519599     0.522998     0.520846     0.514084     0.520050
# 226     0.519719     0.522890     0.522999     0.514962     0.520042
# 227     0.519884     0.522169     0.521569     0.514064     0.520040
# 228     0.520945     0.523154     0.521501     0.513070     0.520036
# 229     0.520945     0.523154     0.521501     0.513070     0.520036
# 230     0.520225     0.521844     0.523563     0.513356     0.520035
# 231     0.520634     0.523380     0.524531     0.512133     0.520027
# 232     0.519803     0.524965     0.523387     0.512555     0.520022
# 233     0.516566     0.522819     0.525385     0.513126     0.520020
# 234     0.516566     0.522819     0.525385     0.513126     0.520020
# 235     0.518606     0.523562     0.522181     0.513157     0.520016
# 236     0.519390     0.523064     0.522599     0.514383     0.520015
# 237     0.517924     0.522142     0.524711     0.513533     0.520009
# 238     0.517924     0.522142     0.524711     0.513533     0.520009
# 239     0.519698     0.522851     0.522546     0.514229     0.520009
# 240     0.519543     0.523025     0.522383     0.513380     0.520001
# 241     0.517924     0.522142     0.525904     0.511986     0.520000
# 242     0.519746     0.523154     0.521501     0.514077     0.519998
# 243     0.520471     0.523230     0.524520     0.512296     0.519995
# 244     0.518873     0.523191     0.522559     0.514736     0.519988
# 245     0.519085     0.523706     0.523187     0.513746     0.519982
# 246     0.519578     0.522367     0.523074     0.513621     0.519976
# 247     0.519930     0.522699     0.523224     0.512937     0.519974
# 248     0.520225     0.521844     0.523563     0.513356     0.519964
# 249     0.520225     0.521844     0.523563     0.513356     0.519964
# 250     0.519203     0.522002     0.522872     0.514064     0.519963
# 251     0.519543     0.523525     0.522735     0.512816     0.519962
# 252     0.519083     0.523668     0.521660     0.513026     0.519948
# 253     0.519592     0.521969     0.521668     0.513215     0.519947
# 254     0.518582     0.523836     0.522508     0.512208     0.519947
# 255     0.519589     0.522707     0.523387     0.512937     0.519940
# 256     0.519368     0.522169     0.521569     0.514064     0.519936
# 257     0.519097     0.523706     0.523199     0.513746     0.519923
# 258     0.519708     0.523358     0.522872     0.514784     0.519908
# 259     0.521257     0.524893     0.521229     0.512648     0.519908
# 260     0.520225     0.521844     0.523224     0.513356     0.519903
# 261     0.520225     0.521844     0.523224     0.513356     0.519903
# 262     0.519533     0.522525     0.521365     0.514394     0.519901
# 263     0.517924     0.522149     0.525196     0.511466     0.519884
# 264     0.517924     0.522149     0.525196     0.511466     0.519884
# 265     0.519640     0.524401     0.524543     0.512707     0.519878
# 266     0.519754     0.523413     0.522057     0.513950     0.519866
# 267     0.520390     0.521844     0.522898     0.513356     0.519864
# 268     0.518697     0.522384     0.522860     0.514318     0.519857
# 269     0.519413     0.522858     0.523224     0.514291     0.519856
# 270     0.516771     0.522142     0.525045     0.513533     0.519846
# 271     0.516771     0.522142     0.525045     0.513533     0.519846
# 272     0.519401     0.523753     0.521894     0.514304     0.519844
# 273     0.519533     0.522525     0.521378     0.513887     0.519835
# 274     0.519533     0.522525     0.521378     0.513887     0.519835
# 275     0.519432     0.522998     0.520846     0.513589     0.519817
# 276     0.520225     0.521896     0.522332     0.514962     0.519811
# 277     0.519843     0.523276     0.521759     0.514304     0.519803
# 278     0.519754     0.522525     0.523738     0.513129     0.519803
# 279     0.519918     0.522525     0.521081     0.514101     0.519802
# 280     0.520417     0.522142     0.520339     0.513573     0.519800
# 281     0.520417     0.522142     0.520339     0.513573     0.519800
# 282     0.519237     0.523073     0.521731     0.514266     0.519793
# 283     0.519543     0.522517     0.522383     0.512803     0.519784
# 284     0.519061     0.522707     0.523211     0.514443     0.519783
# 285     0.519967     0.523728     0.522546     0.512200     0.519783
# 286     0.519967     0.523728     0.522546     0.512200     0.519783
# 287     0.516771     0.522142     0.524711     0.513533     0.519779
# 288     0.520049     0.521896     0.522332     0.514962     0.519776
# 289     0.520987     0.521887     0.522898     0.512816     0.519755
# 290     0.517269     0.522149     0.525196     0.511466     0.519754
# 291     0.517735     0.523276     0.523726     0.513976     0.519745
# 292     0.519368     0.522169     0.521569     0.514064     0.519739
# 293     0.520423     0.521821     0.520496     0.513398     0.519733
# 294     0.518862     0.523686     0.521894     0.514318     0.519725
# 295     0.519401     0.522917     0.523865     0.513129     0.519722
# 296     0.520204     0.522691     0.522383     0.512483     0.519719
# 297     0.519730     0.521566     0.522898     0.515316     0.519711
# 298     0.519578     0.524068     0.520890     0.513293     0.519707
# 299     0.519578     0.524068     0.520890     0.513293     0.519707
# 300     0.519578     0.522858     0.522070     0.512816     0.519702
# 301     0.519049     0.522343     0.522520     0.514394     0.519696
# 302     0.519237     0.523073     0.522057     0.513950     0.519694
# 303     0.519589     0.522707     0.522057     0.512937     0.519674
# 304     0.519884     0.522010     0.520700     0.514052     0.519664
# 305     0.519203     0.522336     0.521352     0.513430     0.519660
# 306     0.520247     0.523101     0.521731     0.513950     0.519640
# 307     0.518873     0.522510     0.521908     0.513227     0.519638
# 308     0.517740     0.522971     0.524185     0.511123     0.519635
# 309     0.520075     0.522142     0.520339     0.513573     0.519632
# 310     0.520565     0.522343     0.521339     0.513368     0.519622
# 311     0.519863     0.522329     0.523035     0.513323     0.519612
# 312     0.520214     0.521731     0.521894     0.514304     0.519602
# 313     0.519578     0.523872     0.520890     0.513293     0.519600
# 314     0.519237     0.523413     0.521731     0.513430     0.519593
# 315     0.519237     0.523413     0.521731     0.513430     0.519593
# 316     0.519425     0.523040     0.522030     0.512582     0.519585
# 317     0.519061     0.522707     0.522194     0.514443     0.519580
# 318     0.518931     0.523144     0.520155     0.512520     0.519576
# 319     0.518582     0.522819     0.521660     0.512208     0.519574
# 320     0.519390     0.522192     0.521718     0.513380     0.519574
# 321     0.519884     0.522010     0.520700     0.514052     0.519561
# 322     0.518544     0.522517     0.521854     0.513887     0.519560
# 323     0.518544     0.522517     0.521854     0.513887     0.519560
# 324     0.519038     0.522169     0.521867     0.512378     0.519557
# 325     0.518027     0.523866     0.522383     0.513635     0.519549
# 326     0.520060     0.522567     0.522233     0.512353     0.519538
# 327     0.518709     0.522851     0.522194     0.513569     0.519538
# 328     0.518709     0.522851     0.522194     0.513569     0.519538
# 329     0.519097     0.523706     0.521229     0.513746     0.519529
# 330     0.519237     0.523073     0.521731     0.513430     0.519525
# 331     0.518356     0.522851     0.521718     0.513545     0.519503
# 332     0.518709     0.522851     0.522194     0.513392     0.519502
# 333     0.519602     0.523413     0.521392     0.512648     0.519481
# 334     0.519214     0.522851     0.520388     0.514229     0.519474
# 335     0.519578     0.522586     0.521745     0.513785     0.519467
# 336     0.519543     0.522851     0.520700     0.514052     0.519464
# 337     0.519249     0.523191     0.521053     0.513014     0.519442
# 338     0.519754     0.522699     0.522924     0.512118     0.519437
# 339     0.520060     0.522567     0.522233     0.512353     0.519435
# 340     0.516947     0.523154     0.526389     0.510780     0.519431
# 341     0.518503     0.522310     0.519403     0.510824     0.519430
# 342     0.519742     0.522771     0.520537     0.513963     0.519408
# 343     0.518556     0.522192     0.521894     0.513722     0.519382
# 344     0.518720     0.522062     0.522247     0.513976     0.519368
# 345     0.516947     0.523154     0.526221     0.510780     0.519362
# 346     0.516947     0.523154     0.526221     0.510780     0.519362
# 347     0.518417     0.522201     0.521435     0.513936     0.519361
# 348     0.518921     0.523248     0.521731     0.513759     0.519334
# 349     0.516761     0.523154     0.526221     0.510780     0.519324
# 350     0.518544     0.522343     0.521718     0.512543     0.519303
# 351     0.518544     0.522343     0.521718     0.512543     0.519303
# 352     0.518544     0.522343     0.521718     0.512543     0.519303
# 353     0.518556     0.522043     0.521053     0.514456     0.519295
# 354     0.519249     0.521995     0.522169     0.513323     0.519281
# 355     0.516595     0.522986     0.526221     0.510780     0.519258
# 356     0.516595     0.522986     0.526221     0.510780     0.519258
# 357     0.519049     0.522510     0.520876     0.513227     0.519174
# 358     0.518556     0.521566     0.522572     0.514456     0.519139
# 359     0.518334     0.522120     0.519410     0.510497     0.519123
# 360     0.518156     0.518598     0.522488     0.511881     0.519047
# 361     0.518503     0.521634     0.520937     0.509633     0.519025
# 362     0.518672     0.521634     0.520937     0.509633     0.519024
# 363     0.518503     0.520945     0.519236     0.510824     0.519023
# 364     0.518503     0.520945     0.519236     0.510824     0.519023
# 365     0.518668     0.520449     0.520943     0.510471     0.518991
# 366     0.518334     0.521634     0.520937     0.509633     0.518991
# 367     0.519578     0.521556     0.521745     0.512431     0.518990
# 368     0.519184     0.521789     0.518407     0.510312     0.518897
# 369     0.518846     0.520791     0.520274     0.510153     0.518868
# 370     0.518556     0.521566     0.520890     0.514456     0.518803
# 371     0.518503     0.518274     0.521646     0.512879     0.518781
# 372     0.518503     0.518274     0.521646     0.512879     0.518781
# 373     0.519298     0.518004     0.521936     0.513266     0.518655
# 374     0.518503     0.518274     0.521646     0.511881     0.518582
# 375     0.518665     0.518598     0.520994     0.513598     0.518559
# 376     0.517991     0.521118     0.519424     0.508777     0.518510
# 377     0.517809     0.518765     0.521479     0.511512     0.518459
# 378     0.517141     0.518248     0.522690     0.512049     0.518444
# 379     0.518616     0.519181     0.521854     0.513203     0.518431
# 380     0.517809     0.518765     0.521479     0.511344     0.518426
# 381     0.517809     0.518765     0.521479     0.511344     0.518426
# 382     0.519115     0.519016     0.521202     0.512848     0.518399
# 383     0.518469     0.518334     0.520302     0.512837     0.518337
# 384     0.518440     0.518521     0.520483     0.512609     0.518325
# 385     0.518440     0.518521     0.520483     0.512609     0.518325
# 386     0.517643     0.518265     0.522321     0.512560     0.518317
# 387     0.517470     0.517573     0.522349     0.512560     0.518310
# 388     0.517310     0.517259     0.520671     0.512543     0.518309
# 389     0.516741     0.522351     0.518557     0.514273     0.518297
# 390     0.517740     0.520638     0.518103     0.514568     0.518287
# 391     0.518152     0.518773     0.520971     0.512049     0.518238
# 392     0.518948     0.519006     0.520551     0.512848     0.518234
# 393     0.518948     0.519006     0.520551     0.512848     0.518234
# 394     0.516898     0.520313     0.516564     0.515369     0.518222
# 395     0.518274     0.519027     0.521583     0.513368     0.518210
# 396     0.518118     0.518851     0.521450     0.510627     0.518196
# 397     0.517740     0.519797     0.518103     0.514909     0.518187
# 398     0.517740     0.519797     0.518103     0.514909     0.518187
# 399     0.518469     0.518334     0.520302     0.512837     0.518172
# 400     0.518469     0.518334     0.520302     0.512837     0.518172
# 401     0.518440     0.518521     0.518351     0.513976     0.518172
# 402     0.517292     0.518440     0.521153     0.511680     0.518122
# 403     0.516798     0.517591     0.521131     0.513544     0.518099
# 404     0.518782     0.518851     0.521894     0.510284     0.518081
# 405     0.517915     0.521321     0.517736     0.514746     0.518029
# 406     0.517240     0.521012     0.516905     0.514242     0.518025
# 407     0.517240     0.521012     0.516905     0.514242     0.518025
# 408     0.516399     0.521995     0.517479     0.514879     0.518007
# 409     0.517320     0.519290     0.520267     0.509298     0.517982
# 410     0.518118     0.518851     0.521450     0.510627     0.517957
# 411     0.518118     0.518851     0.521450     0.510627     0.517957
# 412     0.517809     0.517582     0.522508     0.512568     0.517948
# 413     0.517809     0.517582     0.522508     0.512568     0.517948
# 414     0.516275     0.520313     0.519073     0.514095     0.517944
# 415     0.517991     0.517600     0.521319     0.511000     0.517932
# 416     0.519142     0.518709     0.520999     0.510514     0.517930
# 417     0.516751     0.519990     0.518241     0.515043     0.517926
# 418     0.518432     0.518356     0.520904     0.512023     0.517897
# 419     0.517470     0.517582     0.522508     0.512568     0.517880
# 420     0.518459     0.519368     0.519222     0.511490     0.517865
# 421     0.518800     0.518345     0.518639     0.513443     0.517864
# 422     0.518274     0.518345     0.519045     0.513457     0.517852
# 423     0.516907     0.521012     0.516905     0.514079     0.517832
# 424     0.516784     0.517231     0.520971     0.511176     0.517682
# 425     0.517444     0.519192     0.518707     0.511821     0.517620
# 426     0.516784     0.517231     0.520456     0.511176     0.517579
# 427     0.516784     0.517231     0.520456     0.511176     0.517579
# 428     0.518415     0.518510     0.519529     0.510487     0.517513
# 429     0.517315     0.517740     0.519648     0.510516     0.517460
# 430     0.518469     0.517345     0.518817     0.510957     0.517343
# 431     0.516788     0.517113     0.519123     0.511185     0.517196

# %%
pd.set_option('display.max_row', 10)

# %%
from sklearn.metrics import classification_report, f1_score, confusion_matrix, precision_score, matthews_corrcoef

def predict(X, mode='best_mean'):
    if mode == 'best_mode':
        y_preds = []
        for i in range(K):
            y_preds.append(df_model.loc[0, f'model_{i}'].predict(X))
        y_preds = np.array(y_preds)
        y_preds = scipy.stats.mode(y_preds)
        y_preds = y_preds[0]
        y_preds = y_preds.reshape(-1)
    elif mode == 'best_mean':
        y_preds = []
        for i in range(K):
            y_preds.append(df_model.loc[0, f'model_{i}'].predict_proba(X))
        y_preds = np.mean(np.array(y_preds), axis=0)
        y_preds = np.argmax(y_preds, axis=-1)
    elif mode == 'ensemble_mode':
        y_preds = []
        for i in df_model.index:
            for j in range(K):
                y_preds.append(df_model.loc[i, f'model_{j}'].predict(X))
        y_preds = np.array(y_preds)
        y_preds = scipy.stats.mode(y_preds)
        y_preds = y_preds[0]
        y_preds = y_preds.reshape(-1)
    elif mode == 'ensemble_mean':
        y_preds = []
        for i in df_model.index:
            for j in range(K):
                y_preds.append(df_model.loc[i, f'model_{j}'].predict_proba(X))
        y_preds = np.mean(np.array(y_preds), axis=0)
        y_preds = np.argmax(y_preds, axis=-1)
    elif mode == 'weighted_ensemble_mean':
        y_preds = []
        model_weight = df_model['average_mcc'].apply(lambda a: a/df_model['average_mcc'].sum())
        print(model_weight)
        for i in df_model.index:
            for j in range(K):
                y_preds.append(
                    df_model.loc[i, f'model_{j}'].predict_proba(X) *
                    model_weight[i]
                )
        y_preds = np.mean(np.array(y_preds), axis=0)
        y_preds = np.argmax(y_preds, axis=-1)
    else:
        raise KeyError("Mode isn't supported")
    
    return y_preds

def metrics(y_true, y_pred):
    print('Weighted F1 Score :', f1_score(y_true, y_pred, average='weighted'))
    print('MCC Score :', matthews_corrcoef(y_true, y_pred))
    cm = confusion_matrix(y_true, y_pred)
    cm = pd.DataFrame(cm, [0, 1], [0, 1])

    sns.heatmap(cm, annot=True, cmap="YlGnBu", fmt="d")
    plt.show()

# %%
y_train_pred = predict(X_train, mode='best_mode')
metrics(y_train, y_train_pred)
# Out:
# Weighted F1 Score : 0.8744465805683954
# MCC Score : 0.5301577342716455

# %%
y_train_pred2 = predict(X_train, mode='best_mean')
metrics(y_train, y_train_pred2)
# Out:
# Weighted F1 Score : 0.8746032003246811
# MCC Score : 0.5300770552709704

# %%
y_train_pred3 = predict(X_train, mode='ensemble_mode')
metrics(y_train, y_train_pred3)
# Out:
# Weighted F1 Score : 0.875222691342712
# MCC Score : 0.5305932458396688

# %%
y_train_pred4 = predict(X_train, mode='ensemble_mean')
metrics(y_train, y_train_pred4)
# Out:
# Weighted F1 Score : 0.8753955053400568
# MCC Score : 0.5307512464322698

# %%
y_train_pred5 = predict(X_train, mode='weighted_ensemble_mean')
metrics(y_train, y_train_pred5)
# Out:
# 0      0.002322
# 1      0.002321
# 2      0.002321
# 3      0.002321
# 4      0.002321
#          ...
# 427    0.002304
# 428    0.002304
# 429    0.002304
# 430    0.002303
# 431    0.002303
# Name: average_mcc, Length: 432, dtype: float64
# Weighted F1 Score : 0.8753955053400568
# MCC Score : 0.5307512464322698

# %% [markdown]
# # Test

# %%
y_test_pred = predict(X_test, mode='best_mode')

df_submission = pd.concat([pd.Series(list(range(0, len(X_test))), name='row_id', dtype=np.int32), pd.Series(y_test_pred, name='open_flag')], axis=1)
df_submission.to_csv('submission_best_mode.csv', index=False)

df_submission
# Out:
#        row_id  open_flag
# 0           0          0
# 1           1          0
# 2           2          0
# 3           3          0
# 4           4          0
# ...       ...        ...
# 55965   55965          0
# 55966   55966          0
# 55967   55967          0
# 55968   55968          0
# 55969   55969          1
#
# [55970 rows x 2 columns]

# %%
y_test_pred2 = predict(X_test, mode='best_mean')

df_submission = pd.concat([pd.Series(list(range(0, len(X_test))), name='row_id', dtype=np.int32), pd.Series(y_test_pred2, name='open_flag')], axis=1)
df_submission.to_csv('submission_best_mean.csv', index=False)

df_submission
# Out:
#        row_id  open_flag
# 0           0          0
# 1           1          0
# 2           2          0
# 3           3          0
# 4           4          0
# ...       ...        ...
# 55965   55965          0
# 55966   55966          0
# 55967   55967          0
# 55968   55968          0
# 55969   55969          1
#
# [55970 rows x 2 columns]

# %%
y_test_pred3 = predict(X_test, mode='ensemble_mode')

df_submission = pd.concat([pd.Series(list(range(0, len(X_test))), name='row_id', dtype=np.int32), pd.Series(y_test_pred3, name='open_flag')], axis=1)
df_submission.to_csv('submission_ensemble_mode.csv', index=False)

df_submission
# Out:
#        row_id  open_flag
# 0           0          0
# 1           1          0
# 2           2          0
# 3           3          0
# 4           4          0
# ...       ...        ...
# 55965   55965          0
# 55966   55966          0
# 55967   55967          0
# 55968   55968          0
# 55969   55969          1
#
# [55970 rows x 2 columns]

# %%
y_test_pred4 = predict(X_test, mode='ensemble_mean')

df_submission = pd.concat([pd.Series(list(range(0, len(X_test))), name='row_id', dtype=np.int32), pd.Series(y_test_pred4, name='open_flag')], axis=1)
df_submission.to_csv('submission_ensemble_mean.csv', index=False)

df_submission
# Out:
#        row_id  open_flag
# 0           0          0
# 1           1          0
# 2           2          0
# 3           3          0
# 4           4          0
# ...       ...        ...
# 55965   55965          0
# 55966   55966          0
# 55967   55967          0
# 55968   55968          0
# 55969   55969          1
#
# [55970 rows x 2 columns]

# %%
y_test_pred5 = predict(X_test, mode='weighted_ensemble_mean')

df_submission = pd.concat([pd.Series(list(range(0, len(X_test))), name='row_id', dtype=np.int32), pd.Series(y_test_pred5, name='open_flag')], axis=1)
df_submission.to_csv('submission_weighted_ensemble_mean.csv', index=False)

df_submission
# Out:
# 0      0.002322
# 1      0.002321
# 2      0.002321
# 3      0.002321
# 4      0.002321
#          ...
# 427    0.002304
# 428    0.002304
# 429    0.002304
# 430    0.002303
# 431    0.002303
# Name: average_mcc, Length: 432, dtype: float64
#        row_id  open_flag
# 0           0          0
# 1           1          0
# 2           2          0
# 3           3          0
# 4           4          0
# ...       ...        ...
# 55965   55965          0
# 55966   55966          0
# 55967   55967          0
# 55968   55968          0
# 55969   55969          1
#
# [55970 rows x 2 columns]

# %% [markdown]
# # Visualize
#
# * Feature importance
# * Tree shape

# %%
lgbm.plot_importance(df_model.loc[0, 'model_0'], ignore_zero=False, figsize=(16,9))

# %%
lgbm.plot_split_value_histogram(df_model.loc[0, 'model_0'], 2)
