# %% [markdown]
# # Changelog
#
# ## Version 23
#
# * Final hyperparameter tuning
# * Use 3, 5 & 10 StratifiedKFold
#
# ## Version 21
#
# * Tuning LightGBM parameter from version 20 result
#     * lambda pair : [0.0, 0.0], [0.001, 0.01], [0.01, 0.1], [0.01, 1.0], [1.0, 0.01]
# * Try different boosting_type
# * Change formula for weighted ensemble mean
# * Use 3 & 5 StratifiedKFold
#
# ## Version 20
#
# * Tuning LightGBM parameter from version 18 result
# * Stop using validation data
#
# ## Version 18
#
# * Tuning LightGBM parameter from version 16 result
#     * num_leaves : 63
#     * min_data_in_leaf : 20, 50
#     * bagging_fraction : **no diff**
#     * feature_fraction : 0.9, 1.0
#     * max_bin : 16, 102, 255
#     * min_data_per_group : 1
# * Use validation data to reduce overfit
#
# ## Version 16
#
# * Tuning LightGBM parameter from version 15 result
#     * boosting_type : gbdt
#     * n_estimators : 100
#     * LR : 0.01
#     * num_leaves : 31, 63
#     * min_data_in_leaf : 20, 50
#
# ## Version 15
#
# * Make submission for all mode
# * Fix dump `df_model`
# * Remove `age` from category feature
#
# ## Version 13
#
# * Tuning LightGBM parameter
# * Add additional preprocessing
# * Add EDA
#
# ## Version 10
#
# * Add additional preprocessing
#
# ## Version 9
#
# * Use StratifiedKFold 3, 5, 10
# * Combine parameter from verison 4 & 5
# * Use mean and mode to predict data
#
# ## Version 5
#
# * Use MCC score
# * Visualize LightGBM tree
# * Use different processed dataset
# * Specify categorical feature
# * Tweak parameter
#
# ## Version 4
#
# * Attempt fix overfit
# * Tweak class weight
#
# ## Version 2
#
# * Fix wrong row
# * Lower `max_bin` 255 -> 64
# * Increase `num_iterations` 5000 -> 10000
#
# ## Version 1
#
# * Initial Code

# %% [markdown]
# # Library

# %%
import os
import random
import platform
import itertools

import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import lightgbm as lgbm
import scipy

# %%
# !pip freeze > requirements.txt

# %%
print('Python version:', platform.python_version())
print('Numpy version:', np.__version__)
print('Pandas version:', pd.__version__)
print('Matplotlib version:', matplotlib.__version__)
print('Seaborn version:', sns.__version__)
print('Scikit-Learn version:', sklearn.__version__)
print('LightGBM version:', lgbm.__version__)
print('Scipy version:', scipy.__version__)
# Out:
# Python version: 3.7.6
# Numpy version: 1.18.5
# Pandas version: 1.0.3
# Matplotlib version: 3.2.1
# Seaborn version: 0.10.0
# Scikit-Learn version: 0.23.1
# LightGBM version: 2.3.1
# Scipy version: 1.4.1

# %%
SEED = 42

os.environ['PYTHONHASHSEED']=str(SEED)
random.seed(SEED)
np.random.seed(SEED)

# %%
pd.set_option('display.width', None)
pd.set_option('display.max_column', None)

# %% [markdown]
# # Dataset

# %%
df_train = pd.read_parquet('/kaggle/input/shopee-marketing-data/train_processed.parquet')
df_train
# Out:
#        country_code                 grass_date  subject_line_length  \
# 0                 4  2019-07-16 00:00:00+08:00                   44
# 1                 4  2019-07-16 00:00:00+08:00                   44
# 2                 6  2019-07-16 00:00:00+08:00                   49
# 3                 1  2019-07-16 00:00:00+08:00                   49
# 4                 6  2019-07-16 00:00:00+08:00                   49
# ...             ...                        ...                  ...
# 73534             6  2019-09-02 00:00:00+08:00                   39
# 73535             2  2019-09-02 00:00:00+08:00                   38
# 73536             2  2019-09-02 00:00:00+08:00                   32
# 73537             2  2019-09-02 00:00:00+08:00                   38
# 73538             6  2019-09-02 00:00:00+08:00                   39
#
#        last_open_day  last_login_day  last_checkout_day  \
# 0               19.0             6.0               18.0
# 1                9.0             4.0                8.0
# 2               14.0             5.0                5.0
# 3               49.0             9.0               53.0
# 4              227.0             6.0              221.0
# ...              ...             ...                ...
# 73534           24.0            36.0              279.0
# 73535           46.0            10.0               51.0
# 73536            NaN             NaN                NaN
# 73537            5.0            34.0                NaN
# 73538            1.0             3.0                NaN
#
#        open_count_last_10_days  open_count_last_30_days  \
# 0                            0                        2
# 1                            2                        9
# 2                            0                        4
# 3                            0                        0
# 4                            0                        0
# ...                        ...                      ...
# 73534                        0                        1
# 73535                        0                        0
# 73536                        0                        0
# 73537                        2                        4
# 73538                        2                        2
#
#        open_count_last_60_days  login_count_last_10_days  \
# 0                            4                        12
# 1                           17                        18
# 2                           12                        24
# 3                            1                         9
# 4                            0                         2
# ...                        ...                       ...
# 73534                        1                         0
# 73535                        1                         0
# 73536                        0                         0
# 73537                        4                         0
# 73538                        3                         0
#
#        login_count_last_30_days  login_count_last_60_days  \
# 0                            43                        99
# 1                            48                        90
# 2                            69                       119
# 3                            23                        69
# 4                             5                         5
# ...                         ...                       ...
# 73534                         0                         0
# 73535                         0                         0
# 73536                         0                         0
# 73537                         0                         0
# 73538                         0                         0
#
#        checkout_count_last_10_days  checkout_count_last_30_days  \
# 0                                0                            5
# 1                                1                            1
# 2                                5                           19
# 3                                1                            3
# 4                                0                            0
# ...                            ...                          ...
# 73534                            0                            0
# 73535                            0                            0
# 73536                            0                            0
# 73537                            0                            0
# 73538                            0                            0
#
#        checkout_count_last_60_days  open_flag  attr_1  attr_2  attr_3   age  \
# 0                               10          0     1.0     1.0     2.0  47.0
# 1                                4          1     1.0     1.0     2.0  25.0
# 2                               27          0     NaN     1.0     0.0   NaN
# 3                                6          0     1.0     1.0     2.0  24.0
# 4                                0          0     NaN     1.0     0.0   NaN
# ...                            ...        ...     ...     ...     ...   ...
# 73534                            0          0     1.0     1.0     1.0  37.0
# 73535                            0          0     NaN     1.0     0.0   NaN
# 73536                            0          0     NaN     1.0     0.0   NaN
# 73537                            0          1     NaN     1.0     0.0   NaN
# 73538                            0          0     NaN     1.0     0.0   NaN
#
#        domain
# 0         0.0
# 1         3.0
# 2         2.0
# 3         2.0
# 4         3.0
# ...       ...
# 73534     0.0
# 73535     0.0
# 73536     9.0
# 73537     0.0
# 73538     0.0
#
# [73539 rows x 21 columns]

# %%
df_test = pd.read_parquet('/kaggle/input/shopee-marketing-data/test_processed.parquet')
df_test
# Out:
#        country_code                 grass_date  subject_line_length  \
# 0                 6  2019-09-03 00:00:00+08:00                   35
# 1                 6  2019-09-03 00:00:00+08:00                   35
# 2                 5  2019-09-03 00:00:00+08:00                   25
# 3                 1  2019-09-03 00:00:00+08:00                   36
# 4                 5  2019-09-03 00:00:00+08:00                   23
# ...             ...                        ...                  ...
# 55965             6  2019-09-29 00:00:00+08:00                   53
# 55966             6  2019-09-29 00:00:00+08:00                   53
# 55967             6  2019-09-29 00:00:00+08:00                   43
# 55968             6  2019-09-29 00:00:00+08:00                   43
# 55969             6  2019-09-29 00:00:00+08:00                   53
#
#        last_open_day  last_login_day  last_checkout_day  \
# 0               27.0             2.0               13.0
# 1                7.0             5.0              383.0
# 2               34.0             1.0                3.0
# 3               63.0             5.0                5.0
# 4                6.0             5.0               54.0
# ...              ...             ...                ...
# 55965            NaN             4.0                8.0
# 55966           59.0           802.0             1207.0
# 55967            NaN             7.0                NaN
# 55968            5.0             5.0                6.0
# 55969            5.0             3.0               20.0
#
#        open_count_last_10_days  open_count_last_30_days  \
# 0                            2                        3
# 1                            1                        1
# 2                            0                        0
# 3                            0                        0
# 4                            0                        0
# ...                        ...                      ...
# 55965                        0                        0
# 55966                        0                        0
# 55967                        0                        0
# 55968                        2                        5
# 55969                        2                       14
#
#        open_count_last_60_days  login_count_last_10_days  \
# 0                            4                        10
# 1                            1                         5
# 2                            0                        13
# 3                            0                        43
# 4                            0                         4
# ...                        ...                       ...
# 55965                        0                         0
# 55966                        1                         0
# 55967                        0                         0
# 55968                       14                         0
# 55969                       27                         0
#
#        login_count_last_30_days  login_count_last_60_days  \
# 0                            34                       134
# 1                             5                         5
# 2                            19                        38
# 3                           110                       173
# 4                            12                        39
# ...                         ...                       ...
# 55965                         0                         0
# 55966                         0                         0
# 55967                         0                         0
# 55968                         0                         0
# 55969                         0                         0
#
#        checkout_count_last_10_days  checkout_count_last_30_days  \
# 0                                0                            6
# 1                                0                            0
# 2                                2                            2
# 3                                2                            5
# 4                                0                            0
# ...                            ...                          ...
# 55965                            0                            0
# 55966                            0                            0
# 55967                            0                            0
# 55968                            0                            0
# 55969                            0                            0
#
#        checkout_count_last_60_days  attr_1  attr_2  attr_3   age  domain
# 0                               18     NaN     1.0     0.0   NaN     0.0
# 1                                0     NaN     1.0     0.0   NaN     0.0
# 2                                2     1.0     1.0     2.0  33.0     0.0
# 3                                5     1.0     1.0     2.0  22.0     2.0
# 4                                2     NaN     1.0     0.0   NaN     0.0
# ...                            ...     ...     ...     ...   ...     ...
# 55965                            0     NaN     1.0     0.0   NaN     3.0
# 55966                            0     NaN     1.0     0.0   NaN     0.0
# 55967                            0     NaN     1.0     0.0   NaN     0.0
# 55968                            0     NaN     NaN     NaN   NaN     NaN
# 55969                            0     NaN     NaN     NaN   NaN     NaN
#
# [55970 rows x 20 columns]

# %% [markdown]
# # preprocessing

# %% [markdown]
# ## 1. Timedate

# %%
df_train['day'] = pd.to_datetime(df_train['grass_date']).dt.dayofweek.astype('category')
df_test['day'] = pd.to_datetime(df_test['grass_date']).dt.dayofweek.astype('category')

# %%
del df_train['grass_date']
del df_test['grass_date']

# %% [markdown]
# ## 2. Anomaly

# %%
def fix_age(age):
    if age < 18 or age >= 100:
        return np.nan
    else:
        return age
    
df_train['age'] = df_train['age'].apply(fix_age)
df_test['age'] = df_test['age'].apply(fix_age)

# %% [markdown]
# ## 3. NaN

# %%
# # last_open_day
# df_train['last_open_day_nan'] = df_train['last_open_day'].isnull()
# df_train['last_open_day'] = df_train['last_open_day'].fillna(-1)

# df_test['last_open_day_nan'] = df_test['last_open_day'].isnull()
# df_test['last_open_day'] = df_test['last_open_day'].fillna(-1)

# # last_login_day
# df_train['last_login_day_nan'] = df_train['last_login_day'].isnull()
# df_train['last_login_day'] = df_train['last_login_day'].fillna(-1)

# df_test['last_login_day_nan'] = df_test['last_login_day'].isnull()
# df_test['last_login_day'] = df_test['last_login_day'].fillna(-1)

# # last_checkout_day
# df_train['last_checkout_day_nan'] = df_train['last_checkout_day'].isnull()
# df_train['last_checkout_day'] = df_train['last_checkout_day'].fillna(-1)

# df_test['last_checkout_day_nan'] = df_test['last_checkout_day'].isnull()
# df_test['last_checkout_day'] = df_test['last_checkout_day'].fillna(-1)

# # attr_1
# df_train['attr_1_nan'] = df_train['attr_1'].isnull()
# df_train['attr_1'] = df_train['attr_1'].fillna(-1)

# df_test['attr_1_nan'] = df_test['attr_1'].isnull()
# df_test['attr_1'] = df_test['attr_1'].fillna(-1)

# # attr_2
# df_train['attr_2_nan'] = df_train['attr_2'].isnull()
# df_train['attr_2'] = df_train['attr_2'].fillna(-1)

# df_test['attr_2_nan'] = df_test['attr_2'].isnull()
# df_test['attr_2'] = df_test['attr_2'].fillna(-1)

# # attr_3
# df_train['attr_3_nan'] = df_train['attr_3'].isnull()
# df_train['attr_3'] = df_train['attr_3'].fillna(-1)

# df_test['attr_3_nan'] = df_test['attr_3'].isnull()
# df_test['attr_3'] = df_test['attr_3'].fillna(-1)

# # age
# df_train['age_nan'] = df_train['age'].isnull()
# df_train['age'] = df_train['age'].fillna(-1)

# df_test['age_nan'] = df_test['age'].isnull()
# df_test['age'] = df_test['age'].fillna(-1)

# %%
# domain
# 1 -> 'other' domain from previous preprocessing
# df_train['domain_nan'] = df_train['domain'].isnull()
df_train['domain'] = df_train['domain'].fillna(1)

# df_test['domain_nan'] = df_test['domain'].isnull()
df_test['domain'] = df_test['domain'].fillna(1)

# %% [markdown]
# ## 4. Misc

# %%
X = df_train.copy()
del X['open_flag']

X_test = df_test.copy()

y = df_train['open_flag'].to_numpy()

# %%
cat_feature = [
    'country_code','attr_1', 'attr_2', 'attr_3',
    'domain','day',
#     'last_open_day_nan', 'last_login_day_nan',
#     'last_checkout_day_nan', 'attr_1_nan', 'attr_2_nan',
#     'attr_3_nan', 'age_nan', 'domain_nan',
    
]
cat_feature_idx = [X.columns.get_loc(ct) for ct in cat_feature]
cat_feature_idx
# Out:
# [0, 14, 15, 16, 18, 19]

# %% [markdown]
# # Model

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import matthews_corrcoef

K = [3, 5, 10]

# %%
param_dict = {
    'learning_rate': [0.0075, 0.01, 0.0125],
    'min_data_in_leaf': [20, 50],
    'max_bin': [16, 102, 255],
    'lambda': [
        # l1, l2
        [0.0, 0.0],
        [0.001, 0.01],
        [0.01, 0.1],
        [1.0, 0.01],
    ],
    'n_estimators': [100, 125, 150]
}
param_key = list(param_dict.keys())
param_item = list(param_dict.values())
param_item
# Out:
# [[0.0075, 0.01, 0.0125],
#  [20, 50],
#  [16, 102, 255],
#  [[0.0, 0.0], [0.001, 0.01], [0.01, 0.1], [1.0, 0.01]],
#  [100, 125, 150]]

# %%
param_list = list(itertools.product(*param_item))
param_list[:10]
# Out:
# [(0.0075, 20, 16, [0.0, 0.0], 100),
#  (0.0075, 20, 16, [0.0, 0.0], 125),
#  (0.0075, 20, 16, [0.0, 0.0], 150),
#  (0.0075, 20, 16, [0.001, 0.01], 100),
#  (0.0075, 20, 16, [0.001, 0.01], 125),
#  (0.0075, 20, 16, [0.001, 0.01], 150),
#  (0.0075, 20, 16, [0.01, 0.1], 100),
#  (0.0075, 20, 16, [0.01, 0.1], 125),
#  (0.0075, 20, 16, [0.01, 0.1], 150),
#  (0.0075, 20, 16, [1.0, 0.01], 100)]

# %%
len(param_list)
# Out:
# 216

# %%
df_model = pd.DataFrame(columns=[*param_key, *[f'model_{i}' for i in range(sum(K))], *[f'model_{i}_mcc' for i in range(sum(K))], 'average_mcc'])
df_model
# Out:
# Empty DataFrame
# Columns: [learning_rate, min_data_in_leaf, max_bin, lambda, n_estimators, model_0, model_1, model_2, model_3, model_4, model_5, model_6, model_7, model_8, model_9, model_10, model_11, model_12, model_13, model_14, model_15, model_16, model_17, model_0_mcc, model_1_mcc, model_2_mcc, model_3_mcc, model_4_mcc, model_5_mcc, model_6_mcc, model_7_mcc, model_8_mcc, model_9_mcc, model_10_mcc, model_11_mcc, model_12_mcc, model_13_mcc, model_14_mcc, model_15_mcc, model_16_mcc, model_17_mcc, average_mcc]
# Index: []

# %%
skf_list = [StratifiedKFold(n_splits=k, shuffle=True, random_state=SEED) for k in K]

for param in param_list:
    ctr = 0
    model = []
    mcc_score = []
    for skf in skf_list:
        for train_idx, val_idx in skf.split(X, y):
            X_train, X_val = X.loc[train_idx], X.loc[val_idx]
            y_train, y_val = y[train_idx], y[val_idx]

            model.append(
                lgbm.LGBMClassifier(
                    # fixed
                    is_unbalance=True,
                    seed=SEED,
                    extra_trees=True,

                    min_data_per_group=1,
                    boosting_type='goss',
                    num_leaves=63,
                    feature_fraction=0.9,
                    # variable
                    learning_rate=param[0],
                    min_data_in_leaf=param[1],
                    max_bin=param[2], 
                    lambda_l1=param[3][0],
                    lambda_l2=param[3][1],
                    n_estimators=param[4],
                )
            )
            model[ctr].fit(
                X_train, y_train,
                categorical_feature=cat_feature_idx
            )

            y_val_pred = model[ctr].predict(X_val)
            mcc_score.append(matthews_corrcoef(y_val, y_val_pred))

            ctr += 1
    df_model.loc[ df_model.shape[0] ] = [
        *param,
        *model,
        *mcc_score,
        sum(mcc_score) / len(mcc_score)
    ]
# Out:
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# ...
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))

# %% [markdown]
# # Evaluate

# %%
df_model = df_model.sort_values(by=['average_mcc', 'learning_rate'], ascending=[False, True]).reset_index(drop=True)
df_model.loc[:1000].to_pickle('model.pkl')
# !ls -lah
# Out:
# total 3.1G
# drwxr-xr-x 2 root root 4.0K Aug  8 12:09 .
# drwxr-xr-x 6 root root 4.0K Aug  8 10:19 ..
# ---------- 1 root root 308K Aug  8 12:09 __notebook__.ipynb
# -rw-r--r-- 1 root root 3.1G Aug  8 12:11 model.pkl
# -rw-r--r-- 1 root root  14K Aug  8 10:19 requirements.txt

# %%
pd.set_option('display.max_row', df_model.shape[0])

# %%
df_model
# Out:
#      learning_rate min_data_in_leaf max_bin         lambda n_estimators  \
# 0           0.0075               50      16     [0.0, 0.0]          125
# 1           0.0075               50     102  [0.001, 0.01]          125
# 2           0.0075               20      16     [0.0, 0.0]          125
# 3           0.0075               20      16  [0.001, 0.01]          125
# 4           0.0075               50     255  [0.001, 0.01]          125
# 5           0.0075               50      16  [0.001, 0.01]          125
# 6           0.0075               50      16    [0.01, 0.1]          125
# 7           0.0075               20     102     [0.0, 0.0]          125
# 8           0.0075               50     102    [0.01, 0.1]          125
# 9           0.0075               50     255    [0.01, 0.1]          125
# 10          0.0075               20     255    [0.01, 0.1]          125
# 11          0.0075               50     102    [1.0, 0.01]          125
# 12          0.0075               50     102     [0.0, 0.0]          125
# 13          0.0075               20      16    [0.01, 0.1]          125
# 14          0.0075               50     255     [0.0, 0.0]          125
# 15          0.0075               20     255  [0.001, 0.01]          125
# 16          0.0075               20     102  [0.001, 0.01]          125
# 17          0.0075               20     102    [0.01, 0.1]          125
# 18          0.0075               20     102    [1.0, 0.01]          125
# 19          0.0075               50      16    [1.0, 0.01]          125
# 20          0.0075               20     255    [1.0, 0.01]          125
# 21          0.0075               20      16    [1.0, 0.01]          125
# 22          0.0075               20     255     [0.0, 0.0]          125
# 23          0.0075               20     102  [0.001, 0.01]          150
# 24          0.0075               50     255    [1.0, 0.01]          125
# 25          0.0100               50     255    [1.0, 0.01]          100
# 26          0.0075               50     255    [0.01, 0.1]          150
# 27          0.0100               50     102    [1.0, 0.01]          100
# 28          0.0075               20     102    [0.01, 0.1]          150
# 29          0.0100               20     255     [0.0, 0.0]          100
# 30          0.0075               50     102  [0.001, 0.01]          150
# 31          0.0075               50     102     [0.0, 0.0]          150
# 32          0.0075               20     102    [1.0, 0.01]          150
# 33          0.0100               50     102    [0.01, 0.1]          100
# 34          0.0100               50      16     [0.0, 0.0]          100
# 35          0.0075               50     255     [0.0, 0.0]          150
# 36          0.0100               20     255    [1.0, 0.01]          100
# 37          0.0075               50     102    [0.01, 0.1]          150
# 38          0.0075               20     255  [0.001, 0.01]          150
# 39          0.0100               50      16  [0.001, 0.01]          100
# 40          0.0100               50     102  [0.001, 0.01]          100
# 41          0.0100               20     102     [0.0, 0.0]          100
# 42          0.0100               50      16    [0.01, 0.1]          100
# 43          0.0100               20      16    [1.0, 0.01]          100
# 44          0.0100               50     255  [0.001, 0.01]          100
# 45          0.0100               50     255    [0.01, 0.1]          100
# 46          0.0100               20     102    [0.01, 0.1]          100
# 47          0.0100               20      16    [0.01, 0.1]          100
# 48          0.0075               50     102    [1.0, 0.01]          150
# 49          0.0075               20     102     [0.0, 0.0]          150
# 50          0.0100               20     255    [0.01, 0.1]          100
# 51          0.0100               20     102  [0.001, 0.01]          100
# 52          0.0075               50     255  [0.001, 0.01]          150
# 53          0.0100               50     102     [0.0, 0.0]          100
# 54          0.0100               50      16    [1.0, 0.01]          100
# 55          0.0100               50     255     [0.0, 0.0]          100
# 56          0.0100               20     102    [1.0, 0.01]          100
# 57          0.0100               20      16  [0.001, 0.01]          100
# 58          0.0075               20     255    [1.0, 0.01]          150
# 59          0.0075               50     255    [1.0, 0.01]          150
# 60          0.0075               20     255    [0.01, 0.1]          150
# 61          0.0100               20     255  [0.001, 0.01]          100
# 62          0.0075               20     255     [0.0, 0.0]          150
# 63          0.0100               20      16     [0.0, 0.0]          100
# 64          0.0075               20      16    [0.01, 0.1]          150
# 65          0.0075               50      16     [0.0, 0.0]          150
# 66          0.0075               20      16  [0.001, 0.01]          150
# 67          0.0075               20      16    [1.0, 0.01]          150
# 68          0.0075               50      16    [1.0, 0.01]          150
# 69          0.0075               20      16     [0.0, 0.0]          150
# 70          0.0075               50      16  [0.001, 0.01]          150
# 71          0.0075               50      16    [0.01, 0.1]          150
# 72          0.0100               50     102  [0.001, 0.01]          125
# 73          0.0100               50     255  [0.001, 0.01]          125
# 74          0.0100               50     102     [0.0, 0.0]          125
# 75          0.0100               20     102    [0.01, 0.1]          125
# 76          0.0125               50     102  [0.001, 0.01]          100
# 77          0.0125               50     102     [0.0, 0.0]          100
# 78          0.0125               50     255    [1.0, 0.01]          100
# 79          0.0125               50     102    [0.01, 0.1]          100
# 80          0.0125               20     255    [0.01, 0.1]          100
# 81          0.0100               50     255    [1.0, 0.01]          125
# 82          0.0100               50     255    [0.01, 0.1]          125
# 83          0.0100               20     255    [1.0, 0.01]          125
# 84          0.0100               20     102  [0.001, 0.01]          125
# 85          0.0125               20     255  [0.001, 0.01]          100
# 86          0.0100               50     102    [0.01, 0.1]          125
# 87          0.0100               50     102    [1.0, 0.01]          125
# 88          0.0100               20     255  [0.001, 0.01]          125
# 89          0.0100               50     255     [0.0, 0.0]          125
# 90          0.0100               20     102     [0.0, 0.0]          125
# 91          0.0125               50     255  [0.001, 0.01]          100
# 92          0.0100               20     102    [1.0, 0.01]          125
# 93          0.0125               20     102  [0.001, 0.01]          100
# 94          0.0125               50     255     [0.0, 0.0]          100
# 95          0.0100               20     255    [0.01, 0.1]          125
# 96          0.0100               20     255     [0.0, 0.0]          125
# 97          0.0125               50     102    [1.0, 0.01]          100
# 98          0.0125               20     102    [0.01, 0.1]          100
# 99          0.0125               20     255     [0.0, 0.0]          100
# 100         0.0125               50     255    [0.01, 0.1]          100
# 101         0.0125               20     255    [1.0, 0.01]          100
# 102         0.0125               20     102     [0.0, 0.0]          100
# 103         0.0125               50      16    [0.01, 0.1]          100
# 104         0.0125               20     102    [1.0, 0.01]          100
# 105         0.0100               50      16     [0.0, 0.0]          125
# 106         0.0100               50      16    [0.01, 0.1]          125
# 107         0.0125               50      16  [0.001, 0.01]          100
# 108         0.0125               50      16     [0.0, 0.0]          100
# 109         0.0100               50      16  [0.001, 0.01]          125
# 110         0.0100               20      16    [1.0, 0.01]          125
# 111         0.0125               20      16    [0.01, 0.1]          100
# 112         0.0075               20     255    [0.01, 0.1]          100
# 113         0.0075               50     102    [1.0, 0.01]          100
# 114         0.0125               50      16    [1.0, 0.01]          100
# 115         0.0100               20      16    [0.01, 0.1]          125
# 116         0.0075               50     255    [0.01, 0.1]          100
# 117         0.0075               50     102    [0.01, 0.1]          100
# 118         0.0075               50     102     [0.0, 0.0]          100
# 119         0.0125               20      16     [0.0, 0.0]          100
# 120         0.0075               50      16    [0.01, 0.1]          100
# 121         0.0125               20      16  [0.001, 0.01]          100
# 122         0.0075               20     255     [0.0, 0.0]          100
# 123         0.0100               20      16     [0.0, 0.0]          125
# 124         0.0075               50     255    [1.0, 0.01]          100
# 125         0.0100               50      16    [1.0, 0.01]          125
# 126         0.0075               20     102  [0.001, 0.01]          100
# 127         0.0075               20     255    [1.0, 0.01]          100
# 128         0.0075               20     102     [0.0, 0.0]          100
# 129         0.0075               50     255     [0.0, 0.0]          100
# 130         0.0075               50      16     [0.0, 0.0]          100
# 131         0.0100               20      16  [0.001, 0.01]          125
# 132         0.0075               20      16    [0.01, 0.1]          100
# 133         0.0075               50      16  [0.001, 0.01]          100
# 134         0.0075               20     255  [0.001, 0.01]          100
# 135         0.0125               20      16    [1.0, 0.01]          100
# 136         0.0075               50     102  [0.001, 0.01]          100
# 137         0.0075               20     102    [0.01, 0.1]          100
# 138         0.0075               20     102    [1.0, 0.01]          100
# 139         0.0075               50     255  [0.001, 0.01]          100
# 140         0.0075               50      16    [1.0, 0.01]          100
# 141         0.0075               20      16    [1.0, 0.01]          100
# 142         0.0075               20      16  [0.001, 0.01]          100
# 143         0.0075               20      16     [0.0, 0.0]          100
# 144         0.0100               50     102  [0.001, 0.01]          150
# 145         0.0100               50     255     [0.0, 0.0]          150
# 146         0.0100               20     255  [0.001, 0.01]          150
# 147         0.0100               20     255     [0.0, 0.0]          150
# 148         0.0100               50      16  [0.001, 0.01]          150
# 149         0.0100               50      16    [1.0, 0.01]          150
# 150         0.0100               20      16     [0.0, 0.0]          150
# 151         0.0100               20      16  [0.001, 0.01]          150
# 152         0.0100               50     102    [0.01, 0.1]          150
# 153         0.0100               50     255    [0.01, 0.1]          150
# 154         0.0100               50      16    [0.01, 0.1]          150
# 155         0.0100               50     102    [1.0, 0.01]          150
# 156         0.0100               50     102     [0.0, 0.0]          150
# 157         0.0100               50     255    [1.0, 0.01]          150
# 158         0.0100               20     102  [0.001, 0.01]          150
# 159         0.0100               50     255  [0.001, 0.01]          150
# 160         0.0100               20     102    [1.0, 0.01]          150
# 161         0.0100               20      16    [0.01, 0.1]          150
# 162         0.0100               20     102     [0.0, 0.0]          150
# 163         0.0100               20     255    [1.0, 0.01]          150
# 164         0.0100               20     255    [0.01, 0.1]          150
# 165         0.0100               20     102    [0.01, 0.1]          150
# 166         0.0100               20      16    [1.0, 0.01]          150
# 167         0.0125               20     255    [0.01, 0.1]          125
# 168         0.0100               50      16     [0.0, 0.0]          150
# 169         0.0125               20     102    [0.01, 0.1]          125
# 170         0.0125               50     255     [0.0, 0.0]          125
# 171         0.0125               20     102    [1.0, 0.01]          125
# 172         0.0125               20     102     [0.0, 0.0]          125
# 173         0.0125               50     255    [1.0, 0.01]          125
# 174         0.0125               50     102  [0.001, 0.01]          125
# 175         0.0125               50      16     [0.0, 0.0]          125
# 176         0.0125               20     255  [0.001, 0.01]          125
# 177         0.0125               50      16    [1.0, 0.01]          125
# 178         0.0125               50     102    [1.0, 0.01]          125
# 179         0.0125               20      16    [1.0, 0.01]          125
# 180         0.0125               20     102  [0.001, 0.01]          125
# 181         0.0125               20      16     [0.0, 0.0]          125
# 182         0.0125               50     102     [0.0, 0.0]          125
# 183         0.0125               50     102    [0.01, 0.1]          125
# 184         0.0125               50     255    [0.01, 0.1]          125
# 185         0.0125               50      16    [0.01, 0.1]          125
# 186         0.0125               20      16  [0.001, 0.01]          125
# 187         0.0125               50     255  [0.001, 0.01]          125
# 188         0.0125               20     255     [0.0, 0.0]          125
# 189         0.0125               20      16    [0.01, 0.1]          125
# 190         0.0125               50      16  [0.001, 0.01]          125
# 191         0.0125               20     255    [1.0, 0.01]          125
# 192         0.0125               20     255  [0.001, 0.01]          150
# 193         0.0125               50     102     [0.0, 0.0]          150
# 194         0.0125               20     255    [0.01, 0.1]          150
# 195         0.0125               50     255  [0.001, 0.01]          150
# 196         0.0125               50     255    [0.01, 0.1]          150
# 197         0.0125               20     102    [1.0, 0.01]          150
# 198         0.0125               50      16  [0.001, 0.01]          150
# 199         0.0125               50     255     [0.0, 0.0]          150
# 200         0.0125               20     255    [1.0, 0.01]          150
# 201         0.0125               50     102    [0.01, 0.1]          150
# 202         0.0125               50     255    [1.0, 0.01]          150
# 203         0.0125               20      16     [0.0, 0.0]          150
# 204         0.0125               50     102  [0.001, 0.01]          150
# 205         0.0125               20     102     [0.0, 0.0]          150
# 206         0.0125               20     102  [0.001, 0.01]          150
# 207         0.0125               20     102    [0.01, 0.1]          150
# 208         0.0125               50     102    [1.0, 0.01]          150
# 209         0.0125               20      16    [0.01, 0.1]          150
# 210         0.0125               20     255     [0.0, 0.0]          150
# 211         0.0125               20      16  [0.001, 0.01]          150
# 212         0.0125               20      16    [1.0, 0.01]          150
# 213         0.0125               50      16    [0.01, 0.1]          150
# 214         0.0125               50      16    [1.0, 0.01]          150
# 215         0.0125               50      16     [0.0, 0.0]          150
#
#                                                model_0  \
# 0    LGBMClassifier(boosting_type='goss', extra_tre...
# 1    LGBMClassifier(boosting_type='goss', extra_tre...
# 2    LGBMClassifier(boosting_type='goss', extra_tre...
# 3    LGBMClassifier(boosting_type='goss', extra_tre...
# 4    LGBMClassifier(boosting_type='goss', extra_tre...
# 5    LGBMClassifier(boosting_type='goss', extra_tre...
# 6    LGBMClassifier(boosting_type='goss', extra_tre...
# 7    LGBMClassifier(boosting_type='goss', extra_tre...
# 8    LGBMClassifier(boosting_type='goss', extra_tre...
# 9    LGBMClassifier(boosting_type='goss', extra_tre...
# 10   LGBMClassifier(boosting_type='goss', extra_tre...
# 11   LGBMClassifier(boosting_type='goss', extra_tre...
# 12   LGBMClassifier(boosting_type='goss', extra_tre...
# 13   LGBMClassifier(boosting_type='goss', extra_tre...
# 14   LGBMClassifier(boosting_type='goss', extra_tre...
# 15   LGBMClassifier(boosting_type='goss', extra_tre...
# 16   LGBMClassifier(boosting_type='goss', extra_tre...
# 17   LGBMClassifier(boosting_type='goss', extra_tre...
# 18   LGBMClassifier(boosting_type='goss', extra_tre...
# 19   LGBMClassifier(boosting_type='goss', extra_tre...
# 20   LGBMClassifier(boosting_type='goss', extra_tre...
# 21   LGBMClassifier(boosting_type='goss', extra_tre...
# 22   LGBMClassifier(boosting_type='goss', extra_tre...
# 23   LGBMClassifier(boosting_type='goss', extra_tre...
# 24   LGBMClassifier(boosting_type='goss', extra_tre...
# 25   LGBMClassifier(boosting_type='goss', extra_tre...
# 26   LGBMClassifier(boosting_type='goss', extra_tre...
# 27   LGBMClassifier(boosting_type='goss', extra_tre...
# 28   LGBMClassifier(boosting_type='goss', extra_tre...
# 29   LGBMClassifier(boosting_type='goss', extra_tre...
# 30   LGBMClassifier(boosting_type='goss', extra_tre...
# 31   LGBMClassifier(boosting_type='goss', extra_tre...
# 32   LGBMClassifier(boosting_type='goss', extra_tre...
# 33   LGBMClassifier(boosting_type='goss', extra_tre...
# 34   LGBMClassifier(boosting_type='goss', extra_tre...
# 35   LGBMClassifier(boosting_type='goss', extra_tre...
# 36   LGBMClassifier(boosting_type='goss', extra_tre...
# 37   LGBMClassifier(boosting_type='goss', extra_tre...
# 38   LGBMClassifier(boosting_type='goss', extra_tre...
# 39   LGBMClassifier(boosting_type='goss', extra_tre...
# 40   LGBMClassifier(boosting_type='goss', extra_tre...
# 41   LGBMClassifier(boosting_type='goss', extra_tre...
# 42   LGBMClassifier(boosting_type='goss', extra_tre...
# 43   LGBMClassifier(boosting_type='goss', extra_tre...
# 44   LGBMClassifier(boosting_type='goss', extra_tre...
# 45   LGBMClassifier(boosting_type='goss', extra_tre...
# 46   LGBMClassifier(boosting_type='goss', extra_tre...
# 47   LGBMClassifier(boosting_type='goss', extra_tre...
# 48   LGBMClassifier(boosting_type='goss', extra_tre...
# 49   LGBMClassifier(boosting_type='goss', extra_tre...
# 50   LGBMClassifier(boosting_type='goss', extra_tre...
# 51   LGBMClassifier(boosting_type='goss', extra_tre...
# 52   LGBMClassifier(boosting_type='goss', extra_tre...
# 53   LGBMClassifier(boosting_type='goss', extra_tre...
# 54   LGBMClassifier(boosting_type='goss', extra_tre...
# 55   LGBMClassifier(boosting_type='goss', extra_tre...
# 56   LGBMClassifier(boosting_type='goss', extra_tre...
# 57   LGBMClassifier(boosting_type='goss', extra_tre...
# 58   LGBMClassifier(boosting_type='goss', extra_tre...
# 59   LGBMClassifier(boosting_type='goss', extra_tre...
# 60   LGBMClassifier(boosting_type='goss', extra_tre...
# 61   LGBMClassifier(boosting_type='goss', extra_tre...
# 62   LGBMClassifier(boosting_type='goss', extra_tre...
# 63   LGBMClassifier(boosting_type='goss', extra_tre...
# 64   LGBMClassifier(boosting_type='goss', extra_tre...
# 65   LGBMClassifier(boosting_type='goss', extra_tre...
# 66   LGBMClassifier(boosting_type='goss', extra_tre...
# 67   LGBMClassifier(boosting_type='goss', extra_tre...
# 68   LGBMClassifier(boosting_type='goss', extra_tre...
# 69   LGBMClassifier(boosting_type='goss', extra_tre...
# 70   LGBMClassifier(boosting_type='goss', extra_tre...
# 71   LGBMClassifier(boosting_type='goss', extra_tre...
# 72   LGBMClassifier(boosting_type='goss', extra_tre...
# 73   LGBMClassifier(boosting_type='goss', extra_tre...
# 74   LGBMClassifier(boosting_type='goss', extra_tre...
# 75   LGBMClassifier(boosting_type='goss', extra_tre...
# 76   LGBMClassifier(boosting_type='goss', extra_tre...
# 77   LGBMClassifier(boosting_type='goss', extra_tre...
# 78   LGBMClassifier(boosting_type='goss', extra_tre...
# 79   LGBMClassifier(boosting_type='goss', extra_tre...
# 80   LGBMClassifier(boosting_type='goss', extra_tre...
# 81   LGBMClassifier(boosting_type='goss', extra_tre...
# 82   LGBMClassifier(boosting_type='goss', extra_tre...
# 83   LGBMClassifier(boosting_type='goss', extra_tre...
# 84   LGBMClassifier(boosting_type='goss', extra_tre...
# 85   LGBMClassifier(boosting_type='goss', extra_tre...
# 86   LGBMClassifier(boosting_type='goss', extra_tre...
# 87   LGBMClassifier(boosting_type='goss', extra_tre...
# 88   LGBMClassifier(boosting_type='goss', extra_tre...
# 89   LGBMClassifier(boosting_type='goss', extra_tre...
# 90   LGBMClassifier(boosting_type='goss', extra_tre...
# 91   LGBMClassifier(boosting_type='goss', extra_tre...
# 92   LGBMClassifier(boosting_type='goss', extra_tre...
# 93   LGBMClassifier(boosting_type='goss', extra_tre...
# 94   LGBMClassifier(boosting_type='goss', extra_tre...
# 95   LGBMClassifier(boosting_type='goss', extra_tre...
# 96   LGBMClassifier(boosting_type='goss', extra_tre...
# 97   LGBMClassifier(boosting_type='goss', extra_tre...
# 98   LGBMClassifier(boosting_type='goss', extra_tre...
# 99   LGBMClassifier(boosting_type='goss', extra_tre...
# 100  LGBMClassifier(boosting_type='goss', extra_tre...
# 101  LGBMClassifier(boosting_type='goss', extra_tre...
# 102  LGBMClassifier(boosting_type='goss', extra_tre...
# 103  LGBMClassifier(boosting_type='goss', extra_tre...
# 104  LGBMClassifier(boosting_type='goss', extra_tre...
# 105  LGBMClassifier(boosting_type='goss', extra_tre...
# 106  LGBMClassifier(boosting_type='goss', extra_tre...
# 107  LGBMClassifier(boosting_type='goss', extra_tre...
# 108  LGBMClassifier(boosting_type='goss', extra_tre...
# 109  LGBMClassifier(boosting_type='goss', extra_tre...
# 110  LGBMClassifier(boosting_type='goss', extra_tre...
# 111  LGBMClassifier(boosting_type='goss', extra_tre...
# 112  LGBMClassifier(boosting_type='goss', extra_tre...
# 113  LGBMClassifier(boosting_type='goss', extra_tre...
# 114  LGBMClassifier(boosting_type='goss', extra_tre...
# 115  LGBMClassifier(boosting_type='goss', extra_tre...
# 116  LGBMClassifier(boosting_type='goss', extra_tre...
# 117  LGBMClassifier(boosting_type='goss', extra_tre...
# 118  LGBMClassifier(boosting_type='goss', extra_tre...
# 119  LGBMClassifier(boosting_type='goss', extra_tre...
# 120  LGBMClassifier(boosting_type='goss', extra_tre...
# 121  LGBMClassifier(boosting_type='goss', extra_tre...
# 122  LGBMClassifier(boosting_type='goss', extra_tre...
# 123  LGBMClassifier(boosting_type='goss', extra_tre...
# 124  LGBMClassifier(boosting_type='goss', extra_tre...
# 125  LGBMClassifier(boosting_type='goss', extra_tre...
# 126  LGBMClassifier(boosting_type='goss', extra_tre...
# 127  LGBMClassifier(boosting_type='goss', extra_tre...
# 128  LGBMClassifier(boosting_type='goss', extra_tre...
# 129  LGBMClassifier(boosting_type='goss', extra_tre...
# 130  LGBMClassifier(boosting_type='goss', extra_tre...
# 131  LGBMClassifier(boosting_type='goss', extra_tre...
# 132  LGBMClassifier(boosting_type='goss', extra_tre...
# 133  LGBMClassifier(boosting_type='goss', extra_tre...
# 134  LGBMClassifier(boosting_type='goss', extra_tre...
# 135  LGBMClassifier(boosting_type='goss', extra_tre...
# 136  LGBMClassifier(boosting_type='goss', extra_tre...
# 137  LGBMClassifier(boosting_type='goss', extra_tre...
# 138  LGBMClassifier(boosting_type='goss', extra_tre...
# 139  LGBMClassifier(boosting_type='goss', extra_tre...
# 140  LGBMClassifier(boosting_type='goss', extra_tre...
# 141  LGBMClassifier(boosting_type='goss', extra_tre...
# 142  LGBMClassifier(boosting_type='goss', extra_tre...
# 143  LGBMClassifier(boosting_type='goss', extra_tre...
# 144  LGBMClassifier(boosting_type='goss', extra_tre...
# 145  LGBMClassifier(boosting_type='goss', extra_tre...
# 146  LGBMClassifier(boosting_type='goss', extra_tre...
# 147  LGBMClassifier(boosting_type='goss', extra_tre...
# 148  LGBMClassifier(boosting_type='goss', extra_tre...
# 149  LGBMClassifier(boosting_type='goss', extra_tre...
# 150  LGBMClassifier(boosting_type='goss', extra_tre...
# 151  LGBMClassifier(boosting_type='goss', extra_tre...
# 152  LGBMClassifier(boosting_type='goss', extra_tre...
# 153  LGBMClassifier(boosting_type='goss', extra_tre...
# 154  LGBMClassifier(boosting_type='goss', extra_tre...
# 155  LGBMClassifier(boosting_type='goss', extra_tre...
# 156  LGBMClassifier(boosting_type='goss', extra_tre...
# 157  LGBMClassifier(boosting_type='goss', extra_tre...
# 158  LGBMClassifier(boosting_type='goss', extra_tre...
# 159  LGBMClassifier(boosting_type='goss', extra_tre...
# 160  LGBMClassifier(boosting_type='goss', extra_tre...
# 161  LGBMClassifier(boosting_type='goss', extra_tre...
# 162  LGBMClassifier(boosting_type='goss', extra_tre...
# 163  LGBMClassifier(boosting_type='goss', extra_tre...
# 164  LGBMClassifier(boosting_type='goss', extra_tre...
# 165  LGBMClassifier(boosting_type='goss', extra_tre...
# 166  LGBMClassifier(boosting_type='goss', extra_tre...
# 167  LGBMClassifier(boosting_type='goss', extra_tre...
# 168  LGBMClassifier(boosting_type='goss', extra_tre...
# 169  LGBMClassifier(boosting_type='goss', extra_tre...
# 170  LGBMClassifier(boosting_type='goss', extra_tre...
# 171  LGBMClassifier(boosting_type='goss', extra_tre...
# 172  LGBMClassifier(boosting_type='goss', extra_tre...
# 173  LGBMClassifier(boosting_type='goss', extra_tre...
# 174  LGBMClassifier(boosting_type='goss', extra_tre...
# 175  LGBMClassifier(boosting_type='goss', extra_tre...
# 176  LGBMClassifier(boosting_type='goss', extra_tre...
# 177  LGBMClassifier(boosting_type='goss', extra_tre...
# 178  LGBMClassifier(boosting_type='goss', extra_tre...
# 179  LGBMClassifier(boosting_type='goss', extra_tre...
# 180  LGBMClassifier(boosting_type='goss', extra_tre...
# 181  LGBMClassifier(boosting_type='goss', extra_tre...
# 182  LGBMClassifier(boosting_type='goss', extra_tre...
# 183  LGBMClassifier(boosting_type='goss', extra_tre...
# 184  LGBMClassifier(boosting_type='goss', extra_tre...
# 185  LGBMClassifier(boosting_type='goss', extra_tre...
# 186  LGBMClassifier(boosting_type='goss', extra_tre...
# 187  LGBMClassifier(boosting_type='goss', extra_tre...
# 188  LGBMClassifier(boosting_type='goss', extra_tre...
# 189  LGBMClassifier(boosting_type='goss', extra_tre...
# 190  LGBMClassifier(boosting_type='goss', extra_tre...
# 191  LGBMClassifier(boosting_type='goss', extra_tre...
# 192  LGBMClassifier(boosting_type='goss', extra_tre...
# 193  LGBMClassifier(boosting_type='goss', extra_tre...
# 194  LGBMClassifier(boosting_type='goss', extra_tre...
# 195  LGBMClassifier(boosting_type='goss', extra_tre...
# 196  LGBMClassifier(boosting_type='goss', extra_tre...
# 197  LGBMClassifier(boosting_type='goss', extra_tre...
# 198  LGBMClassifier(boosting_type='goss', extra_tre...
# 199  LGBMClassifier(boosting_type='goss', extra_tre...
# 200  LGBMClassifier(boosting_type='goss', extra_tre...
# 201  LGBMClassifier(boosting_type='goss', extra_tre...
# 202  LGBMClassifier(boosting_type='goss', extra_tre...
# 203  LGBMClassifier(boosting_type='goss', extra_tre...
# 204  LGBMClassifier(boosting_type='goss', extra_tre...
# 205  LGBMClassifier(boosting_type='goss', extra_tre...
# 206  LGBMClassifier(boosting_type='goss', extra_tre...
# 207  LGBMClassifier(boosting_type='goss', extra_tre...
# 208  LGBMClassifier(boosting_type='goss', extra_tre...
# 209  LGBMClassifier(boosting_type='goss', extra_tre...
# 210  LGBMClassifier(boosting_type='goss', extra_tre...
# 211  LGBMClassifier(boosting_type='goss', extra_tre...
# 212  LGBMClassifier(boosting_type='goss', extra_tre...
# 213  LGBMClassifier(boosting_type='goss', extra_tre...
# 214  LGBMClassifier(boosting_type='goss', extra_tre...
# 215  LGBMClassifier(boosting_type='goss', extra_tre...
#
#                                                model_1  \
# 0    LGBMClassifier(boosting_type='goss', extra_tre...
# 1    LGBMClassifier(boosting_type='goss', extra_tre...
# 2    LGBMClassifier(boosting_type='goss', extra_tre...
# 3    LGBMClassifier(boosting_type='goss', extra_tre...
# 4    LGBMClassifier(boosting_type='goss', extra_tre...
# 5    LGBMClassifier(boosting_type='goss', extra_tre...
# 6    LGBMClassifier(boosting_type='goss', extra_tre...
# 7    LGBMClassifier(boosting_type='goss', extra_tre...
# 8    LGBMClassifier(boosting_type='goss', extra_tre...
# 9    LGBMClassifier(boosting_type='goss', extra_tre...
# 10   LGBMClassifier(boosting_type='goss', extra_tre...
# 11   LGBMClassifier(boosting_type='goss', extra_tre...
# 12   LGBMClassifier(boosting_type='goss', extra_tre...
# 13   LGBMClassifier(boosting_type='goss', extra_tre...
# 14   LGBMClassifier(boosting_type='goss', extra_tre...
# 15   LGBMClassifier(boosting_type='goss', extra_tre...
# 16   LGBMClassifier(boosting_type='goss', extra_tre...
# 17   LGBMClassifier(boosting_type='goss', extra_tre...
# 18   LGBMClassifier(boosting_type='goss', extra_tre...
# 19   LGBMClassifier(boosting_type='goss', extra_tre...
# 20   LGBMClassifier(boosting_type='goss', extra_tre...
# 21   LGBMClassifier(boosting_type='goss', extra_tre...
# 22   LGBMClassifier(boosting_type='goss', extra_tre...
# 23   LGBMClassifier(boosting_type='goss', extra_tre...
# 24   LGBMClassifier(boosting_type='goss', extra_tre...
# 25   LGBMClassifier(boosting_type='goss', extra_tre...
# 26   LGBMClassifier(boosting_type='goss', extra_tre...
# 27   LGBMClassifier(boosting_type='goss', extra_tre...
# 28   LGBMClassifier(boosting_type='goss', extra_tre...
# 29   LGBMClassifier(boosting_type='goss', extra_tre...
# 30   LGBMClassifier(boosting_type='goss', extra_tre...
# 31   LGBMClassifier(boosting_type='goss', extra_tre...
# 32   LGBMClassifier(boosting_type='goss', extra_tre...
# 33   LGBMClassifier(boosting_type='goss', extra_tre...
# 34   LGBMClassifier(boosting_type='goss', extra_tre...
# 35   LGBMClassifier(boosting_type='goss', extra_tre...
# 36   LGBMClassifier(boosting_type='goss', extra_tre...
# 37   LGBMClassifier(boosting_type='goss', extra_tre...
# 38   LGBMClassifier(boosting_type='goss', extra_tre...
# 39   LGBMClassifier(boosting_type='goss', extra_tre...
# 40   LGBMClassifier(boosting_type='goss', extra_tre...
# 41   LGBMClassifier(boosting_type='goss', extra_tre...
# 42   LGBMClassifier(boosting_type='goss', extra_tre...
# 43   LGBMClassifier(boosting_type='goss', extra_tre...
# 44   LGBMClassifier(boosting_type='goss', extra_tre...
# 45   LGBMClassifier(boosting_type='goss', extra_tre...
# 46   LGBMClassifier(boosting_type='goss', extra_tre...
# 47   LGBMClassifier(boosting_type='goss', extra_tre...
# 48   LGBMClassifier(boosting_type='goss', extra_tre...
# 49   LGBMClassifier(boosting_type='goss', extra_tre...
# 50   LGBMClassifier(boosting_type='goss', extra_tre...
# 51   LGBMClassifier(boosting_type='goss', extra_tre...
# 52   LGBMClassifier(boosting_type='goss', extra_tre...
# 53   LGBMClassifier(boosting_type='goss', extra_tre...
# 54   LGBMClassifier(boosting_type='goss', extra_tre...
# 55   LGBMClassifier(boosting_type='goss', extra_tre...
# 56   LGBMClassifier(boosting_type='goss', extra_tre...
# 57   LGBMClassifier(boosting_type='goss', extra_tre...
# 58   LGBMClassifier(boosting_type='goss', extra_tre...
# 59   LGBMClassifier(boosting_type='goss', extra_tre...
# 60   LGBMClassifier(boosting_type='goss', extra_tre...
# 61   LGBMClassifier(boosting_type='goss', extra_tre...
# 62   LGBMClassifier(boosting_type='goss', extra_tre...
# 63   LGBMClassifier(boosting_type='goss', extra_tre...
# 64   LGBMClassifier(boosting_type='goss', extra_tre...
# 65   LGBMClassifier(boosting_type='goss', extra_tre...
# 66   LGBMClassifier(boosting_type='goss', extra_tre...
# 67   LGBMClassifier(boosting_type='goss', extra_tre...
# 68   LGBMClassifier(boosting_type='goss', extra_tre...
# 69   LGBMClassifier(boosting_type='goss', extra_tre...
# 70   LGBMClassifier(boosting_type='goss', extra_tre...
# 71   LGBMClassifier(boosting_type='goss', extra_tre...
# 72   LGBMClassifier(boosting_type='goss', extra_tre...
# 73   LGBMClassifier(boosting_type='goss', extra_tre...
# 74   LGBMClassifier(boosting_type='goss', extra_tre...
# 75   LGBMClassifier(boosting_type='goss', extra_tre...
# 76   LGBMClassifier(boosting_type='goss', extra_tre...
# 77   LGBMClassifier(boosting_type='goss', extra_tre...
# 78   LGBMClassifier(boosting_type='goss', extra_tre...
# 79   LGBMClassifier(boosting_type='goss', extra_tre...
# 80   LGBMClassifier(boosting_type='goss', extra_tre...
# 81   LGBMClassifier(boosting_type='goss', extra_tre...
# 82   LGBMClassifier(boosting_type='goss', extra_tre...
# 83   LGBMClassifier(boosting_type='goss', extra_tre...
# 84   LGBMClassifier(boosting_type='goss', extra_tre...
# 85   LGBMClassifier(boosting_type='goss', extra_tre...
# 86   LGBMClassifier(boosting_type='goss', extra_tre...
# 87   LGBMClassifier(boosting_type='goss', extra_tre...
# 88   LGBMClassifier(boosting_type='goss', extra_tre...
# 89   LGBMClassifier(boosting_type='goss', extra_tre...
# 90   LGBMClassifier(boosting_type='goss', extra_tre...
# 91   LGBMClassifier(boosting_type='goss', extra_tre...
# 92   LGBMClassifier(boosting_type='goss', extra_tre...
# 93   LGBMClassifier(boosting_type='goss', extra_tre...
# 94   LGBMClassifier(boosting_type='goss', extra_tre...
# 95   LGBMClassifier(boosting_type='goss', extra_tre...
# 96   LGBMClassifier(boosting_type='goss', extra_tre...
# 97   LGBMClassifier(boosting_type='goss', extra_tre...
# 98   LGBMClassifier(boosting_type='goss', extra_tre...
# 99   LGBMClassifier(boosting_type='goss', extra_tre...
# 100  LGBMClassifier(boosting_type='goss', extra_tre...
# 101  LGBMClassifier(boosting_type='goss', extra_tre...
# 102  LGBMClassifier(boosting_type='goss', extra_tre...
# 103  LGBMClassifier(boosting_type='goss', extra_tre...
# 104  LGBMClassifier(boosting_type='goss', extra_tre...
# 105  LGBMClassifier(boosting_type='goss', extra_tre...
# 106  LGBMClassifier(boosting_type='goss', extra_tre...
# 107  LGBMClassifier(boosting_type='goss', extra_tre...
# 108  LGBMClassifier(boosting_type='goss', extra_tre...
# 109  LGBMClassifier(boosting_type='goss', extra_tre...
# 110  LGBMClassifier(boosting_type='goss', extra_tre...
# 111  LGBMClassifier(boosting_type='goss', extra_tre...
# 112  LGBMClassifier(boosting_type='goss', extra_tre...
# 113  LGBMClassifier(boosting_type='goss', extra_tre...
# 114  LGBMClassifier(boosting_type='goss', extra_tre...
# 115  LGBMClassifier(boosting_type='goss', extra_tre...
# 116  LGBMClassifier(boosting_type='goss', extra_tre...
# 117  LGBMClassifier(boosting_type='goss', extra_tre...
# 118  LGBMClassifier(boosting_type='goss', extra_tre...
# 119  LGBMClassifier(boosting_type='goss', extra_tre...
# 120  LGBMClassifier(boosting_type='goss', extra_tre...
# 121  LGBMClassifier(boosting_type='goss', extra_tre...
# 122  LGBMClassifier(boosting_type='goss', extra_tre...
# 123  LGBMClassifier(boosting_type='goss', extra_tre...
# 124  LGBMClassifier(boosting_type='goss', extra_tre...
# 125  LGBMClassifier(boosting_type='goss', extra_tre...
# 126  LGBMClassifier(boosting_type='goss', extra_tre...
# 127  LGBMClassifier(boosting_type='goss', extra_tre...
# 128  LGBMClassifier(boosting_type='goss', extra_tre...
# 129  LGBMClassifier(boosting_type='goss', extra_tre...
# 130  LGBMClassifier(boosting_type='goss', extra_tre...
# 131  LGBMClassifier(boosting_type='goss', extra_tre...
# 132  LGBMClassifier(boosting_type='goss', extra_tre...
# 133  LGBMClassifier(boosting_type='goss', extra_tre...
# 134  LGBMClassifier(boosting_type='goss', extra_tre...
# 135  LGBMClassifier(boosting_type='goss', extra_tre...
# 136  LGBMClassifier(boosting_type='goss', extra_tre...
# 137  LGBMClassifier(boosting_type='goss', extra_tre...
# 138  LGBMClassifier(boosting_type='goss', extra_tre...
# 139  LGBMClassifier(boosting_type='goss', extra_tre...
# 140  LGBMClassifier(boosting_type='goss', extra_tre...
# 141  LGBMClassifier(boosting_type='goss', extra_tre...
# 142  LGBMClassifier(boosting_type='goss', extra_tre...
# 143  LGBMClassifier(boosting_type='goss', extra_tre...
# 144  LGBMClassifier(boosting_type='goss', extra_tre...
# 145  LGBMClassifier(boosting_type='goss', extra_tre...
# 146  LGBMClassifier(boosting_type='goss', extra_tre...
# 147  LGBMClassifier(boosting_type='goss', extra_tre...
# 148  LGBMClassifier(boosting_type='goss', extra_tre...
# 149  LGBMClassifier(boosting_type='goss', extra_tre...
# 150  LGBMClassifier(boosting_type='goss', extra_tre...
# 151  LGBMClassifier(boosting_type='goss', extra_tre...
# 152  LGBMClassifier(boosting_type='goss', extra_tre...
# 153  LGBMClassifier(boosting_type='goss', extra_tre...
# 154  LGBMClassifier(boosting_type='goss', extra_tre...
# 155  LGBMClassifier(boosting_type='goss', extra_tre...
# 156  LGBMClassifier(boosting_type='goss', extra_tre...
# 157  LGBMClassifier(boosting_type='goss', extra_tre...
# 158  LGBMClassifier(boosting_type='goss', extra_tre...
# 159  LGBMClassifier(boosting_type='goss', extra_tre...
# 160  LGBMClassifier(boosting_type='goss', extra_tre...
# 161  LGBMClassifier(boosting_type='goss', extra_tre...
# 162  LGBMClassifier(boosting_type='goss', extra_tre...
# 163  LGBMClassifier(boosting_type='goss', extra_tre...
# 164  LGBMClassifier(boosting_type='goss', extra_tre...
# 165  LGBMClassifier(boosting_type='goss', extra_tre...
# 166  LGBMClassifier(boosting_type='goss', extra_tre...
# 167  LGBMClassifier(boosting_type='goss', extra_tre...
# 168  LGBMClassifier(boosting_type='goss', extra_tre...
# 169  LGBMClassifier(boosting_type='goss', extra_tre...
# 170  LGBMClassifier(boosting_type='goss', extra_tre...
# 171  LGBMClassifier(boosting_type='goss', extra_tre...
# 172  LGBMClassifier(boosting_type='goss', extra_tre...
# 173  LGBMClassifier(boosting_type='goss', extra_tre...
# 174  LGBMClassifier(boosting_type='goss', extra_tre...
# 175  LGBMClassifier(boosting_type='goss', extra_tre...
# 176  LGBMClassifier(boosting_type='goss', extra_tre...
# 177  LGBMClassifier(boosting_type='goss', extra_tre...
# 178  LGBMClassifier(boosting_type='goss', extra_tre...
# 179  LGBMClassifier(boosting_type='goss', extra_tre...
# 180  LGBMClassifier(boosting_type='goss', extra_tre...
# 181  LGBMClassifier(boosting_type='goss', extra_tre...
# 182  LGBMClassifier(boosting_type='goss', extra_tre...
# 183  LGBMClassifier(boosting_type='goss', extra_tre...
# 184  LGBMClassifier(boosting_type='goss', extra_tre...
# 185  LGBMClassifier(boosting_type='goss', extra_tre...
# 186  LGBMClassifier(boosting_type='goss', extra_tre...
# 187  LGBMClassifier(boosting_type='goss', extra_tre...
# 188  LGBMClassifier(boosting_type='goss', extra_tre...
# 189  LGBMClassifier(boosting_type='goss', extra_tre...
# 190  LGBMClassifier(boosting_type='goss', extra_tre...
# 191  LGBMClassifier(boosting_type='goss', extra_tre...
# 192  LGBMClassifier(boosting_type='goss', extra_tre...
# 193  LGBMClassifier(boosting_type='goss', extra_tre...
# 194  LGBMClassifier(boosting_type='goss', extra_tre...
# 195  LGBMClassifier(boosting_type='goss', extra_tre...
# 196  LGBMClassifier(boosting_type='goss', extra_tre...
# 197  LGBMClassifier(boosting_type='goss', extra_tre...
# 198  LGBMClassifier(boosting_type='goss', extra_tre...
# 199  LGBMClassifier(boosting_type='goss', extra_tre...
# 200  LGBMClassifier(boosting_type='goss', extra_tre...
# 201  LGBMClassifier(boosting_type='goss', extra_tre...
# 202  LGBMClassifier(boosting_type='goss', extra_tre...
# 203  LGBMClassifier(boosting_type='goss', extra_tre...
# 204  LGBMClassifier(boosting_type='goss', extra_tre...
# 205  LGBMClassifier(boosting_type='goss', extra_tre...
# 206  LGBMClassifier(boosting_type='goss', extra_tre...
# 207  LGBMClassifier(boosting_type='goss', extra_tre...
# 208  LGBMClassifier(boosting_type='goss', extra_tre...
# 209  LGBMClassifier(boosting_type='goss', extra_tre...
# 210  LGBMClassifier(boosting_type='goss', extra_tre...
# 211  LGBMClassifier(boosting_type='goss', extra_tre...
# 212  LGBMClassifier(boosting_type='goss', extra_tre...
# 213  LGBMClassifier(boosting_type='goss', extra_tre...
# 214  LGBMClassifier(boosting_type='goss', extra_tre...
# 215  LGBMClassifier(boosting_type='goss', extra_tre...
#
#                                                model_2  \
# 0    LGBMClassifier(boosting_type='goss', extra_tre...
# 1    LGBMClassifier(boosting_type='goss', extra_tre...
# 2    LGBMClassifier(boosting_type='goss', extra_tre...
# 3    LGBMClassifier(boosting_type='goss', extra_tre...
# 4    LGBMClassifier(boosting_type='goss', extra_tre...
# 5    LGBMClassifier(boosting_type='goss', extra_tre...
# 6    LGBMClassifier(boosting_type='goss', extra_tre...
# 7    LGBMClassifier(boosting_type='goss', extra_tre...
# 8    LGBMClassifier(boosting_type='goss', extra_tre...
# 9    LGBMClassifier(boosting_type='goss', extra_tre...
# 10   LGBMClassifier(boosting_type='goss', extra_tre...
# 11   LGBMClassifier(boosting_type='goss', extra_tre...
# 12   LGBMClassifier(boosting_type='goss', extra_tre...
# 13   LGBMClassifier(boosting_type='goss', extra_tre...
# 14   LGBMClassifier(boosting_type='goss', extra_tre...
# 15   LGBMClassifier(boosting_type='goss', extra_tre...
# 16   LGBMClassifier(boosting_type='goss', extra_tre...
# 17   LGBMClassifier(boosting_type='goss', extra_tre...
# 18   LGBMClassifier(boosting_type='goss', extra_tre...
# 19   LGBMClassifier(boosting_type='goss', extra_tre...
# 20   LGBMClassifier(boosting_type='goss', extra_tre...
# 21   LGBMClassifier(boosting_type='goss', extra_tre...
# 22   LGBMClassifier(boosting_type='goss', extra_tre...
# 23   LGBMClassifier(boosting_type='goss', extra_tre...
# 24   LGBMClassifier(boosting_type='goss', extra_tre...
# 25   LGBMClassifier(boosting_type='goss', extra_tre...
# 26   LGBMClassifier(boosting_type='goss', extra_tre...
# 27   LGBMClassifier(boosting_type='goss', extra_tre...
# 28   LGBMClassifier(boosting_type='goss', extra_tre...
# 29   LGBMClassifier(boosting_type='goss', extra_tre...
# 30   LGBMClassifier(boosting_type='goss', extra_tre...
# 31   LGBMClassifier(boosting_type='goss', extra_tre...
# 32   LGBMClassifier(boosting_type='goss', extra_tre...
# 33   LGBMClassifier(boosting_type='goss', extra_tre...
# 34   LGBMClassifier(boosting_type='goss', extra_tre...
# 35   LGBMClassifier(boosting_type='goss', extra_tre...
# 36   LGBMClassifier(boosting_type='goss', extra_tre...
# 37   LGBMClassifier(boosting_type='goss', extra_tre...
# 38   LGBMClassifier(boosting_type='goss', extra_tre...
# 39   LGBMClassifier(boosting_type='goss', extra_tre...
# 40   LGBMClassifier(boosting_type='goss', extra_tre...
# 41   LGBMClassifier(boosting_type='goss', extra_tre...
# 42   LGBMClassifier(boosting_type='goss', extra_tre...
# 43   LGBMClassifier(boosting_type='goss', extra_tre...
# 44   LGBMClassifier(boosting_type='goss', extra_tre...
# 45   LGBMClassifier(boosting_type='goss', extra_tre...
# 46   LGBMClassifier(boosting_type='goss', extra_tre...
# 47   LGBMClassifier(boosting_type='goss', extra_tre...
# 48   LGBMClassifier(boosting_type='goss', extra_tre...
# 49   LGBMClassifier(boosting_type='goss', extra_tre...
# 50   LGBMClassifier(boosting_type='goss', extra_tre...
# 51   LGBMClassifier(boosting_type='goss', extra_tre...
# 52   LGBMClassifier(boosting_type='goss', extra_tre...
# 53   LGBMClassifier(boosting_type='goss', extra_tre...
# 54   LGBMClassifier(boosting_type='goss', extra_tre...
# 55   LGBMClassifier(boosting_type='goss', extra_tre...
# 56   LGBMClassifier(boosting_type='goss', extra_tre...
# 57   LGBMClassifier(boosting_type='goss', extra_tre...
# 58   LGBMClassifier(boosting_type='goss', extra_tre...
# 59   LGBMClassifier(boosting_type='goss', extra_tre...
# 60   LGBMClassifier(boosting_type='goss', extra_tre...
# 61   LGBMClassifier(boosting_type='goss', extra_tre...
# 62   LGBMClassifier(boosting_type='goss', extra_tre...
# 63   LGBMClassifier(boosting_type='goss', extra_tre...
# 64   LGBMClassifier(boosting_type='goss', extra_tre...
# 65   LGBMClassifier(boosting_type='goss', extra_tre...
# 66   LGBMClassifier(boosting_type='goss', extra_tre...
# 67   LGBMClassifier(boosting_type='goss', extra_tre...
# 68   LGBMClassifier(boosting_type='goss', extra_tre...
# 69   LGBMClassifier(boosting_type='goss', extra_tre...
# 70   LGBMClassifier(boosting_type='goss', extra_tre...
# 71   LGBMClassifier(boosting_type='goss', extra_tre...
# 72   LGBMClassifier(boosting_type='goss', extra_tre...
# 73   LGBMClassifier(boosting_type='goss', extra_tre...
# 74   LGBMClassifier(boosting_type='goss', extra_tre...
# 75   LGBMClassifier(boosting_type='goss', extra_tre...
# 76   LGBMClassifier(boosting_type='goss', extra_tre...
# 77   LGBMClassifier(boosting_type='goss', extra_tre...
# 78   LGBMClassifier(boosting_type='goss', extra_tre...
# 79   LGBMClassifier(boosting_type='goss', extra_tre...
# 80   LGBMClassifier(boosting_type='goss', extra_tre...
# 81   LGBMClassifier(boosting_type='goss', extra_tre...
# 82   LGBMClassifier(boosting_type='goss', extra_tre...
# 83   LGBMClassifier(boosting_type='goss', extra_tre...
# 84   LGBMClassifier(boosting_type='goss', extra_tre...
# 85   LGBMClassifier(boosting_type='goss', extra_tre...
# 86   LGBMClassifier(boosting_type='goss', extra_tre...
# 87   LGBMClassifier(boosting_type='goss', extra_tre...
# 88   LGBMClassifier(boosting_type='goss', extra_tre...
# 89   LGBMClassifier(boosting_type='goss', extra_tre...
# 90   LGBMClassifier(boosting_type='goss', extra_tre...
# 91   LGBMClassifier(boosting_type='goss', extra_tre...
# 92   LGBMClassifier(boosting_type='goss', extra_tre...
# 93   LGBMClassifier(boosting_type='goss', extra_tre...
# 94   LGBMClassifier(boosting_type='goss', extra_tre...
# 95   LGBMClassifier(boosting_type='goss', extra_tre...
# 96   LGBMClassifier(boosting_type='goss', extra_tre...
# 97   LGBMClassifier(boosting_type='goss', extra_tre...
# 98   LGBMClassifier(boosting_type='goss', extra_tre...
# 99   LGBMClassifier(boosting_type='goss', extra_tre...
# 100  LGBMClassifier(boosting_type='goss', extra_tre...
# 101  LGBMClassifier(boosting_type='goss', extra_tre...
# 102  LGBMClassifier(boosting_type='goss', extra_tre...
# 103  LGBMClassifier(boosting_type='goss', extra_tre...
# 104  LGBMClassifier(boosting_type='goss', extra_tre...
# 105  LGBMClassifier(boosting_type='goss', extra_tre...
# 106  LGBMClassifier(boosting_type='goss', extra_tre...
# 107  LGBMClassifier(boosting_type='goss', extra_tre...
# 108  LGBMClassifier(boosting_type='goss', extra_tre...
# 109  LGBMClassifier(boosting_type='goss', extra_tre...
# 110  LGBMClassifier(boosting_type='goss', extra_tre...
# ...
# 141      0.543626      0.523947      0.508076      0.500178      0.523871
# 142      0.543097      0.523947      0.509097      0.502543      0.524312
# 143      0.543097      0.523947      0.508803      0.501967      0.524150
# 144      0.525070      0.521368      0.508003      0.517276      0.503283
# 145      0.525581      0.522720      0.503393      0.516507      0.502951
# 146      0.521089      0.525869      0.507349      0.513845      0.504725
# 147      0.526378      0.522155      0.501832      0.513257      0.508598
# 148      0.521674      0.522155      0.503682      0.518592      0.505526
# 149      0.522723      0.520581      0.504476      0.518318      0.507545
# 150      0.520027      0.526228      0.507508      0.514720      0.506899
# 151      0.519516      0.521343      0.506577      0.515115      0.507308
# 152      0.527245      0.522637      0.505690      0.512885      0.503673
# 153      0.524019      0.521736      0.506513      0.515740      0.501010
# 154      0.522466      0.522481      0.506025      0.515509      0.505768
# 155      0.525460      0.522915      0.507369      0.511073      0.505700
# 156      0.524167      0.524461      0.503393      0.517806      0.501010
# 157      0.523762      0.524207      0.503647      0.515509      0.504409
# 158      0.525313      0.525499      0.505923      0.512007      0.503914
# 159      0.527254      0.525478      0.503985      0.514070      0.501679
# 160      0.523912      0.523840      0.503844      0.512039      0.502564
# 161      0.521833      0.521482      0.505527      0.515858      0.506577
# 162      0.523539      0.525107      0.506343      0.512403      0.506843
# 163      0.525086      0.524069      0.505860      0.514325      0.504908
# 164      0.523284      0.524832      0.505549      0.509981      0.501947
# 165      0.525869      0.523954      0.505434      0.511724      0.502117
# 166      0.519224      0.522892      0.504734      0.513053      0.507949
# 167      0.526169      0.521992      0.506622      0.510359      0.505851
# 168      0.519241      0.524167      0.502138      0.513280      0.504802
# 169      0.524297      0.518124      0.504313      0.510119      0.506301
# 170      0.526169      0.520059      0.505216      0.510808      0.508087
# 171      0.522326      0.521006      0.507379      0.512902      0.508870
# 172      0.523939      0.519961      0.503060      0.512157      0.506393
# 173      0.525499      0.524126      0.503113      0.506878      0.502933
# 174      0.521396      0.519618      0.507341      0.508562      0.506600
# 175      0.520640      0.522111      0.507023      0.512953      0.511427
# 176      0.525160      0.521006      0.507486      0.509224      0.508189
# 177      0.520609      0.520307      0.503513      0.514992      0.505959
# 178      0.523539      0.519910      0.505026      0.510110      0.503554
# 179      0.522043      0.521300      0.506582      0.511456      0.504460
# 180      0.525664      0.518274      0.505314      0.509071      0.500803
# 181      0.521034      0.520655      0.507451      0.511607      0.506193
# 182      0.525361      0.516641      0.505467      0.508712      0.504090
# 183      0.526169      0.520158      0.501809      0.509211      0.505004
# 184      0.524233      0.521400      0.503160      0.507468      0.504090
# 185      0.518952      0.520757      0.507233      0.513001      0.506462
# 186      0.520531      0.518027      0.505133      0.510272      0.509919
# 187      0.524626      0.519862      0.502909      0.506724      0.505378
# 188      0.522075      0.517192      0.501055      0.507990      0.507716
# 189      0.520245      0.521255      0.502108      0.511014      0.507037
# 190      0.516485      0.520068      0.506004      0.512902      0.506294
# 191      0.522326      0.515198      0.499454      0.509166      0.506088
# 192      0.518836      0.509506      0.500271      0.502346      0.501269
# 193      0.519312      0.509506      0.501302      0.504555      0.501111
# 194      0.514543      0.510147      0.497166      0.502735      0.504831
# 195      0.518526      0.513581      0.502117      0.505537      0.502514
# 196      0.514476      0.514283      0.500694      0.500881      0.504155
# 197      0.516913      0.513579      0.499363      0.504092      0.505620
# 198      0.514680      0.514581      0.504908      0.503630      0.501336
# 199      0.511440      0.513988      0.498632      0.507871      0.501336
# 200      0.513328      0.506878      0.498822      0.507695      0.503102
# 201      0.517175      0.513348      0.497702      0.502503      0.505884
# 202      0.514443      0.512240      0.497639      0.502841      0.502426
# 203      0.516913      0.510785      0.502831      0.505537      0.505019
# 204      0.516130      0.512589      0.499468      0.501654      0.503893
# 205      0.515994      0.511541      0.498161      0.498643      0.505884
# 206      0.514071      0.509683      0.501560      0.501012      0.502675
# 207      0.515085      0.509506      0.498458      0.500574      0.502067
# 208      0.512450      0.514161      0.499059      0.504775      0.504721
# 209      0.512281      0.513643      0.504741      0.502808      0.504343
# 210      0.514611      0.511892      0.495526      0.504041      0.505620
# 211      0.512855      0.511949      0.502016      0.502988      0.503254
# 212      0.515085      0.512181      0.503307      0.503788      0.503479
# 213      0.514918      0.514924      0.501417      0.505714      0.501408
# 214      0.513397      0.514752      0.500248      0.503399      0.504684
# 215      0.515538      0.512707      0.501370      0.505827      0.501561
#
#      model_16_mcc  model_17_mcc  average_mcc
# 0        0.525021      0.509318     0.522314
# 1        0.522201      0.510380     0.522148
# 2        0.523976      0.510355     0.522069
# 3        0.523642      0.509324     0.521977
# 4        0.522537      0.511070     0.521973
# 5        0.523976      0.508289     0.521955
# 6        0.523642      0.508282     0.521948
# 7        0.523226      0.512082     0.521933
# 8        0.521848      0.510365     0.521890
# 9        0.522184      0.510022     0.521805
# 10       0.523226      0.511051     0.521780
# 11       0.522220      0.511399     0.521744
# 12       0.521848      0.511405     0.521733
# 13       0.523642      0.509314     0.521689
# 14       0.524288      0.508657     0.521647
# 15       0.522910      0.511742     0.521622
# 16       0.522873      0.510022     0.521609
# 17       0.522873      0.511399     0.521543
# 18       0.522184      0.510372     0.521511
# 19       0.523265      0.508975     0.521460
# 20       0.522201      0.511044     0.521384
# 21       0.524332      0.509314     0.521381
# 22       0.522201      0.511399     0.521380
# 23       0.519411      0.512361     0.521344
# 24       0.521512      0.511742     0.521201
# 25       0.521737      0.509875     0.520976
# 26       0.522227      0.512289     0.520962
# 27       0.523446      0.509911     0.520916
# 28       0.519123      0.507802     0.520915
# 29       0.523446      0.509551     0.520905
# 30       0.520522      0.511389     0.520890
# 31       0.519795      0.511463     0.520806
# 32       0.518564      0.513776     0.520789
# 33       0.522769      0.508620     0.520785
# 34       0.521741      0.509551     0.520769
# 35       0.520159      0.512361     0.520748
# 36       0.523445      0.508258     0.520704
# 37       0.518622      0.510418     0.520683
# 38       0.519795      0.512961     0.520671
# 39       0.522762      0.508904     0.520613
# 40       0.520716      0.508620     0.520610
# 41       0.521741      0.509551     0.520610
# 42       0.522762      0.507822     0.520580
# 43       0.521061      0.508437     0.520539
# 44       0.520031      0.509948     0.520501
# 45       0.520371      0.509021     0.520483
# 46       0.523113      0.508659     0.520454
# 47       0.521741      0.508471     0.520446
# 48       0.520159      0.508999     0.520432
# 49       0.521557      0.509828     0.520421
# 50       0.522085      0.508904     0.520410
# 51       0.521052      0.508904     0.520409
# 52       0.520159      0.509073     0.520360
# 53       0.521401      0.507292     0.520319
# 54       0.521401      0.505730     0.520275
# 55       0.521737      0.509911     0.520263
# 56       0.522078      0.507897     0.520259
# 57       0.523105      0.509122     0.520245
# 58       0.516912      0.511835     0.520232
# 59       0.517835      0.509599     0.520200
# 60       0.517278      0.511689     0.520186
# 61       0.522081      0.507897     0.520186
# 62       0.520159      0.507128     0.520152
# 63       0.522762      0.506091     0.519894
# 64       0.521447      0.511238     0.519707
# 65       0.517092      0.515947     0.519218
# 66       0.520522      0.512961     0.519071
# 67       0.518396      0.513404     0.518888
# 68       0.520522      0.512289     0.518837
# 69       0.520215      0.512661     0.518756
# 70       0.516725      0.512590     0.518752
# 71       0.516725      0.510418     0.518601
# 72       0.516229      0.517393     0.518336
# 73       0.513784      0.520107     0.518299
# 74       0.514065      0.514751     0.518124
# 75       0.518309      0.514897     0.517937
# 76       0.512178      0.520469     0.517870
# 77       0.512279      0.513429     0.517827
# 78       0.510217      0.517569     0.517678
# 79       0.513022      0.515516     0.517648
# 80       0.512641      0.516425     0.517575
# 81       0.514165      0.517218     0.517520
# 82       0.514926      0.518610     0.517517
# 83       0.515572      0.515690     0.517438
# 84       0.514628      0.516146     0.517413
# 85       0.515488      0.517705     0.517375
# 86       0.512077      0.519168     0.517358
# 87       0.514628      0.513534     0.517343
# 88       0.516614      0.514195     0.517307
# 89       0.512560      0.516176     0.517267
# 90       0.519065      0.515412     0.517241
# 91       0.509171      0.515899     0.517204
# 92       0.516703      0.514195     0.517140
# 93       0.513503      0.509778     0.517082
# 94       0.509628      0.513085     0.517038
# 95       0.517270      0.515205     0.517013
# 96       0.516420      0.513917     0.516950
# 97       0.511215      0.515005     0.516925
# 98       0.516050      0.513685     0.516873
# 99       0.515510      0.514368     0.516772
# 100      0.512690      0.517774     0.516693
# 101      0.515290      0.514130     0.516686
# 102      0.513503      0.515238     0.516497
# 103      0.514952      0.513685     0.516373
# 104      0.511542      0.512595     0.516303
# 105      0.516629      0.513192     0.516264
# 106      0.514221      0.513794     0.516243
# 107      0.512866      0.516664     0.516231
# 108      0.509316      0.512978     0.516227
# 109      0.513527      0.514090     0.516201
# 110      0.512866      0.517218     0.516032
# 111      0.517390      0.512640     0.515976
# 112      0.508063      0.512164     0.515893
# 113      0.507329      0.512705     0.515827
# 114      0.511856      0.515485     0.515780
# 115      0.515510      0.512978     0.515773
# 116      0.508796      0.512107     0.515763
# 117      0.504560      0.512530     0.515709
# 118      0.506594      0.511984     0.515706
# 119      0.514468      0.512595     0.515696
# 120      0.507958      0.509334     0.515608
# 121      0.514086      0.514023     0.515582
# 122      0.506768      0.514819     0.515550
# 123      0.515769      0.514961     0.515545
# 124      0.508063      0.511563     0.515540
# 125      0.511439      0.514300     0.515515
# 126      0.509051      0.513972     0.515503
# 127      0.508516      0.512164     0.515498
# 128      0.508237      0.512705     0.515481
# 129      0.508970      0.511563     0.515474
# 130      0.508136      0.512164     0.515448
# 131      0.513807      0.514473     0.515440
# 132      0.507329      0.509820     0.515422
# 133      0.505578      0.511184     0.515397
# 134      0.507503      0.515375     0.515364
# 135      0.510533      0.514345     0.515320
# 136      0.505578      0.512406     0.515307
# 137      0.508692      0.511984     0.515300
# 138      0.508796      0.511864     0.515255
# 139      0.507782      0.513127     0.515231
# 140      0.508516      0.510002     0.515190
# 141      0.507782      0.510002     0.515189
# 142      0.504671      0.512232     0.515135
# 143      0.504671      0.510573     0.515123
# 144      0.515190      0.507684     0.511488
# 145      0.512885      0.503414     0.511285
# 146      0.512606      0.503396     0.511157
# 147      0.512606      0.507494     0.511157
# 148      0.508357      0.504713     0.510991
# 149      0.509008      0.508182     0.510926
# 150      0.514952      0.503237     0.510916
# 151      0.514580      0.507588     0.510908
# 152      0.512350      0.506597     0.510907
# 153      0.509945      0.508582     0.510880
# 154      0.513631      0.505298     0.510834
# 155      0.514440      0.506385     0.510833
# 156      0.513535      0.507648     0.510819
# 157      0.509885      0.503571     0.510798
# 158      0.512350      0.506289     0.510772
# 159      0.509745      0.510129     0.510756
# 160      0.510792      0.507187     0.510756
# 161      0.510168      0.506103     0.510746
# 162      0.512862      0.506845     0.510689
# 163      0.511724      0.502854     0.510655
# 164      0.517902      0.503414     0.510597
# 165      0.511935      0.504132     0.510568
# 166      0.506690      0.506634     0.510381
# 167      0.510486      0.500717     0.510144
# 168      0.512149      0.506330     0.510072
# 169      0.514211      0.498214     0.510046
# 170      0.511930      0.502825     0.510000
# 171      0.514779      0.500874     0.509857
# 172      0.510509      0.502008     0.509820
# 173      0.513734      0.504035     0.509808
# 174      0.512435      0.505087     0.509792
# 175      0.513662      0.502419     0.509634
# 176      0.511028      0.500641     0.509622
# 177      0.512658      0.504035     0.509523
# 178      0.513845      0.504196     0.509506
# 179      0.509517      0.504763     0.509427
# 180      0.510921      0.502334     0.509403
# 181      0.510860      0.501849     0.509298
# 182      0.512763      0.502091     0.509277
# 183      0.511214      0.504526     0.509261
# 184      0.513085      0.502027     0.509177
# 185      0.514922      0.503067     0.509150
# 186      0.511968      0.506308     0.509025
# 187      0.510233      0.501787     0.509013
# 188      0.513228      0.500795     0.508984
# 189      0.511822      0.507190     0.508793
# 190      0.514562      0.504683     0.508758
# 191      0.513954      0.500566     0.508638
# 192      0.510396      0.494544     0.504318
# 193      0.509899      0.493068     0.504282
# 194      0.511187      0.491401     0.504266
# 195      0.507512      0.494428     0.504027
# 196      0.506799      0.498177     0.503929
# 197      0.509109      0.489696     0.503781
# 198      0.512953      0.488982     0.503774
# 199      0.511830      0.495259     0.503692
# 200      0.509991      0.493676     0.503690
# 201      0.508324      0.494092     0.503639
# 202      0.510230      0.494694     0.503603
# 203      0.510708      0.490531     0.503536
# 204      0.509038      0.496395     0.503497
# 205      0.507512      0.491628     0.503447
# 206      0.502866      0.495109     0.503443
# 207      0.507583      0.493747     0.503402
# 208      0.509974      0.492044     0.503331
# 209      0.508394      0.494962     0.503260
# 210      0.510455      0.492008     0.503242
# 211      0.508562      0.492271     0.503203
# 212      0.511099      0.496317     0.503041
# 213      0.509825      0.490879     0.502933
# 214      0.509647      0.490203     0.502583
# 215      0.507988      0.489592     0.502503

# %%
pd.set_option('display.max_row', 10)

# %%
from sklearn.metrics import classification_report, f1_score, confusion_matrix, precision_score, matthews_corrcoef

def predict(X, mode='best_mean'):
    if mode == 'best_mode':
        y_preds = []
        for i in range(sum(K)):
            y_preds.append(df_model.loc[0, f'model_{i}'].predict(X))
        y_preds = np.array(y_preds)
        y_preds = scipy.stats.mode(y_preds)
        y_preds = y_preds[0]
        y_preds = y_preds.reshape(-1)
    elif mode == 'best_mean':
        y_preds = []
        for i in range(sum(K)):
            y_preds.append(df_model.loc[0, f'model_{i}'].predict_proba(X))
        y_preds = np.mean(np.array(y_preds), axis=0)
        y_preds = np.argmax(y_preds, axis=-1)
    elif mode == 'ensemble_mode':
        y_preds = []
        for i in df_model.index:
            for j in range(sum(K)):
                y_preds.append(df_model.loc[i, f'model_{j}'].predict(X))
        y_preds = np.array(y_preds)
        y_preds = scipy.stats.mode(y_preds)
        y_preds = y_preds[0]
        y_preds = y_preds.reshape(-1)
    elif mode == 'ensemble_mean':
        y_preds = []
        for i in df_model.index:
            for j in range(sum(K)):
                y_preds.append(df_model.loc[i, f'model_{j}'].predict_proba(X))
        y_preds = np.mean(np.array(y_preds), axis=0)
        y_preds = np.argmax(y_preds, axis=-1)
    elif mode == 'weighted_ensemble_mean':
        y_preds = []
#         model_weight = df_model['average_mcc'].apply(lambda a: a/df_model['average_mcc'].sum())
        model_weight = []
        for i in df_model.index:
            model_weight.append(1 + np.log10(df_model.shape[0] - i + 1))
        print(model_weight[:10])
        for i in df_model.index:
            for j in range(sum(K)):
                y_preds.append(
                    df_model.loc[i, f'model_{j}'].predict_proba(X) *
                    model_weight[i]
                )
        y_preds = np.array(y_preds)
        y_preds = np.mean(y_preds, axis=0)
        y_preds = np.argmax(y_preds, axis=-1)
    else:
        raise ValueError("Mode isn't supported")
    
    return y_preds

def metrics(y_true, y_pred):
    print('Weighted F1 Score :', f1_score(y_true, y_pred, average='weighted'))
    print('MCC Score :', matthews_corrcoef(y_true, y_pred))
    cm = confusion_matrix(y_true, y_pred)
    cm = pd.DataFrame(cm, [0, 1], [0, 1])

    sns.heatmap(cm, annot=True, cmap="YlGnBu", fmt="d")
    plt.show()

# %%
y_train_pred = predict(X_train, mode='best_mode')
metrics(y_train, y_train_pred)
# Out:
# Weighted F1 Score : 0.8766270648125604
# MCC Score : 0.5300845659344611

# %%
y_train_pred2 = predict(X_train, mode='best_mean')
metrics(y_train, y_train_pred2)
# Out:
# Weighted F1 Score : 0.87649259328918
# MCC Score : 0.5296909452324555

# %%
y_train_pred3 = predict(X_train, mode='ensemble_mode')
metrics(y_train, y_train_pred3)
# Out:
# Weighted F1 Score : 0.8692859466878633
# MCC Score : 0.5329133215265088

# %%
y_train_pred4 = predict(X_train, mode='ensemble_mean')
metrics(y_train, y_train_pred4)
# Out:
# Weighted F1 Score : 0.8700895751893908
# MCC Score : 0.5348356539094019

# %%
y_train_pred5 = predict(X_train, mode='weighted_ensemble_mean')
metrics(y_train, y_train_pred5)
# Out:
# [3.3364597338485296, 3.3344537511509307, 3.3324384599156054, 3.330413773349191, 3.3283796034387376, 3.3263358609287517, 3.3242824552976926, 3.322219294733919, 3.320146286111054, 3.3180633349627615]
# Weighted F1 Score : 0.8712748889986816
# MCC Score : 0.5358505953620997

# %% [markdown]
# # Test

# %%
y_test_pred = predict(X_test, mode='best_mode')

df_submission = pd.concat([pd.Series(list(range(0, len(X_test))), name='row_id', dtype=np.int32), pd.Series(y_test_pred, name='open_flag')], axis=1)
df_submission.to_csv('submission_best_mode.csv', index=False)

df_submission
# Out:
#        row_id  open_flag
# 0           0          0
# 1           1          0
# 2           2          0
# 3           3          0
# 4           4          0
# ...       ...        ...
# 55965   55965          0
# 55966   55966          0
# 55967   55967          0
# 55968   55968          0
# 55969   55969          1
#
# [55970 rows x 2 columns]

# %%
y_test_pred2 = predict(X_test, mode='best_mean')

df_submission = pd.concat([pd.Series(list(range(0, len(X_test))), name='row_id', dtype=np.int32), pd.Series(y_test_pred2, name='open_flag')], axis=1)
df_submission.to_csv('submission_best_mean.csv', index=False)

df_submission
# Out:
#        row_id  open_flag
# 0           0          0
# 1           1          0
# 2           2          0
# 3           3          0
# 4           4          0
# ...       ...        ...
# 55965   55965          0
# 55966   55966          0
# 55967   55967          0
# 55968   55968          0
# 55969   55969          1
#
# [55970 rows x 2 columns]

# %%
y_test_pred3 = predict(X_test, mode='ensemble_mode')

df_submission = pd.concat([pd.Series(list(range(0, len(X_test))), name='row_id', dtype=np.int32), pd.Series(y_test_pred3, name='open_flag')], axis=1)
df_submission.to_csv('submission_ensemble_mode.csv', index=False)

df_submission
# Out:
#        row_id  open_flag
# 0           0          0
# 1           1          0
# 2           2          0
# 3           3          0
# 4           4          0
# ...       ...        ...
# 55965   55965          0
# 55966   55966          0
# 55967   55967          0
# 55968   55968          1
# 55969   55969          1
#
# [55970 rows x 2 columns]

# %%
y_test_pred4 = predict(X_test, mode='ensemble_mean')

df_submission = pd.concat([pd.Series(list(range(0, len(X_test))), name='row_id', dtype=np.int32), pd.Series(y_test_pred4, name='open_flag')], axis=1)
df_submission.to_csv('submission_ensemble_mean.csv', index=False)

df_submission
# Out:
#        row_id  open_flag
# 0           0          0
# 1           1          0
# 2           2          0
# 3           3          0
# 4           4          0
# ...       ...        ...
# 55965   55965          0
# 55966   55966          0
# 55967   55967          0
# 55968   55968          1
# 55969   55969          1
#
# [55970 rows x 2 columns]

# %%
y_test_pred5 = predict(X_test, mode='weighted_ensemble_mean')

df_submission = pd.concat([pd.Series(list(range(0, len(X_test))), name='row_id', dtype=np.int32), pd.Series(y_test_pred5, name='open_flag')], axis=1)
df_submission.to_csv('submission_weighted_ensemble_mean.csv', index=False)

df_submission
# Out:
# [3.3364597338485296, 3.3344537511509307, 3.3324384599156054, 3.330413773349191, 3.3283796034387376, 3.3263358609287517, 3.3242824552976926, 3.322219294733919, 3.320146286111054, 3.3180633349627615]
#        row_id  open_flag
# 0           0          0
# 1           1          0
# 2           2          0
# 3           3          0
# 4           4          0
# ...       ...        ...
# 55965   55965          0
# 55966   55966          0
# 55967   55967          0
# 55968   55968          1
# 55969   55969          1
#
# [55970 rows x 2 columns]

# %% [markdown]
# # Visualize

# %%
lgbm.plot_importance(df_model.loc[0, 'model_0'], ignore_zero=False, figsize=(16,9))

# %%
lgbm.plot_split_value_histogram(df_model.loc[0, 'model_0'], 2)
