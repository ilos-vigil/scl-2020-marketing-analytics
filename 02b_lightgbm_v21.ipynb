# %% [markdown]
# # Changelog
#
# ## Version 21
#
# * Tuning LightGBM parameter from version 20 result
#     * lambda pair : [0.0, 0.0], [0.001, 0.01], [0.01, 0.1], [0.01, 1.0], [1.0, 0.01]
# * Try different boosting_type
# * Change formula for weighted ensemble mean
# * Use 3 & 5 StratifiedKFold
#
# ## Version 20
#
# * Tuning LightGBM parameter from version 18 result
# * Stop using validation data
#
# ## Version 18
#
# * Tuning LightGBM parameter from version 16 result
#     * num_leaves : 63
#     * min_data_in_leaf : 20, 50
#     * bagging_fraction : **no diff**
#     * feature_fraction : 0.9, 1.0
#     * max_bin : 16, 102, 255
#     * min_data_per_group : 1
# * Use validation data to reduce overfit
#
# ## Version 16
#
# * Tuning LightGBM parameter from version 15 result
#     * boosting_type : gbdt
#     * n_estimators : 100
#     * LR : 0.01
#     * num_leaves : 31, 63
#     * min_data_in_leaf : 20, 50
#
# ## Version 15
#
# * Make submission for all mode
# * Fix dump `df_model`
# * Remove `age` from category feature
#
# ## Version 13
#
# * Tuning LightGBM parameter
# * Add additional preprocessing
# * Add EDA
#
# ## Version 10
#
# * Add additional preprocessing
#
# ## Version 9
#
# * Use StratifiedKFold 3, 5, 10
# * Combine parameter from verison 4 & 5
# * Use mean and mode to predict data
#
# ## Version 5
#
# * Use MCC score
# * Visualize LightGBM tree
# * Use different processed dataset
# * Specify categorical feature
# * Tweak parameter
#
# ## Version 4
#
# * Attempt fix overfit
# * Tweak class weight
#
# ## Version 2
#
# * Fix wrong row
# * Lower `max_bin` 255 -> 64
# * Increase `num_iterations` 5000 -> 10000
#
# ## Version 1
#
# * Initial Code

# %% [markdown]
# # Library

# %%
import os
import random
import platform
import itertools

import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import lightgbm as lgbm
import scipy

# %%
# !pip freeze > requirements.txt

# %%
print('Python version:', platform.python_version())
print('Numpy version:', np.__version__)
print('Pandas version:', pd.__version__)
print('Matplotlib version:', matplotlib.__version__)
print('Seaborn version:', sns.__version__)
print('Scikit-Learn version:', sklearn.__version__)
print('LightGBM version:', lgbm.__version__)
print('Scipy version:', scipy.__version__)
# Out:
# Python version: 3.7.6
# Numpy version: 1.18.5
# Pandas version: 1.0.3
# Matplotlib version: 3.2.1
# Seaborn version: 0.10.0
# Scikit-Learn version: 0.23.1
# LightGBM version: 2.3.1
# Scipy version: 1.4.1

# %%
SEED = 42

os.environ['PYTHONHASHSEED']=str(SEED)
random.seed(SEED)
np.random.seed(SEED)

# %%
pd.set_option('display.width', None)
pd.set_option('display.max_column', None)

# %% [markdown]
# # Processed Dataset

# %%
df_train = pd.read_parquet('/kaggle/input/shopee-marketing-data/train_processed.parquet')
df_train
# Out:
#        country_code                 grass_date  subject_line_length  \
# 0                 4  2019-07-16 00:00:00+08:00                   44
# 1                 4  2019-07-16 00:00:00+08:00                   44
# 2                 6  2019-07-16 00:00:00+08:00                   49
# 3                 1  2019-07-16 00:00:00+08:00                   49
# 4                 6  2019-07-16 00:00:00+08:00                   49
# ...             ...                        ...                  ...
# 73534             6  2019-09-02 00:00:00+08:00                   39
# 73535             2  2019-09-02 00:00:00+08:00                   38
# 73536             2  2019-09-02 00:00:00+08:00                   32
# 73537             2  2019-09-02 00:00:00+08:00                   38
# 73538             6  2019-09-02 00:00:00+08:00                   39
#
#        last_open_day  last_login_day  last_checkout_day  \
# 0               19.0             6.0               18.0
# 1                9.0             4.0                8.0
# 2               14.0             5.0                5.0
# 3               49.0             9.0               53.0
# 4              227.0             6.0              221.0
# ...              ...             ...                ...
# 73534           24.0            36.0              279.0
# 73535           46.0            10.0               51.0
# 73536            NaN             NaN                NaN
# 73537            5.0            34.0                NaN
# 73538            1.0             3.0                NaN
#
#        open_count_last_10_days  open_count_last_30_days  \
# 0                            0                        2
# 1                            2                        9
# 2                            0                        4
# 3                            0                        0
# 4                            0                        0
# ...                        ...                      ...
# 73534                        0                        1
# 73535                        0                        0
# 73536                        0                        0
# 73537                        2                        4
# 73538                        2                        2
#
#        open_count_last_60_days  login_count_last_10_days  \
# 0                            4                        12
# 1                           17                        18
# 2                           12                        24
# 3                            1                         9
# 4                            0                         2
# ...                        ...                       ...
# 73534                        1                         0
# 73535                        1                         0
# 73536                        0                         0
# 73537                        4                         0
# 73538                        3                         0
#
#        login_count_last_30_days  login_count_last_60_days  \
# 0                            43                        99
# 1                            48                        90
# 2                            69                       119
# 3                            23                        69
# 4                             5                         5
# ...                         ...                       ...
# 73534                         0                         0
# 73535                         0                         0
# 73536                         0                         0
# 73537                         0                         0
# 73538                         0                         0
#
#        checkout_count_last_10_days  checkout_count_last_30_days  \
# 0                                0                            5
# 1                                1                            1
# 2                                5                           19
# 3                                1                            3
# 4                                0                            0
# ...                            ...                          ...
# 73534                            0                            0
# 73535                            0                            0
# 73536                            0                            0
# 73537                            0                            0
# 73538                            0                            0
#
#        checkout_count_last_60_days  open_flag  attr_1  attr_2  attr_3   age  \
# 0                               10          0     1.0     1.0     2.0  47.0
# 1                                4          1     1.0     1.0     2.0  25.0
# 2                               27          0     NaN     1.0     0.0   NaN
# 3                                6          0     1.0     1.0     2.0  24.0
# 4                                0          0     NaN     1.0     0.0   NaN
# ...                            ...        ...     ...     ...     ...   ...
# 73534                            0          0     1.0     1.0     1.0  37.0
# 73535                            0          0     NaN     1.0     0.0   NaN
# 73536                            0          0     NaN     1.0     0.0   NaN
# 73537                            0          1     NaN     1.0     0.0   NaN
# 73538                            0          0     NaN     1.0     0.0   NaN
#
#        domain
# 0         0.0
# 1         3.0
# 2         2.0
# 3         2.0
# 4         3.0
# ...       ...
# 73534     0.0
# 73535     0.0
# 73536     9.0
# 73537     0.0
# 73538     0.0
#
# [73539 rows x 21 columns]

# %%
df_test = pd.read_parquet('/kaggle/input/shopee-marketing-data/test_processed.parquet')
df_test
# Out:
#        country_code                 grass_date  subject_line_length  \
# 0                 6  2019-09-03 00:00:00+08:00                   35
# 1                 6  2019-09-03 00:00:00+08:00                   35
# 2                 5  2019-09-03 00:00:00+08:00                   25
# 3                 1  2019-09-03 00:00:00+08:00                   36
# 4                 5  2019-09-03 00:00:00+08:00                   23
# ...             ...                        ...                  ...
# 55965             6  2019-09-29 00:00:00+08:00                   53
# 55966             6  2019-09-29 00:00:00+08:00                   53
# 55967             6  2019-09-29 00:00:00+08:00                   43
# 55968             6  2019-09-29 00:00:00+08:00                   43
# 55969             6  2019-09-29 00:00:00+08:00                   53
#
#        last_open_day  last_login_day  last_checkout_day  \
# 0               27.0             2.0               13.0
# 1                7.0             5.0              383.0
# 2               34.0             1.0                3.0
# 3               63.0             5.0                5.0
# 4                6.0             5.0               54.0
# ...              ...             ...                ...
# 55965            NaN             4.0                8.0
# 55966           59.0           802.0             1207.0
# 55967            NaN             7.0                NaN
# 55968            5.0             5.0                6.0
# 55969            5.0             3.0               20.0
#
#        open_count_last_10_days  open_count_last_30_days  \
# 0                            2                        3
# 1                            1                        1
# 2                            0                        0
# 3                            0                        0
# 4                            0                        0
# ...                        ...                      ...
# 55965                        0                        0
# 55966                        0                        0
# 55967                        0                        0
# 55968                        2                        5
# 55969                        2                       14
#
#        open_count_last_60_days  login_count_last_10_days  \
# 0                            4                        10
# 1                            1                         5
# 2                            0                        13
# 3                            0                        43
# 4                            0                         4
# ...                        ...                       ...
# 55965                        0                         0
# 55966                        1                         0
# 55967                        0                         0
# 55968                       14                         0
# 55969                       27                         0
#
#        login_count_last_30_days  login_count_last_60_days  \
# 0                            34                       134
# 1                             5                         5
# 2                            19                        38
# 3                           110                       173
# 4                            12                        39
# ...                         ...                       ...
# 55965                         0                         0
# 55966                         0                         0
# 55967                         0                         0
# 55968                         0                         0
# 55969                         0                         0
#
#        checkout_count_last_10_days  checkout_count_last_30_days  \
# 0                                0                            6
# 1                                0                            0
# 2                                2                            2
# 3                                2                            5
# 4                                0                            0
# ...                            ...                          ...
# 55965                            0                            0
# 55966                            0                            0
# 55967                            0                            0
# 55968                            0                            0
# 55969                            0                            0
#
#        checkout_count_last_60_days  attr_1  attr_2  attr_3   age  domain
# 0                               18     NaN     1.0     0.0   NaN     0.0
# 1                                0     NaN     1.0     0.0   NaN     0.0
# 2                                2     1.0     1.0     2.0  33.0     0.0
# 3                                5     1.0     1.0     2.0  22.0     2.0
# 4                                2     NaN     1.0     0.0   NaN     0.0
# ...                            ...     ...     ...     ...   ...     ...
# 55965                            0     NaN     1.0     0.0   NaN     3.0
# 55966                            0     NaN     1.0     0.0   NaN     0.0
# 55967                            0     NaN     1.0     0.0   NaN     0.0
# 55968                            0     NaN     NaN     NaN   NaN     NaN
# 55969                            0     NaN     NaN     NaN   NaN     NaN
#
# [55970 rows x 20 columns]

# %% [markdown]
# # EDA

# %%
df_train.describe()
# Out:
#        country_code  subject_line_length  last_open_day  last_login_day  \
# count  73539.000000         73539.000000    66021.00000    73260.000000
# mean       2.533159            43.656373       32.75323       53.335695
# std        1.675251            11.219323       55.16675      345.223999
# min        1.000000            10.000000        1.00000        0.000000
# 25%        1.000000            34.000000        5.00000        3.000000
# 50%        2.000000            43.000000       14.00000        8.000000
# 75%        3.000000            52.000000       38.00000       26.000000
# max        7.000000            75.000000      808.00000    18141.000000
#
#        last_checkout_day  open_count_last_10_days  open_count_last_30_days  \
# count       56634.000000             73539.000000             73539.000000
# mean           73.645725                 0.911829                 2.780457
# std           129.415239                 1.754052                 4.570239
# min             1.000000                 0.000000                 0.000000
# 25%             7.000000                 0.000000                 0.000000
# 50%            22.000000                 0.000000                 1.000000
# 75%            77.000000                 1.000000                 3.000000
# max          1445.000000                31.000000                92.000000
#
#        open_count_last_60_days  login_count_last_10_days  \
# count             73539.000000              73539.000000
# mean                  5.019364                  8.382287
# std                   7.902313                 13.424436
# min                   0.000000                  0.000000
# 25%                   0.000000                  0.000000
# 50%                   2.000000                  3.000000
# 75%                   6.000000                 12.000000
# max                 135.000000                254.000000
#
#        login_count_last_30_days  login_count_last_60_days  \
# count              73539.000000              73539.000000
# mean                  25.284053                 49.010430
# std                   37.853189                 71.819327
# min                    0.000000                  0.000000
# 25%                    1.000000                  3.000000
# 50%                   11.000000                 22.000000
# 75%                   35.000000                 69.000000
# max                  735.000000               1260.000000
#
#        checkout_count_last_10_days  checkout_count_last_30_days  \
# count                 73539.000000                 73539.000000
# mean                      0.909898                     2.796040
# std                       2.887416                     7.686064
# min                       0.000000                     0.000000
# 25%                       0.000000                     0.000000
# 50%                       0.000000                     0.000000
# 75%                       1.000000                     3.000000
# max                     157.000000                   531.000000
#
#        checkout_count_last_60_days     open_flag        attr_1        attr_2  \
# count                 73539.000000  73539.000000  45758.000000  73287.000000
# mean                      5.420960      0.155781      0.999847      0.997912
# std                      13.980182      0.362650      0.012368      0.045644
# min                       0.000000      0.000000      0.000000      0.000000
# 25%                       0.000000      0.000000      1.000000      1.000000
# 50%                       1.000000      0.000000      1.000000      1.000000
# 75%                       6.000000      0.000000      1.000000      1.000000
# max                     783.000000      1.000000      1.000000      1.000000
#
#              attr_3           age        domain
# count  73518.000000  45758.000000  73518.000000
# mean       1.087230     31.348464      0.434166
# std        1.033832     11.584066      1.259629
# min        0.000000    -16.000000      0.000000
# 25%        0.000000     24.000000      0.000000
# 50%        1.000000     29.000000      0.000000
# 75%        2.000000     36.000000      0.000000
# max        4.000000    118.000000     10.000000

# %%
df_test.describe()
# Out:
#        country_code  subject_line_length  last_open_day  last_login_day  \
# count  55970.000000         55970.000000   48381.000000    55801.000000
# mean       2.835215            42.212703      32.641078       47.723607
# std        1.728489            12.276136      52.263247      276.075845
# min        1.000000            11.000000       1.000000        0.000000
# 25%        1.000000            35.000000       6.000000        2.000000
# 50%        3.000000            41.000000      18.000000        8.000000
# 75%        4.000000            48.000000      40.000000       23.000000
# max        7.000000            79.000000     812.000000    18165.000000
#
#        last_checkout_day  open_count_last_10_days  open_count_last_30_days  \
# count       44567.000000             55970.000000             55970.000000
# mean           69.409743                 0.774272                 2.441880
# std           126.579497                 1.752984                 4.786883
# min             1.000000                 0.000000                 0.000000
# 25%             6.000000                 0.000000                 0.000000
# 50%            19.000000                 0.000000                 0.000000
# 75%            69.000000                 1.000000                 3.000000
# max          1462.000000                30.000000                79.000000
#
#        open_count_last_60_days  login_count_last_10_days  \
# count             55970.000000              55970.000000
# mean                  5.323530                  8.978899
# std                   9.053473                 13.975840
# min                   0.000000                  0.000000
# 25%                   0.000000                  0.000000
# 50%                   2.000000                  4.000000
# 75%                   6.000000                 13.000000
# max                 120.000000                329.000000
#
#        login_count_last_30_days  login_count_last_60_days  \
# count              55970.000000              55970.000000
# mean                  26.289459                 50.713882
# std                   38.572656                 73.289199
# min                    0.000000                  0.000000
# 25%                    2.000000                  4.000000
# 50%                   13.000000                 25.000000
# 75%                   36.000000                 70.000000
# max                  746.000000               1300.000000
#
#        checkout_count_last_10_days  checkout_count_last_30_days  \
# count                 55970.000000                 55970.000000
# mean                      1.124674                     3.219385
# std                       3.500704                     8.197445
# min                       0.000000                     0.000000
# 25%                       0.000000                     0.000000
# 50%                       0.000000                     1.000000
# 75%                       1.000000                     3.000000
# max                     252.000000                   404.000000
#
#        checkout_count_last_60_days        attr_1        attr_2        attr_3  \
# count                 55970.000000  34254.000000  55731.000000  55951.000000
# mean                      5.933893      0.999796      0.998152      1.070347
# std                      14.233715      0.014294      0.042951      1.036071
# min                       0.000000      0.000000      0.000000      0.000000
# 25%                       0.000000      1.000000      1.000000      0.000000
# 50%                       2.000000      1.000000      1.000000      1.000000
# 75%                       7.000000      1.000000      1.000000      2.000000
# max                     609.000000      1.000000      1.000000      4.000000
#
#                 age        domain
# count  34254.000000  55951.000000
# mean      31.404099      0.444407
# std       11.609694      1.298730
# min      -17.000000      0.000000
# 25%       24.000000      0.000000
# 50%       29.000000      0.000000
# 75%       36.000000      0.000000
# max      118.000000     10.000000

# %%
df_train.isnull().sum()
# Out:
# country_code                       0
# grass_date                         0
# subject_line_length                0
# last_open_day                   7518
# last_login_day                   279
# last_checkout_day              16905
# open_count_last_10_days            0
# open_count_last_30_days            0
# open_count_last_60_days            0
# login_count_last_10_days           0
# login_count_last_30_days           0
# login_count_last_60_days           0
# checkout_count_last_10_days        0
# checkout_count_last_30_days        0
# checkout_count_last_60_days        0
# open_flag                          0
# attr_1                         27781
# attr_2                           252
# attr_3                            21
# age                            27781
# domain                            21
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# country_code                       0
# grass_date                         0
# subject_line_length                0
# last_open_day                   7589
# last_login_day                   169
# last_checkout_day              11403
# open_count_last_10_days            0
# open_count_last_30_days            0
# open_count_last_60_days            0
# login_count_last_10_days           0
# login_count_last_30_days           0
# login_count_last_60_days           0
# checkout_count_last_10_days        0
# checkout_count_last_30_days        0
# checkout_count_last_60_days        0
# attr_1                         21716
# attr_2                           239
# attr_3                            19
# age                            21716
# domain                            19
# dtype: int64

# %% [markdown]
# ## Age

# %%
print('Train dataset!')
print('Total data with age below 13:', df_train['age'][df_train['age'] < 13].count())
print('Total data with age below 18:', df_train['age'][df_train['age'] < 18].count())
print('Total data with age 70 or more:', df_train['age'][df_train['age'] >= 70].count())
print('Total data with age 100 or more:', df_train['age'][df_train['age'] >= 100].count())

print('Test dataset!')
print('Total data with age below 13:', df_test['age'][df_test['age'] < 13].count())
print('Total data with age below 18:', df_test['age'][df_test['age'] < 18].count())
print('Total data with age 70 or more:', df_test['age'][df_test['age'] >= 70].count())
print('Total data with age 100 or more:', df_test['age'][df_test['age'] >= 100].count())
# Out:
# Train dataset!
# Total data with age below 13: 326
# Total data with age below 18: 962
# Total data with age 70 or more: 343
# Total data with age 100 or more: 286
# Test dataset!
# Total data with age below 13: 215
# Total data with age below 18: 758
# Total data with age 70 or more: 253
# Total data with age 100 or more: 217

# %% [markdown]
# ## last_login_day & last_checkout_day

# %%
df_train[ df_train['last_login_day'].isnull() & ~df_train['last_checkout_day'].isnull() ]
# Out:
#        country_code                 grass_date  subject_line_length  \
# 7022              1  2019-07-21 00:00:00+08:00                   40
# 12170             4  2019-07-24 00:00:00+08:00                   53
# 12173             4  2019-07-24 00:00:00+08:00                   53
# 12175             4  2019-07-24 00:00:00+08:00                   53
# 12177             4  2019-07-24 00:00:00+08:00                   53
# ...             ...                        ...                  ...
# 42788             4  2019-08-14 00:00:00+08:00                   33
# 50177             7  2019-08-19 00:00:00+08:00                   69
# 52770             1  2019-08-20 00:00:00+08:00                   68
# 54478             3  2019-08-21 00:00:00+08:00                   23
# 67568             1  2019-09-01 00:00:00+08:00                   40
#
#        last_open_day  last_login_day  last_checkout_day  \
# 7022             NaN             NaN               66.0
# 12170            NaN             NaN               43.0
# 12173            NaN             NaN              443.0
# 12175            NaN             NaN                5.0
# 12177            NaN             NaN                1.0
# ...              ...             ...                ...
# 42788            NaN             NaN              101.0
# 50177            NaN             NaN               73.0
# 52770            NaN             NaN               14.0
# 54478            NaN             NaN               55.0
# 67568            NaN             NaN                9.0
#
#        open_count_last_10_days  open_count_last_30_days  \
# 7022                         0                        0
# 12170                        0                        0
# 12173                        0                        0
# 12175                        0                        0
# 12177                        2                        2
# ...                        ...                      ...
# 42788                        1                        1
# 50177                        0                        0
# 52770                        0                        0
# 54478                        0                        4
# 67568                        0                        0
#
#        open_count_last_60_days  login_count_last_10_days  \
# 7022                         0                        37
# 12170                        0                         1
# 12173                        0                         0
# 12175                        0                        18
# 12177                        3                         9
# ...                        ...                       ...
# 42788                        1                        42
# 50177                        0                         0
# 52770                        1                        52
# 54478                        7                         0
# 67568                        0                         2
#
#        login_count_last_30_days  login_count_last_60_days  \
# 7022                         92                       122
# 12170                         2                         7
# 12173                         1                         6
# 12175                        47                        93
# 12177                        29                        62
# ...                         ...                       ...
# 42788                       142                       289
# 50177                         3                        18
# 52770                       153                       277
# 54478                         0                        15
# 67568                         2                         3
#
#        checkout_count_last_10_days  checkout_count_last_30_days  \
# 7022                             0                            0
# 12170                            0                            0
# 12173                            0                            0
# 12175                            3                           13
# 12177                            4                           11
# ...                            ...                          ...
# 42788                            0                            0
# 50177                            0                            0
# 52770                            0                            2
# 54478                            0                            0
# 67568                            1                            1
#
#        checkout_count_last_60_days  open_flag  attr_1  attr_2  attr_3   age  \
# 7022                             0          0     1.0     1.0     4.0  43.0
# 12170                            1          0     1.0     NaN     2.0  28.0
# 12173                            0          0     1.0     NaN     2.0  29.0
# 12175                           18          0     1.0     NaN     2.0  27.0
# 12177                           17          1     1.0     NaN     2.0  22.0
# ...                            ...        ...     ...     ...     ...   ...
# 42788                            0          0     1.0     1.0     1.0  31.0
# 50177                            0          0     1.0     1.0     2.0  31.0
# 52770                            3          0     1.0     1.0     1.0  25.0
# 54478                            1          0     NaN     1.0     0.0   NaN
# 67568                            1          0     1.0     1.0     1.0  23.0
#
#        domain
# 7022      3.0
# 12170     2.0
# 12173     0.0
# 12175     2.0
# 12177     0.0
# ...       ...
# 42788     0.0
# 50177     0.0
# 52770     0.0
# 54478     0.0
# 67568     0.0
#
# [253 rows x 21 columns]

# %%
df_test[ df_test['last_login_day'].isnull() & ~df_test['last_checkout_day'].isnull() ]
# Out:
#        country_code                 grass_date  subject_line_length  \
# 20896             3  2019-09-09 00:00:00+08:00                   41
# 38884             6  2019-09-16 00:00:00+08:00                   20
# 48025             6  2019-09-23 00:00:00+08:00                   30
# 49559             6  2019-09-24 00:00:00+08:00                   20
# 51541             6  2019-09-25 00:00:00+08:00                   54
#
#        last_open_day  last_login_day  last_checkout_day  \
# 20896            NaN             NaN                3.0
# 38884            NaN             NaN               16.0
# 48025            NaN             NaN                3.0
# 49559            NaN             NaN               54.0
# 51541            NaN             NaN               36.0
#
#        open_count_last_10_days  open_count_last_30_days  \
# 20896                        0                        0
# 38884                        1                        2
# 48025                        0                        0
# 49559                        0                        0
# 51541                        1                        4
#
#        open_count_last_60_days  login_count_last_10_days  \
# 20896                        1                         8
# 38884                        6                        54
# 48025                        2                         0
# 49559                        0                        17
# 51541                        6                         0
#
#        login_count_last_30_days  login_count_last_60_days  \
# 20896                        28                        48
# 38884                       151                       309
# 48025                         0                         0
# 49559                        82                       225
# 51541                         0                         0
#
#        checkout_count_last_10_days  checkout_count_last_30_days  \
# 20896                            3                            7
# 38884                            0                            0
# 48025                            0                            0
# 49559                            0                            0
# 51541                            0                            0
#
#        checkout_count_last_60_days  attr_1  attr_2  attr_3   age  domain
# 20896                           11     1.0     1.0     1.0  36.0     2.0
# 38884                            0     NaN     1.0     0.0   NaN     0.0
# 48025                            0     1.0     1.0     2.0  29.0     2.0
# 49559                            1     1.0     1.0     2.0  19.0     0.0
# 51541                            0     1.0     0.0     1.0  26.0     0.0

# %% [markdown]
# ## last_open_day && open_count_last_{}_days

# %%
df_train[ df_train['last_open_day'].isnull() & ((df_train['open_count_last_10_days'] > 0) | (df_train['open_count_last_30_days'] > 0) | (df_train['open_count_last_60_days'] > 0)) ]
# Out:
#        country_code                 grass_date  subject_line_length  \
# 667               1  2019-07-16 00:00:00+08:00                   58
# 1011              2  2019-07-16 00:00:00+08:00                   36
# 1132              2  2019-07-16 00:00:00+08:00                   36
# 1287              5  2019-07-16 00:00:00+08:00                   43
# 1321              2  2019-07-16 00:00:00+08:00                   36
# ...             ...                        ...                  ...
# 73228             1  2019-09-02 00:00:00+08:00                   33
# 73269             1  2019-09-02 00:00:00+08:00                   33
# 73363             1  2019-09-02 00:00:00+08:00                   33
# 73415             3  2019-09-02 00:00:00+08:00                   49
# 73451             1  2019-09-02 00:00:00+08:00                   33
#
#        last_open_day  last_login_day  last_checkout_day  \
# 667              NaN            14.0               19.0
# 1011             NaN           196.0               45.0
# 1132             NaN            15.0               15.0
# 1287             NaN            94.0              197.0
# 1321             NaN           348.0                NaN
# ...              ...             ...                ...
# 73228            NaN            27.0                NaN
# 73269            NaN            27.0                NaN
# 73363            NaN            14.0                NaN
# 73415            NaN             3.0                NaN
# 73451            NaN             3.0                NaN
#
#        open_count_last_10_days  open_count_last_30_days  \
# 667                          1                        1
# 1011                         0                        2
# 1132                         1                        1
# 1287                         2                        2
# 1321                         0                        2
# ...                        ...                      ...
# 73228                        2                        2
# 73269                        2                        2
# 73363                        0                        1
# 73415                        1                        1
# 73451                        1                        1
#
#        open_count_last_60_days  login_count_last_10_days  \
# 667                          1                         0
# 1011                         2                         0
# 1132                         1                         0
# 1287                         2                         0
# 1321                         2                         0
# ...                        ...                       ...
# 73228                        2                         0
# 73269                        2                         0
# 73363                        1                         0
# 73415                        1                         8
# 73451                        1                         2
#
#        login_count_last_30_days  login_count_last_60_days  \
# 667                          15                        18
# 1011                          0                         2
# 1132                          0                         0
# 1287                          0                         0
# 1321                          0                         0
# ...                         ...                       ...
# 73228                         2                         2
# 73269                         1                         1
# 73363                         5                         5
# 73415                        17                        17
# 73451                         3                         3
#
#        checkout_count_last_10_days  checkout_count_last_30_days  \
# 667                              0                            1
# 1011                             0                            0
# 1132                             0                            0
# 1287                             0                            0
# 1321                             0                            0
# ...                            ...                          ...
# 73228                            0                            0
# 73269                            0                            0
# 73363                            0                            0
# 73415                            0                            0
# 73451                            0                            0
#
#        checkout_count_last_60_days  open_flag  attr_1  attr_2  attr_3   age  \
# 667                              1          0     NaN     1.0     0.0   NaN
# 1011                             4          0     1.0     1.0     1.0  29.0
# 1132                             0          1     1.0     1.0     2.0  27.0
# 1287                             0          0     1.0     1.0     2.0  31.0
# 1321                             0          0     1.0     1.0     2.0  27.0
# ...                            ...        ...     ...     ...     ...   ...
# 73228                            0          1     NaN     1.0     0.0   NaN
# 73269                            0          0     NaN     1.0     0.0   NaN
# 73363                            0          0     NaN     1.0     0.0   NaN
# 73415                            0          0     1.0     1.0     1.0   1.0
# 73451                            0          1     NaN     1.0     0.0   NaN
#
#        domain
# 667       0.0
# 1011      0.0
# 1132      0.0
# 1287      0.0
# 1321      0.0
# ...       ...
# 73228     0.0
# 73269     0.0
# 73363     0.0
# 73415     0.0
# 73451     0.0
#
# [377 rows x 21 columns]

# %%
df_test[ df_test['last_open_day'].isnull() & ((df_test['open_count_last_10_days'] > 0) | (df_test['open_count_last_30_days'] > 0) | (df_test['open_count_last_60_days'] > 0)) ]
# Out:
#        country_code                 grass_date  subject_line_length  \
# 3080              1  2019-09-03 00:00:00+08:00                   36
# 3085              6  2019-09-03 00:00:00+08:00                   35
# 3106              1  2019-09-03 00:00:00+08:00                   43
# 3133              1  2019-09-03 00:00:00+08:00                   43
# 3215              1  2019-09-03 00:00:00+08:00                   43
# ...             ...                        ...                  ...
# 54302             6  2019-09-27 00:00:00+08:00                   21
# 55202             3  2019-09-28 00:00:00+08:00                   38
# 55916             3  2019-09-29 00:00:00+08:00                   50
# 55924             3  2019-09-29 00:00:00+08:00                   43
# 55954             6  2019-09-29 00:00:00+08:00                   41
#
#        last_open_day  last_login_day  last_checkout_day  \
# 3080             NaN             2.0                2.0
# 3085             NaN             1.0                7.0
# 3106             NaN            13.0                NaN
# 3133             NaN            11.0               26.0
# 3215             NaN            11.0               14.0
# ...              ...             ...                ...
# 54302            NaN             NaN                NaN
# 55202            NaN             2.0                4.0
# 55916            NaN            15.0                NaN
# 55924            NaN             5.0                NaN
# 55954            NaN             NaN                NaN
#
#        open_count_last_10_days  open_count_last_30_days  \
# 3080                         0                        1
# 3085                         1                        1
# 3106                         1                        1
# 3133                         2                        2
# 3215                         1                        1
# ...                        ...                      ...
# 54302                        3                        7
# 55202                        1                        1
# 55916                        3                        6
# 55924                        2                        2
# 55954                        1                        1
#
#        open_count_last_60_days  login_count_last_10_days  \
# 3080                         1                        42
# 3085                         1                         4
# 3106                         1                         1
# 3133                         2                         3
# 3215                         1                         2
# ...                        ...                       ...
# 54302                        8                         0
# 55202                        1                        37
# 55916                        6                         0
# 55924                        2                         1
# 55954                        1                        39
#
#        login_count_last_30_days  login_count_last_60_days  \
# 3080                         77                        77
# 3085                          5                         5
# 3106                         17                        17
# 3133                         21                        21
# 3215                         10                        10
# ...                         ...                       ...
# 54302                         0                         0
# 55202                        56                        56
# 55916                         6                         6
# 55924                         8                         8
# 55954                        41                        41
#
#        checkout_count_last_10_days  checkout_count_last_30_days  \
# 3080                            11                           13
# 3085                             2                            2
# 3106                             0                            0
# 3133                             0                            1
# 3215                             0                            3
# ...                            ...                          ...
# 54302                            0                            0
# 55202                            1                            2
# 55916                            0                            0
# 55924                            0                            0
# 55954                            0                            0
#
#        checkout_count_last_60_days  attr_1  attr_2  attr_3   age  domain
# 3080                            13     1.0     1.0     1.0  20.0     0.0
# 3085                             2     1.0     1.0     2.0  22.0     0.0
# 3106                             0     NaN     1.0     0.0   NaN     0.0
# 3133                             1     NaN     1.0     0.0   NaN     0.0
# 3215                             3     1.0     1.0     2.0  31.0     0.0
# ...                            ...     ...     ...     ...   ...     ...
# 54302                            0     1.0     1.0     1.0  29.0     0.0
# 55202                            2     NaN     1.0     0.0   NaN     0.0
# 55916                            0     NaN     1.0     0.0   NaN     0.0
# 55924                            0     1.0     1.0     3.0  30.0     0.0
# 55954                            0     NaN     1.0     0.0   NaN     0.0
#
# [281 rows x 20 columns]

# %% [markdown]
# ## last_login_day && login_count_last_{}_days

# %%
df_train[ df_train['last_login_day'].isnull() & ((df_train['login_count_last_10_days'] > 0) | (df_train['login_count_last_30_days'] > 0) | (df_train['login_count_last_60_days'] > 0)) ]
# Out:
#        country_code                 grass_date  subject_line_length  \
# 7022              1  2019-07-21 00:00:00+08:00                   40
# 11759             3  2019-07-23 00:00:00+08:00                   47
# 12170             4  2019-07-24 00:00:00+08:00                   53
# 12173             4  2019-07-24 00:00:00+08:00                   53
# 12175             4  2019-07-24 00:00:00+08:00                   53
# ...             ...                        ...                  ...
# 50177             7  2019-08-19 00:00:00+08:00                   69
# 52770             1  2019-08-20 00:00:00+08:00                   68
# 53971             2  2019-08-21 00:00:00+08:00                   38
# 54478             3  2019-08-21 00:00:00+08:00                   23
# 67568             1  2019-09-01 00:00:00+08:00                   40
#
#        last_open_day  last_login_day  last_checkout_day  \
# 7022             NaN             NaN               66.0
# 11759            NaN             NaN                NaN
# 12170            NaN             NaN               43.0
# 12173            NaN             NaN              443.0
# 12175            NaN             NaN                5.0
# ...              ...             ...                ...
# 50177            NaN             NaN               73.0
# 52770            NaN             NaN               14.0
# 53971            NaN             NaN                NaN
# 54478            NaN             NaN               55.0
# 67568            NaN             NaN                9.0
#
#        open_count_last_10_days  open_count_last_30_days  \
# 7022                         0                        0
# 11759                        0                        0
# 12170                        0                        0
# 12173                        0                        0
# 12175                        0                        0
# ...                        ...                      ...
# 50177                        0                        0
# 52770                        0                        0
# 53971                        0                        1
# 54478                        0                        4
# 67568                        0                        0
#
#        open_count_last_60_days  login_count_last_10_days  \
# 7022                         0                        37
# 11759                        0                         0
# 12170                        0                         1
# 12173                        0                         0
# 12175                        0                        18
# ...                        ...                       ...
# 50177                        0                         0
# 52770                        1                        52
# 53971                        6                         2
# 54478                        7                         0
# 67568                        0                         2
#
#        login_count_last_30_days  login_count_last_60_days  \
# 7022                         92                       122
# 11759                         0                         2
# 12170                         2                         7
# 12173                         1                         6
# 12175                        47                        93
# ...                         ...                       ...
# 50177                         3                        18
# 52770                       153                       277
# 53971                        17                        25
# 54478                         0                        15
# 67568                         2                         3
#
#        checkout_count_last_10_days  checkout_count_last_30_days  \
# 7022                             0                            0
# 11759                            0                            0
# 12170                            0                            0
# 12173                            0                            0
# 12175                            3                           13
# ...                            ...                          ...
# 50177                            0                            0
# 52770                            0                            2
# 53971                            0                           17
# 54478                            0                            0
# 67568                            1                            1
#
#        checkout_count_last_60_days  open_flag  attr_1  attr_2  attr_3   age  \
# 7022                             0          0     1.0     1.0     4.0  43.0
# 11759                            0          1     NaN     1.0     0.0   NaN
# 12170                            1          0     1.0     NaN     2.0  28.0
# 12173                            0          0     1.0     NaN     2.0  29.0
# 12175                           18          0     1.0     NaN     2.0  27.0
# ...                            ...        ...     ...     ...     ...   ...
# 50177                            0          0     1.0     1.0     2.0  31.0
# 52770                            3          0     1.0     1.0     1.0  25.0
# 53971                           18          0     NaN     1.0     0.0   NaN
# 54478                            1          0     NaN     1.0     0.0   NaN
# 67568                            1          0     1.0     1.0     1.0  23.0
#
#        domain
# 7022      3.0
# 11759     2.0
# 12170     2.0
# 12173     0.0
# 12175     2.0
# ...       ...
# 50177     0.0
# 52770     0.0
# 53971     0.0
# 54478     0.0
# 67568     0.0
#
# [259 rows x 21 columns]

# %%
df_test[ df_test['last_login_day'].isnull() & ((df_test['login_count_last_10_days'] > 0) | (df_test['login_count_last_30_days'] > 0) | (df_test['login_count_last_60_days'] > 0)) ]
# Out:
#        country_code                 grass_date  subject_line_length  \
# 20896             3  2019-09-09 00:00:00+08:00                   41
# 30797             6  2019-09-11 00:00:00+08:00                   20
# 31043             6  2019-09-11 00:00:00+08:00                   20
# 31332             6  2019-09-11 00:00:00+08:00                   20
# 31765             6  2019-09-11 00:00:00+08:00                   20
# ...             ...                        ...                  ...
# 54095             6  2019-09-27 00:00:00+08:00                   21
# 54147             6  2019-09-27 00:00:00+08:00                   21
# 54155             6  2019-09-27 00:00:00+08:00                   21
# 54293             6  2019-09-27 00:00:00+08:00                   21
# 55954             6  2019-09-29 00:00:00+08:00                   41
#
#        last_open_day  last_login_day  last_checkout_day  \
# 20896            NaN             NaN                3.0
# 30797            NaN             NaN                NaN
# 31043            NaN             NaN                NaN
# 31332            NaN             NaN                NaN
# 31765            NaN             NaN                NaN
# ...              ...             ...                ...
# 54095            NaN             NaN                NaN
# 54147            NaN             NaN                NaN
# 54155            NaN             NaN                NaN
# 54293            NaN             NaN                NaN
# 55954            NaN             NaN                NaN
#
#        open_count_last_10_days  open_count_last_30_days  \
# 20896                        0                        0
# 30797                        0                        0
# 31043                        0                        0
# 31332                        0                        0
# 31765                        0                        0
# ...                        ...                      ...
# 54095                        0                        1
# 54147                        1                        2
# 54155                        0                        0
# 54293                        2                        2
# 55954                        1                        1
#
#        open_count_last_60_days  login_count_last_10_days  \
# 20896                        1                         8
# 30797                        0                         1
# 31043                        0                        13
# 31332                        0                         0
# 31765                        1                        21
# ...                        ...                       ...
# 54095                        3                        13
# 54147                        7                         5
# 54155                        0                         0
# 54293                        2                        13
# 55954                        1                        39
#
#        login_count_last_30_days  login_count_last_60_days  \
# 20896                        28                        48
# 30797                         1                         1
# 31043                        41                        76
# 31332                         1                         2
# 31765                        69                       142
# ...                         ...                       ...
# 54095                        40                        93
# 54147                        23                        57
# 54155                         0                         7
# 54293                        13                        13
# 55954                        41                        41
#
#        checkout_count_last_10_days  checkout_count_last_30_days  \
# 20896                            3                            7
# 30797                            0                            0
# 31043                            0                            0
# 31332                            0                            0
# 31765                            0                            0
# ...                            ...                          ...
# 54095                            0                            0
# 54147                            0                            0
# 54155                            0                            0
# 54293                            0                            0
# 55954                            0                            0
#
#        checkout_count_last_60_days  attr_1  attr_2  attr_3   age  domain
# 20896                           11     1.0     1.0     1.0  36.0     2.0
# 30797                            0     1.0     1.0     1.0  33.0     0.0
# 31043                            0     NaN     1.0     0.0   NaN     0.0
# 31332                            0     1.0     1.0     1.0  22.0     0.0
# 31765                            0     NaN     1.0     0.0   NaN     0.0
# ...                            ...     ...     ...     ...   ...     ...
# 54095                            0     1.0     1.0     2.0  22.0     3.0
# 54147                            0     NaN     1.0     0.0   NaN     3.0
# 54155                            0     NaN     1.0     0.0   NaN     9.0
# 54293                            0     1.0     1.0     1.0  29.0     0.0
# 55954                            0     NaN     1.0     0.0   NaN     0.0
#
# [103 rows x 20 columns]

# %% [markdown]
# ## last_login_day && login_count_last_{}_days

# %%
df_train[ df_train['last_checkout_day'].isnull() & ((df_train['checkout_count_last_10_days'] > 0) | (df_train['checkout_count_last_30_days'] > 0) | (df_train['checkout_count_last_60_days'] > 0)) ]
# Out:
#        country_code                 grass_date  subject_line_length  \
# 405               1  2019-07-16 00:00:00+08:00                   58
# 688               1  2019-07-16 00:00:00+08:00                   64
# 705               2  2019-07-16 00:00:00+08:00                   36
# 738               3  2019-07-16 00:00:00+08:00                   33
# 841               1  2019-07-16 00:00:00+08:00                   49
# ...             ...                        ...                  ...
# 73371             1  2019-09-02 00:00:00+08:00                   33
# 73412             1  2019-09-02 00:00:00+08:00                   33
# 73449             2  2019-09-02 00:00:00+08:00                   38
# 73454             1  2019-09-02 00:00:00+08:00                   33
# 73475             6  2019-09-02 00:00:00+08:00                   39
#
#        last_open_day  last_login_day  last_checkout_day  \
# 405              4.0            38.0                NaN
# 688             83.0             4.0                NaN
# 705              3.0            95.0                NaN
# 738              7.0            37.0                NaN
# 841             22.0             6.0                NaN
# ...              ...             ...                ...
# 73371            NaN            14.0                NaN
# 73412            NaN             2.0                NaN
# 73449           14.0             2.0                NaN
# 73454           13.0             1.0                NaN
# 73475            6.0             8.0                NaN
#
#        open_count_last_10_days  open_count_last_30_days  \
# 405                          6                       15
# 688                          0                        0
# 705                         11                       18
# 738                          1                        5
# 841                          0                        1
# ...                        ...                      ...
# 73371                        0                        0
# 73412                        0                        0
# 73449                        0                        0
# 73454                        0                        0
# 73475                        1                        1
#
#        open_count_last_60_days  login_count_last_10_days  \
# 405                         29                         4
# 688                          0                        35
# 705                         23                         1
# 738                         10                         1
# 841                          2                         7
# ...                        ...                       ...
# 73371                        0                         1
# 73412                        0                        17
# 73449                        0                         7
# 73454                        0                        11
# 73475                        1                         1
#
#        login_count_last_30_days  login_count_last_60_days  \
# 405                          25                        52
# 688                         126                       273
# 705                           8                        54
# 738                           1                         6
# 841                          19                        48
# ...                         ...                       ...
# 73371                         7                         7
# 73412                        29                        29
# 73449                        20                        20
# 73454                        20                        20
# 73475                         4                         4
#
#        checkout_count_last_10_days  checkout_count_last_30_days  \
# 405                              0                            0
# 688                              0                            3
# 705                              0                            0
# 738                              0                            0
# 841                              2                           10
# ...                            ...                          ...
# 73371                            0                            2
# 73412                            0                            1
# 73449                            0                            1
# 73454                           26                           49
# 73475                            0                            1
#
#        checkout_count_last_60_days  open_flag  attr_1  attr_2  attr_3   age  \
# 405                              3          0     1.0     1.0     2.0  24.0
# 688                             14          0     1.0     1.0     1.0  33.0
# 705                              7          1     NaN     1.0     0.0   NaN
# 738                              1          0     1.0     1.0     2.0  27.0
# 841                             24          0     1.0     1.0     2.0  25.0
# ...                            ...        ...     ...     ...     ...   ...
# 73371                            2          0     NaN     1.0     0.0   NaN
# 73412                            1          0     NaN     1.0     0.0   NaN
# 73449                            1          0     1.0     1.0     1.0  29.0
# 73454                           49          0     1.0     1.0     2.0  50.0
# 73475                            1          0     NaN     1.0     0.0   NaN
#
#        domain
# 405       0.0
# 688       0.0
# 705       0.0
# 738       0.0
# 841       0.0
# ...       ...
# 73371     0.0
# 73412     0.0
# 73449     0.0
# 73454     2.0
# 73475     0.0
#
# [813 rows x 21 columns]

# %%
df_test[ df_test['last_checkout_day'].isnull() & ((df_test['checkout_count_last_10_days'] > 0) | (df_test['checkout_count_last_30_days'] > 0) | (df_test['checkout_count_last_60_days'] > 0)) ]
# Out:
#        country_code                 grass_date  subject_line_length  \
# 863               1  2019-09-03 00:00:00+08:00                   43
# 1528              2  2019-09-03 00:00:00+08:00                   43
# 1980              1  2019-09-03 00:00:00+08:00                   43
# 2239              3  2019-09-03 00:00:00+08:00                   28
# 2242              3  2019-09-03 00:00:00+08:00                   46
# ...             ...                        ...                  ...
# 55895             6  2019-09-29 00:00:00+08:00                   43
# 55901             3  2019-09-29 00:00:00+08:00                   43
# 55923             3  2019-09-29 00:00:00+08:00                   43
# 55936             1  2019-09-29 00:00:00+08:00                   48
# 55944             3  2019-09-29 00:00:00+08:00                   50
#
#        last_open_day  last_login_day  last_checkout_day  \
# 863            201.0             9.0                NaN
# 1528             4.0             9.0                NaN
# 1980            10.0            22.0                NaN
# 2239             NaN             9.0                NaN
# 2242            18.0             3.0                NaN
# ...              ...             ...                ...
# 55895           11.0             7.0                NaN
# 55901            NaN             4.0                NaN
# 55923            NaN             7.0                NaN
# 55936            NaN            17.0                NaN
# 55944            NaN            15.0                NaN
#
#        open_count_last_10_days  open_count_last_30_days  \
# 863                          0                        0
# 1528                         1                        3
# 1980                         0                        0
# 2239                         0                        0
# 2242                         0                        2
# ...                        ...                      ...
# 55895                        0                        3
# 55901                        0                        0
# 55923                        0                        0
# 55936                        0                        0
# 55944                        0                        0
#
#        open_count_last_60_days  login_count_last_10_days  \
# 863                          0                         1
# 1528                         9                         2
# 1980                         2                         0
# 2239                         0                        11
# 2242                         3                         4
# ...                        ...                       ...
# 55895                        3                         7
# 55901                        0                         4
# 55923                        0                        22
# 55936                        0                         4
# 55944                        0                         0
#
#        login_count_last_30_days  login_count_last_60_days  \
# 863                           4                         4
# 1528                          5                        19
# 1980                          5                        18
# 2239                         40                        64
# 2242                         13                        16
# ...                         ...                       ...
# 55895                        26                        28
# 55901                         9                         9
# 55923                        41                        41
# 55936                        15                        15
# 55944                         2                         2
#
#        checkout_count_last_10_days  checkout_count_last_30_days  \
# 863                              0                            1
# 1528                             0                            0
# 1980                             0                            0
# 2239                             0                            1
# 2242                             0                            0
# ...                            ...                          ...
# 55895                            0                            3
# 55901                            1                            1
# 55923                            1                            2
# 55936                            0                            1
# 55944                            0                            1
#
#        checkout_count_last_60_days  attr_1  attr_2  attr_3   age  domain
# 863                              1     1.0     1.0     1.0  31.0     0.0
# 1528                             7     1.0     1.0     2.0  50.0     0.0
# 1980                             1     1.0     1.0     1.0  19.0     0.0
# 2239                             2     NaN     1.0     0.0   NaN     0.0
# 2242                             1     NaN     1.0     0.0   NaN     0.0
# ...                            ...     ...     ...     ...   ...     ...
# 55895                            3     NaN     1.0     0.0   NaN     0.0
# 55901                            1     1.0     1.0     1.0  20.0     0.0
# 55923                            2     NaN     1.0     0.0   NaN     0.0
# 55936                            1     NaN     1.0     0.0   NaN     0.0
# 55944                            1     NaN     1.0     0.0   NaN     9.0
#
# [569 rows x 20 columns]

# %% [markdown]
# # Additional preprocessing

# %% [markdown]
# ## 1. Timedate

# %%
df_train['day'] = pd.to_datetime(df_train['grass_date']).dt.dayofweek.astype('category')
df_test['day'] = pd.to_datetime(df_test['grass_date']).dt.dayofweek.astype('category')

# %%
del df_train['grass_date']
del df_test['grass_date']

# %% [markdown]
# ## 2. ~~Normalization~~ Standardization

# %%
# from sklearn.preprocessing import StandardScaler

# cont_feature = [
#     'subject_line_length', 'last_open_day', 'last_login_day', 'last_checkout_day',
#     'open_count_last_10_days', 'open_count_last_30_days', 'open_count_last_60_days',
#     'login_count_last_10_days', 'login_count_last_30_days', 'login_count_last_60_days',
#     'checkout_count_last_10_days', 'checkout_count_last_30_days',
#     'checkout_count_last_60_days', 'age'
# ]

# scaler = StandardScaler()
# df_train[cont_feature] = scaler.fit_transform(df_train[cont_feature])
# df_test[cont_feature] = scaler.transform(df_test[cont_feature])

# %% [markdown]
# ## 3. Anomaly

# %%
def fix_age(age):
    if age < 18 or age >= 100:
        return np.nan
    else:
        return age
    
df_train['age'] = df_train['age'].apply(fix_age)
df_test['age'] = df_test['age'].apply(fix_age)

# %% [markdown]
# ## 4. NaN

# %%
# # last_open_day
# df_train['last_open_day_nan'] = df_train['last_open_day'].isnull()
# df_train['last_open_day'] = df_train['last_open_day'].fillna(-1)

# df_test['last_open_day_nan'] = df_test['last_open_day'].isnull()
# df_test['last_open_day'] = df_test['last_open_day'].fillna(-1)

# # last_login_day
# df_train['last_login_day_nan'] = df_train['last_login_day'].isnull()
# df_train['last_login_day'] = df_train['last_login_day'].fillna(-1)

# df_test['last_login_day_nan'] = df_test['last_login_day'].isnull()
# df_test['last_login_day'] = df_test['last_login_day'].fillna(-1)

# # last_checkout_day
# df_train['last_checkout_day_nan'] = df_train['last_checkout_day'].isnull()
# df_train['last_checkout_day'] = df_train['last_checkout_day'].fillna(-1)

# df_test['last_checkout_day_nan'] = df_test['last_checkout_day'].isnull()
# df_test['last_checkout_day'] = df_test['last_checkout_day'].fillna(-1)

# # attr_1
# df_train['attr_1_nan'] = df_train['attr_1'].isnull()
# df_train['attr_1'] = df_train['attr_1'].fillna(-1)

# df_test['attr_1_nan'] = df_test['attr_1'].isnull()
# df_test['attr_1'] = df_test['attr_1'].fillna(-1)

# # attr_2
# df_train['attr_2_nan'] = df_train['attr_2'].isnull()
# df_train['attr_2'] = df_train['attr_2'].fillna(-1)

# df_test['attr_2_nan'] = df_test['attr_2'].isnull()
# df_test['attr_2'] = df_test['attr_2'].fillna(-1)

# # attr_3
# df_train['attr_3_nan'] = df_train['attr_3'].isnull()
# df_train['attr_3'] = df_train['attr_3'].fillna(-1)

# df_test['attr_3_nan'] = df_test['attr_3'].isnull()
# df_test['attr_3'] = df_test['attr_3'].fillna(-1)

# # age
# df_train['age_nan'] = df_train['age'].isnull()
# df_train['age'] = df_train['age'].fillna(-1)

# df_test['age_nan'] = df_test['age'].isnull()
# df_test['age'] = df_test['age'].fillna(-1)

# %%
# domain
# 1 -> 'other' domain from previous preprocessing
# df_train['domain_nan'] = df_train['domain'].isnull()
df_train['domain'] = df_train['domain'].fillna(1)

# df_test['domain_nan'] = df_test['domain'].isnull()
df_test['domain'] = df_test['domain'].fillna(1)

# %% [markdown]
# ## 5. Misc

# %%
X = df_train.copy()
del X['open_flag']

X_test = df_test.copy()

y = df_train['open_flag'].to_numpy()

# %%
cat_feature = [
    'country_code','attr_1', 'attr_2', 'attr_3',
    'domain','day',
#     'last_open_day_nan', 'last_login_day_nan',
#     'last_checkout_day_nan', 'attr_1_nan', 'attr_2_nan',
#     'attr_3_nan', 'age_nan', 'domain_nan',
    
]
cat_feature_idx = [X.columns.get_loc(ct) for ct in cat_feature]
cat_feature_idx
# Out:
# [0, 14, 15, 16, 18, 19]

# %% [markdown]
# # KFold Model

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import matthews_corrcoef

K = [3, 5]

# %%
param_dict = {
    'boosting_type': ['gbdt', 'goss'],
    'learning_rate': [0.01, 0.03, 0.1],
    'min_data_in_leaf': [20, 50],
    'num_leaves': [31, 63],
    'feature_fraction': [0.9, 1.0],
    'max_bin': [16, 102, 255],
    'lambda': [
        # l1, l2
        [0.0, 0.0],
        [0.001, 0.01],
        [0.01, 0.1],
        [0.01, 1.0],
        [1.0, 0.01],
    ]
    
}
param_key = list(param_dict.keys())
param_item = list(param_dict.values())
param_item
# Out:
# [['gbdt', 'goss'],
#  [0.01, 0.03, 0.1],
#  [20, 50],
#  [31, 63],
#  [0.9, 1.0],
#  [16, 102, 255],
#  [[0.0, 0.0], [0.001, 0.01], [0.01, 0.1], [0.01, 1.0], [1.0, 0.01]]]

# %%
param_list = list(itertools.product(*param_item))
param_list[:10]
# Out:
# [('gbdt', 0.01, 20, 31, 0.9, 16, [0.0, 0.0]),
#  ('gbdt', 0.01, 20, 31, 0.9, 16, [0.001, 0.01]),
#  ('gbdt', 0.01, 20, 31, 0.9, 16, [0.01, 0.1]),
#  ('gbdt', 0.01, 20, 31, 0.9, 16, [0.01, 1.0]),
#  ('gbdt', 0.01, 20, 31, 0.9, 16, [1.0, 0.01]),
#  ('gbdt', 0.01, 20, 31, 0.9, 102, [0.0, 0.0]),
#  ('gbdt', 0.01, 20, 31, 0.9, 102, [0.001, 0.01]),
#  ('gbdt', 0.01, 20, 31, 0.9, 102, [0.01, 0.1]),
#  ('gbdt', 0.01, 20, 31, 0.9, 102, [0.01, 1.0]),
#  ('gbdt', 0.01, 20, 31, 0.9, 102, [1.0, 0.01])]

# %%
len(param_list)
# Out:
# 720

# %%
df_model = pd.DataFrame(columns=[*param_key, *[f'model_{i}' for i in range(sum(K))], *[f'model_{i}_mcc' for i in range(sum(K))], 'average_mcc'])
df_model
# Out:
# Empty DataFrame
# Columns: [boosting_type, learning_rate, min_data_in_leaf, num_leaves, feature_fraction, max_bin, lambda, model_0, model_1, model_2, model_3, model_4, model_5, model_6, model_7, model_0_mcc, model_1_mcc, model_2_mcc, model_3_mcc, model_4_mcc, model_5_mcc, model_6_mcc, model_7_mcc, average_mcc]
# Index: []

# %%
skf_list = [StratifiedKFold(n_splits=k, shuffle=True, random_state=SEED) for k in K]

for param in param_list:
    ctr = 0
    model = []
    mcc_score = []
    for skf in skf_list:
        for train_idx, val_idx in skf.split(X, y):
            X_train, X_val = X.loc[train_idx], X.loc[val_idx]
            y_train, y_val = y[train_idx], y[val_idx]

            model.append(
                lgbm.LGBMClassifier(
                    # fixed
                    is_unbalance=True,
                    seed=SEED,
                    extra_trees=True,

                    n_estimators=100,
                    min_data_per_group=1,
                    # variable
                    boosting_type=param[0],
                    learning_rate=param[1],
                    min_data_in_leaf=param[2],
                    num_leaves=param[3],
                    feature_fraction=param[4],
                    max_bin=param[5], 
                    lambda_l1=param[6][0],
                    lambda_l2=param[6][1],
                )
            )
            model[ctr].fit(
                X_train, y_train,
                categorical_feature=cat_feature_idx
            )

            y_val_pred = model[ctr].predict(X_val)
            mcc_score.append(matthews_corrcoef(y_val, y_val_pred))

            ctr += 1
    df_model.loc[ df_model.shape[0] ] = [
        *param,
        *model,
        *mcc_score,
        sum(mcc_score) / len(mcc_score)
    ]
# Out:
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# ...
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1295: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is [0, 14, 15, 16, 18, 19]
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))

# %% [markdown]
# # Evaluate

# %%
df_model = df_model.sort_values(by=['average_mcc', 'boosting_type', 'learning_rate', 'min_data_in_leaf', 'num_leaves', 'max_bin'], ascending=[False, False, False, True, True, True]).reset_index(drop=True)
df_model.loc[:1000].to_pickle('model.pkl')
# !ls -lah
# Out:
# total 2.7G
# drwxr-xr-x 2 root root 4.0K Aug  7 17:31 .
# drwxr-xr-x 6 root root 4.0K Aug  7 15:34 ..
# ---------- 1 root root  23K Aug  7 15:34 __notebook__.ipynb
# -rw-r--r-- 1 root root 2.7G Aug  7 17:32 model.pkl
# -rw-r--r-- 1 root root  14K Aug  7 15:34 requirements.txt

# %%
pd.set_option('display.max_row', df_model.shape[0])

# %%
df_model
# Out:
#     boosting_type  learning_rate min_data_in_leaf num_leaves  \
# 0            goss           0.01               20         63
# 1            gbdt           0.01               20         63
# 2            goss           0.01               20         63
# 3            gbdt           0.01               20         63
# 4            goss           0.01               20         63
# 5            gbdt           0.01               20         63
# 6            goss           0.01               20         63
# 7            gbdt           0.01               20         63
# 8            goss           0.01               50         63
# 9            gbdt           0.01               50         63
# 10           goss           0.01               50         63
# 11           gbdt           0.01               50         63
# 12           goss           0.01               50         63
# 13           gbdt           0.01               50         63
# 14           goss           0.01               50         63
# 15           gbdt           0.01               50         63
# 16           goss           0.01               50         63
# 17           gbdt           0.01               50         63
# 18           goss           0.01               20         63
# 19           gbdt           0.01               20         63
# 20           goss           0.01               20         63
# 21           gbdt           0.01               20         63
# 22           goss           0.01               20         63
# 23           gbdt           0.01               20         63
# 24           goss           0.01               20         63
# 25           gbdt           0.01               20         63
# 26           goss           0.01               20         63
# 27           gbdt           0.01               20         63
# 28           goss           0.01               50         63
# 29           gbdt           0.01               50         63
# 30           goss           0.01               50         63
# 31           gbdt           0.01               50         63
# 32           goss           0.01               20         63
# 33           gbdt           0.01               20         63
# 34           goss           0.01               50         63
# 35           gbdt           0.01               50         63
# 36           goss           0.01               50         63
# 37           gbdt           0.01               50         63
# 38           goss           0.01               20         63
# 39           gbdt           0.01               20         63
# 40           goss           0.01               50         63
# 41           gbdt           0.01               50         63
# 42           goss           0.01               20         63
# 43           gbdt           0.01               20         63
# 44           goss           0.01               50         63
# 45           gbdt           0.01               50         63
# 46           goss           0.01               50         63
# 47           gbdt           0.01               50         63
# 48           goss           0.01               20         63
# 49           gbdt           0.01               20         63
# 50           goss           0.01               50         63
# 51           gbdt           0.01               50         63
# 52           goss           0.01               50         63
# 53           gbdt           0.01               50         63
# 54           goss           0.01               20         63
# 55           gbdt           0.01               20         63
# 56           goss           0.01               50         63
# 57           gbdt           0.01               50         63
# 58           goss           0.01               50         63
# 59           gbdt           0.01               50         63
# 60           goss           0.01               50         63
# 61           gbdt           0.01               50         63
# 62           goss           0.01               20         63
# 63           gbdt           0.01               20         63
# 64           goss           0.01               20         63
# 65           gbdt           0.01               20         63
# 66           goss           0.01               50         63
# 67           gbdt           0.01               50         63
# 68           goss           0.01               50         63
# 69           gbdt           0.01               50         63
# 70           goss           0.01               50         63
# 71           gbdt           0.01               50         63
# 72           goss           0.01               20         63
# 73           gbdt           0.01               20         63
# 74           goss           0.01               50         63
# 75           gbdt           0.01               50         63
# 76           goss           0.01               20         63
# 77           gbdt           0.01               20         63
# 78           goss           0.01               20         63
# 79           gbdt           0.01               20         63
# 80           goss           0.01               50         63
# 81           gbdt           0.01               50         63
# 82           goss           0.01               20         63
# 83           gbdt           0.01               20         63
# 84           goss           0.01               50         63
# 85           gbdt           0.01               50         63
# 86           goss           0.01               20         63
# 87           gbdt           0.01               20         63
# 88           goss           0.01               20         63
# 89           gbdt           0.01               20         63
# 90           goss           0.01               50         63
# 91           gbdt           0.01               50         63
# 92           goss           0.01               50         63
# 93           gbdt           0.01               50         63
# 94           goss           0.01               50         31
# 95           gbdt           0.01               50         31
# 96           goss           0.01               50         63
# 97           gbdt           0.01               50         63
# 98           goss           0.01               50         63
# 99           gbdt           0.01               50         63
# 100          goss           0.01               20         31
# 101          gbdt           0.01               20         31
# 102          goss           0.01               50         63
# 103          gbdt           0.01               50         63
# 104          goss           0.01               20         63
# 105          gbdt           0.01               20         63
# 106          goss           0.01               50         31
# 107          gbdt           0.01               50         31
# 108          goss           0.01               50         63
# 109          gbdt           0.01               50         63
# 110          goss           0.01               20         31
# 111          gbdt           0.01               20         31
# 112          goss           0.01               20         63
# 113          gbdt           0.01               20         63
# 114          goss           0.01               20         63
# 115          gbdt           0.01               20         63
# 116          goss           0.01               20         63
# 117          gbdt           0.01               20         63
# 118          goss           0.01               50         31
# 119          gbdt           0.01               50         31
# 120          goss           0.01               20         63
# 121          gbdt           0.01               20         63
# 122          goss           0.01               20         63
# 123          gbdt           0.01               20         63
# 124          goss           0.01               20         31
# 125          gbdt           0.01               20         31
# 126          goss           0.01               50         31
# 127          gbdt           0.01               50         31
# 128          goss           0.01               20         63
# 129          gbdt           0.01               20         63
# 130          goss           0.01               50         31
# 131          gbdt           0.01               50         31
# 132          goss           0.01               20         31
# 133          gbdt           0.01               20         31
# 134          goss           0.01               20         31
# 135          gbdt           0.01               20         31
# 136          goss           0.01               20         63
# 137          gbdt           0.01               20         63
# 138          goss           0.01               20         31
# 139          gbdt           0.01               20         31
# 140          goss           0.01               50         31
# 141          gbdt           0.01               50         31
# 142          goss           0.01               50         31
# 143          gbdt           0.01               50         31
# 144          goss           0.01               20         31
# 145          gbdt           0.01               20         31
# 146          goss           0.01               50         63
# 147          gbdt           0.01               50         63
# 148          goss           0.01               50         31
# 149          gbdt           0.01               50         31
# 150          goss           0.01               50         31
# 151          gbdt           0.01               50         31
# 152          goss           0.01               50         31
# 153          gbdt           0.01               50         31
# 154          goss           0.01               20         31
# 155          gbdt           0.01               20         31
# 156          goss           0.01               20         31
# 157          gbdt           0.01               20         31
# 158          goss           0.01               20         31
# 159          gbdt           0.01               20         31
# 160          goss           0.01               50         31
# 161          gbdt           0.01               50         31
# 162          goss           0.01               20         31
# 163          gbdt           0.01               20         31
# 164          goss           0.01               50         31
# 165          gbdt           0.01               50         31
# 166          goss           0.01               20         31
# 167          gbdt           0.01               20         31
# 168          goss           0.01               50         31
# 169          gbdt           0.01               50         31
# 170          goss           0.01               50         31
# 171          gbdt           0.01               50         31
# 172          goss           0.01               20         31
# 173          gbdt           0.01               20         31
# 174          goss           0.01               50         31
# 175          gbdt           0.01               50         31
# 176          goss           0.01               20         31
# 177          gbdt           0.01               20         31
# 178          goss           0.01               20         31
# 179          gbdt           0.01               20         31
# 180          goss           0.01               20         31
# 181          gbdt           0.01               20         31
# 182          goss           0.01               50         31
# 183          gbdt           0.01               50         31
# 184          goss           0.01               50         31
# 185          gbdt           0.01               50         31
# 186          goss           0.01               20         31
# 187          gbdt           0.01               20         31
# 188          goss           0.01               20         31
# 189          gbdt           0.01               20         31
# 190          goss           0.01               50         31
# 191          gbdt           0.01               50         31
# 192          goss           0.01               50         31
# 193          gbdt           0.01               50         31
# 194          goss           0.01               20         31
# 195          gbdt           0.01               20         31
# 196          goss           0.01               50         31
# 197          gbdt           0.01               50         31
# 198          goss           0.01               20         31
# 199          gbdt           0.01               20         31
# 200          goss           0.01               20         31
# 201          gbdt           0.01               20         31
# 202          goss           0.01               50         31
# 203          gbdt           0.01               50         31
# 204          goss           0.01               50         31
# 205          gbdt           0.01               50         31
# 206          goss           0.01               50         31
# 207          gbdt           0.01               50         31
# 208          goss           0.01               50         31
# 209          gbdt           0.01               50         31
# 210          goss           0.01               20         31
# 211          gbdt           0.01               20         31
# 212          goss           0.01               20         31
# 213          gbdt           0.01               20         31
# 214          goss           0.01               50         31
# 215          gbdt           0.01               50         31
# 216          goss           0.01               20         31
# 217          gbdt           0.01               20         31
# 218          goss           0.01               20         31
# 219          gbdt           0.01               20         31
# 220          goss           0.01               20         31
# 221          gbdt           0.01               20         31
# 222          goss           0.01               50         31
# 223          gbdt           0.01               50         31
# 224          goss           0.01               50         31
# 225          gbdt           0.01               50         31
# 226          goss           0.01               50         31
# 227          gbdt           0.01               50         31
# 228          goss           0.01               50         31
# 229          gbdt           0.01               50         31
# 230          goss           0.01               20         31
# 231          gbdt           0.01               20         31
# 232          goss           0.01               20         31
# 233          gbdt           0.01               20         31
# 234          goss           0.01               20         31
# 235          gbdt           0.01               20         31
# 236          goss           0.01               20         31
# 237          gbdt           0.01               20         31
# 238          goss           0.01               50         31
# 239          gbdt           0.01               50         31
# 240          gbdt           0.10               50         63
# 241          gbdt           0.10               20         63
# 242          gbdt           0.10               50         63
# 243          gbdt           0.10               20         63
# 244          gbdt           0.10               50         63
# 245          gbdt           0.10               20         63
# 246          gbdt           0.10               50         63
# 247          gbdt           0.10               50         63
# 248          gbdt           0.10               50         63
# 249          gbdt           0.10               50         63
# 250          gbdt           0.10               50         63
# 251          gbdt           0.10               50         63
# 252          gbdt           0.10               20         63
# 253          gbdt           0.10               20         63
# 254          gbdt           0.10               20         63
# 255          gbdt           0.10               50         63
# 256          gbdt           0.10               50         63
# 257          gbdt           0.10               20         63
# 258          gbdt           0.10               50         63
# 259          gbdt           0.10               50         63
# 260          gbdt           0.10               50         63
# 261          gbdt           0.10               20         63
# 262          gbdt           0.10               50         63
# 263          gbdt           0.10               20         63
# 264          gbdt           0.10               20         63
# 265          gbdt           0.10               50         63
# 266          gbdt           0.10               20         63
# 267          gbdt           0.10               20         63
# 268          gbdt           0.10               20         63
# 269          gbdt           0.10               50         63
# 270          gbdt           0.10               50         63
# 271          gbdt           0.10               20         63
# 272          gbdt           0.10               50         63
# 273          gbdt           0.10               20         63
# 274          gbdt           0.10               20         63
# 275          gbdt           0.10               20         63
# 276          gbdt           0.10               50         63
# 277          goss           0.10               50         63
# 278          gbdt           0.10               50         63
# 279          gbdt           0.10               20         63
# 280          goss           0.10               50         63
# 281          gbdt           0.10               20         63
# 282          gbdt           0.10               20         63
# 283          gbdt           0.10               20         63
# 284          goss           0.10               50         63
# 285          gbdt           0.10               20         63
# 286          gbdt           0.10               50         63
# 287          gbdt           0.10               20         63
# 288          gbdt           0.10               20         63
# 289          gbdt           0.10               20         63
# 290          gbdt           0.10               50         63
# 291          gbdt           0.10               20         63
# 292          goss           0.10               50         63
# 293          gbdt           0.10               20         63
# 294          gbdt           0.10               50         63
# 295          goss           0.10               50         63
# 296          goss           0.10               50         63
# 297          goss           0.10               50         63
# 298          goss           0.10               50         63
# 299          gbdt           0.10               20         63
# 300          goss           0.10               50         63
# 301          goss           0.10               50         63
# 302          goss           0.10               20         63
# 303          gbdt           0.10               50         63
# 304          goss           0.10               50         63
# 305          goss           0.10               50         63
# 306          gbdt           0.10               20         63
# 307          goss           0.10               20         63
# 308          gbdt           0.10               50         63
# 309          gbdt           0.10               50         63
# 310          goss           0.10               50         63
# 311          goss           0.10               50         63
# 312          gbdt           0.10               50         63
# 313          goss           0.10               50         63
# 314          gbdt           0.10               50         63
# 315          goss           0.10               20         63
# 316          gbdt           0.10               50         63
# 317          goss           0.10               20         63
# 318          goss           0.10               50         63
# 319          goss           0.10               20         63
# 320          goss           0.10               20         63
# 321          gbdt           0.10               20         31
# 322          gbdt           0.10               50         31
# 323          goss           0.10               20         63
# 324          goss           0.10               20         63
# 325          goss           0.10               20         63
# 326          gbdt           0.10               50         31
# 327          goss           0.10               50         63
# 328          gbdt           0.03               50         63
# 329          goss           0.10               50         63
# 330          gbdt           0.10               20         63
# 331          gbdt           0.10               50         31
# 332          goss           0.10               50         63
# 333          gbdt           0.03               50         63
# 334          goss           0.10               50         31
# 335          gbdt           0.10               50         31
# 336          goss           0.10               50         63
# 337          gbdt           0.10               50         31
# 338          goss           0.10               20         63
# 339          gbdt           0.10               20         31
# 340          gbdt           0.03               20         63
# 341          goss           0.10               50         63
# 342          goss           0.03               50         63
# 343          goss           0.10               20         63
# 344          gbdt           0.10               20         31
# 345          gbdt           0.03               50         63
# 346          gbdt           0.10               20         31
# 347          gbdt           0.10               50         31
# 348          gbdt           0.10               50         31
# 349          goss           0.10               20         63
# 350          goss           0.10               50         63
# 351          gbdt           0.10               20         31
# 352          gbdt           0.10               50         31
# 353          gbdt           0.03               50         63
# 354          goss           0.10               20         63
# 355          gbdt           0.03               50         63
# 356          gbdt           0.10               50         31
# 357          goss           0.10               20         63
# 358          gbdt           0.03               20         63
# 359          gbdt           0.10               50         31
# 360          gbdt           0.03               20         63
# 361          gbdt           0.10               50         31
# 362          gbdt           0.10               20         31
# 363          gbdt           0.03               20         63
# 364          gbdt           0.03               20         63
# 365          gbdt           0.03               50         63
# 366          gbdt           0.03               20         63
# 367          gbdt           0.03               50         63
# 368          goss           0.10               50         63
# 369          gbdt           0.10               20         31
# 370          gbdt           0.10               20         31
# 371          goss           0.10               20         63
# 372          gbdt           0.03               50         63
# 373          gbdt           0.10               50         31
# 374          gbdt           0.10               50         31
# 375          gbdt           0.03               50         63
# 376          gbdt           0.03               20         63
# 377          goss           0.03               20         63
# 378          gbdt           0.03               20         63
# 379          goss           0.10               50         31
# 380          goss           0.10               20         63
# 381          goss           0.03               50         63
# 382          gbdt           0.03               50         63
# 383          gbdt           0.10               20         31
# 384          gbdt           0.03               50         63
# 385          gbdt           0.03               50         63
# 386          gbdt           0.10               50         31
# 387          gbdt           0.10               20         31
# 388          gbdt           0.10               20         31
# 389          gbdt           0.03               50         63
# 390          goss           0.10               50         31
# 391          gbdt           0.10               20         31
# 392          goss           0.10               20         63
# 393          gbdt           0.10               50         31
# 394          goss           0.10               50         31
# 395          gbdt           0.03               20         63
# 396          gbdt           0.10               50         31
# 397          goss           0.10               20         63
# 398          gbdt           0.03               50         63
# 399          goss           0.10               20         63
# 400          gbdt           0.03               20         63
# 401          gbdt           0.03               50         63
# 402          goss           0.10               50         63
# 403          goss           0.03               20         63
# 404          gbdt           0.03               20         63
# 405          goss           0.03               20         63
# 406          gbdt           0.03               50         63
# 407          goss           0.10               20         63
# 408          gbdt           0.03               20         63
# 409          gbdt           0.03               20         63
# 410          goss           0.03               20         63
# 411          gbdt           0.10               20         31
# 412          goss           0.10               50         63
# 413          goss           0.10               50         31
# 414          gbdt           0.03               50         63
# 415          gbdt           0.03               20         63
# 416          goss           0.10               20         63
# 417          gbdt           0.10               50         31
# 418          goss           0.03               20         63
# 419          gbdt           0.10               50         31
# 420          goss           0.10               20         63
# 421          gbdt           0.03               20         63
# 422          gbdt           0.03               20         63
# 423          goss           0.10               50         31
# 424          goss           0.10               50         63
# 425          goss           0.10               20         63
# 426          gbdt           0.03               50         63
# 427          gbdt           0.10               20         31
# 428          gbdt           0.03               20         63
# 429          goss           0.10               50         31
# 430          goss           0.10               50         31
# 431          gbdt           0.03               20         63
# 432          gbdt           0.03               50         63
# 433          gbdt           0.10               20         31
# 434          gbdt           0.03               50         63
# 435          goss           0.10               50         31
# 436          goss           0.10               50         31
# 437          gbdt           0.10               20         31
# 438          gbdt           0.10               50         31
# 439          goss           0.03               20         63
# 440          gbdt           0.10               50         31
# 441          goss           0.10               20         63
# 442          gbdt           0.03               20         63
# 443          goss           0.03               50         63
# 444          goss           0.10               20         31
# 445          gbdt           0.10               50         31
# 446          gbdt           0.03               20         63
# 447          gbdt           0.10               20         31
# 448          goss           0.10               20         63
# 449          gbdt           0.10               50         31
# 450          goss           0.10               50         31
# 451          goss           0.10               20         31
# 452          gbdt           0.03               20         63
# 453          goss           0.03               50         63
# 454          goss           0.03               50         63
# 455          goss           0.03               20         63
# 456          gbdt           0.03               20         63
# 457          gbdt           0.10               50         31
# 458          goss           0.03               50         63
# 459          goss           0.03               20         63
# 460          goss           0.03               50         63
# 461          goss           0.03               20         63
# 462          goss           0.03               20         63
# 463          goss           0.03               50         63
# 464          goss           0.03               50         63
# 465          goss           0.03               20         63
# 466          goss           0.10               20         31
# 467          gbdt           0.03               20         63
# 468          gbdt           0.10               50         31
# 469          goss           0.10               50         31
# 470          goss           0.10               20         31
# 471          goss           0.10               50         31
# 472          goss           0.10               20         63
# 473          goss           0.03               50         63
# 474          goss           0.03               20         63
# 475          gbdt           0.03               50         63
# 476          gbdt           0.03               20         63
# 477          gbdt           0.10               20         31
# 478          goss           0.10               20         63
# 479          goss           0.10               20         31
# 480          goss           0.03               20         63
# 481          gbdt           0.10               20         31
# 482          gbdt           0.10               50         31
# 483          goss           0.10               50         63
# 484          goss           0.03               50         63
# 485          goss           0.10               50         31
# 486          gbdt           0.03               20         63
# 487          gbdt           0.03               50         63
# 488          gbdt           0.03               50         63
# 489          goss           0.10               20         63
# 490          goss           0.03               50         63
# 491          goss           0.10               50         63
# 492          goss           0.10               50         31
# 493          goss           0.03               50         63
# 494          goss           0.03               20         63
# 495          gbdt           0.03               50         63
# 496          goss           0.03               50         63
# 497          gbdt           0.03               50         63
# 498          gbdt           0.10               20         31
# 499          goss           0.03               20         63
# 500          gbdt           0.10               50         31
# 501          gbdt           0.03               20         63
# 502          gbdt           0.10               20         31
# 503          gbdt           0.10               20         31
# 504          goss           0.10               20         31
# 505          goss           0.03               20         63
# 506          goss           0.03               20         63
# 507          gbdt           0.03               50         63
# 508          goss           0.10               20         31
# 509          goss           0.03               20         63
# 510          gbdt           0.10               20         31
# 511          gbdt           0.10               20         31
# 512          gbdt           0.03               50         63
# 513          goss           0.10               20         31
# 514          gbdt           0.03               20         63
# 515          goss           0.10               20         63
# 516          goss           0.10               20         31
# 517          gbdt           0.03               50         63
# 518          gbdt           0.10               20         31
# 519          gbdt           0.10               50         31
# 520          goss           0.10               50         31
# 521          gbdt           0.10               20         31
# 522          goss           0.03               20         63
# 523          gbdt           0.03               50         63
# 524          goss           0.03               50         63
# 525          goss           0.03               50         63
# 526          goss           0.10               50         31
# 527          gbdt           0.10               20         31
# 528          goss           0.03               50         63
# 529          goss           0.10               50         31
# 530          goss           0.10               50         31
# 531          gbdt           0.03               50         63
# 532          goss           0.03               50         63
# 533          goss           0.10               50         31
# 534          gbdt           0.03               20         63
# 535          goss           0.03               50         63
# 536          goss           0.10               20         31
# 537          goss           0.03               20         63
# 538          goss           0.10               20         31
# 539          gbdt           0.10               20         31
# 540          gbdt           0.03               20         63
# 541          goss           0.03               20         63
# 542          goss           0.03               50         63
# 543          goss           0.10               50         31
# 544          goss           0.03               50         63
# 545          goss           0.03               50         63
# 546          goss           0.10               20         31
# 547          goss           0.10               50         63
# 548          goss           0.03               20         63
# 549          goss           0.10               20         31
# 550          goss           0.03               20         63
# 551          goss           0.10               20         31
# 552          goss           0.03               50         63
# 553          goss           0.10               50         31
# 554          gbdt           0.10               50         31
# 555          gbdt           0.10               50         31
# 556          gbdt           0.03               20         31
# 557          goss           0.03               50         63
# 558          gbdt           0.10               50         31
# 559          goss           0.03               50         63
# 560          goss           0.03               20         63
# 561          goss           0.10               50         31
# 562          gbdt           0.10               20         31
# 563          gbdt           0.10               20         31
# 564          goss           0.03               20         63
# 565          goss           0.10               50         31
# 566          goss           0.10               20         31
# 567          goss           0.03               50         63
# 568          goss           0.03               20         63
# 569          goss           0.10               20         31
# 570          goss           0.03               20         63
# 571          goss           0.03               50         63
# 572          goss           0.03               20         63
# 573          goss           0.10               50         31
# 574          goss           0.10               20         63
# 575          gbdt           0.03               20         63
# 576          goss           0.10               20         31
# 577          goss           0.10               50         31
# 578          goss           0.03               50         31
# 579          goss           0.03               50         63
# 580          goss           0.10               20         31
# 581          goss           0.10               50         31
# 582          goss           0.10               20         31
# 583          goss           0.10               20         31
# 584          goss           0.10               50         31
# 585          goss           0.10               20         31
# 586          goss           0.10               50         63
# 587          goss           0.03               50         31
# 588          gbdt           0.03               20         31
# 589          goss           0.10               20         31
# 590          gbdt           0.03               20         31
# 591          gbdt           0.03               50         31
# 592          goss           0.03               20         31
# 593          goss           0.10               20         31
# 594          gbdt           0.03               20         31
# 595          goss           0.03               20         31
# 596          goss           0.03               20         63
# 597          gbdt           0.03               20         31
# 598          gbdt           0.03               20         31
# 599          gbdt           0.03               50         31
# 600          goss           0.03               50         31
# 601          gbdt           0.03               50         31
# 602          gbdt           0.03               20         31
# 603          gbdt           0.03               20         31
# 604          goss           0.03               20         63
# 605          goss           0.10               20         31
# 606          goss           0.03               20         31
# 607          gbdt           0.03               50         31
# 608          gbdt           0.03               50         31
# 609          goss           0.03               20         31
# 610          gbdt           0.03               20         31
# 611          gbdt           0.03               50         31
# 612          goss           0.03               50         31
# 613          gbdt           0.03               50         31
# 614          gbdt           0.03               50         31
# 615          goss           0.03               50         31
# 616          gbdt           0.03               20         31
# 617          goss           0.03               50         31
# 618          gbdt           0.03               50         31
# 619          gbdt           0.03               50         31
# 620          gbdt           0.03               20         31
# 621          gbdt           0.03               50         31
# 622          goss           0.10               20         31
# 623          goss           0.03               20         31
# 624          gbdt           0.03               20         31
# 625          goss           0.03               50         63
# 626          gbdt           0.03               50         31
# 627          gbdt           0.03               20         31
# 628          gbdt           0.03               50         31
# 629          gbdt           0.03               20         31
# 630          goss           0.03               20         31
# 631          gbdt           0.03               50         31
# 632          goss           0.03               20         31
# 633          gbdt           0.03               20         31
# 634          goss           0.03               20         31
# 635          goss           0.03               20         31
# 636          goss           0.03               20         31
# 637          goss           0.10               20         31
# 638          gbdt           0.03               20         31
# 639          gbdt           0.03               20         31
# 640          gbdt           0.03               20         31
# 641          gbdt           0.03               50         31
# 642          gbdt           0.03               50         31
# 643          gbdt           0.03               20         31
# 644          gbdt           0.03               50         31
# 645          goss           0.03               50         31
# 646          goss           0.03               50         63
# 647          goss           0.03               50         31
# 648          goss           0.03               50         31
# 649          gbdt           0.03               50         31
# 650          gbdt           0.03               20         31
# 651          goss           0.03               20         31
# 652          gbdt           0.03               50         31
# 653          gbdt           0.03               20         31
# 654          goss           0.03               50         31
# 655          gbdt           0.03               50         31
# 656          goss           0.03               50         31
# 657          goss           0.10               20         31
# 658          gbdt           0.03               50         31
# 659          goss           0.03               20         31
# 660          gbdt           0.03               50         31
# 661          goss           0.03               50         31
# 662          goss           0.10               50         31
# 663          goss           0.03               20         31
# 664          gbdt           0.03               20         31
# 665          goss           0.03               50         31
# 666          gbdt           0.03               20         31
# 667          goss           0.03               50         31
# 668          goss           0.03               50         31
# 669          gbdt           0.03               20         31
# 670          goss           0.03               20         31
# 671          goss           0.03               20         31
# 672          gbdt           0.03               50         31
# 673          goss           0.03               50         31
# 674          gbdt           0.03               50         31
# 675          gbdt           0.03               20         31
# 676          goss           0.03               20         31
# 677          goss           0.03               20         31
# 678          gbdt           0.03               20         31
# 679          goss           0.03               20         31
# 680          gbdt           0.03               50         31
# 681          goss           0.03               20         31
# 682          goss           0.03               20         31
# 683          goss           0.03               50         31
# 684          gbdt           0.03               50         31
# 685          gbdt           0.03               20         31
# 686          goss           0.03               20         31
# 687          goss           0.03               20         31
# 688          goss           0.03               20         31
# 689          gbdt           0.03               50         31
# 690          goss           0.10               20         31
# 691          goss           0.03               50         31
# 692          goss           0.03               50         31
# 693          goss           0.03               50         31
# 694          goss           0.03               50         31
# 695          gbdt           0.03               20         31
# 696          gbdt           0.03               50         31
# 697          goss           0.03               50         31
# 698          gbdt           0.03               20         31
# 699          goss           0.03               50         31
# 700          gbdt           0.03               50         31
# 701          goss           0.03               20         31
# 702          goss           0.03               20         31
# 703          goss           0.03               50         31
# 704          goss           0.10               50         31
# 705          goss           0.10               20         31
# 706          goss           0.03               50         31
# 707          goss           0.03               20         31
# 708          goss           0.03               20         31
# 709          goss           0.03               50         31
# 710          goss           0.10               20         31
# 711          goss           0.03               20         31
# 712          goss           0.03               50         31
# 713          goss           0.03               50         31
# 714          gbdt           0.03               50         31
# 715          goss           0.03               50         31
# 716          gbdt           0.03               20         31
# 717          goss           0.03               20         31
# 718          goss           0.03               50         31
# 719          goss           0.03               20         31
#
#      feature_fraction max_bin         lambda  \
# 0                 0.9     102    [0.01, 0.1]
# 1                 0.9     102    [0.01, 0.1]
# 2                 0.9     255     [0.0, 0.0]
# 3                 0.9     255     [0.0, 0.0]
# 4                 0.9     255  [0.001, 0.01]
# 5                 0.9     255  [0.001, 0.01]
# 6                 0.9     255    [1.0, 0.01]
# 7                 0.9     255    [1.0, 0.01]
# 8                 0.9     102    [1.0, 0.01]
# 9                 0.9     102    [1.0, 0.01]
# 10                0.9      16    [0.01, 0.1]
# 11                0.9      16    [0.01, 0.1]
# 12                0.9     255    [1.0, 0.01]
# 13                0.9     255    [1.0, 0.01]
# 14                0.9     102  [0.001, 0.01]
# 15                0.9     102  [0.001, 0.01]
# 16                0.9     102    [0.01, 0.1]
# 17                0.9     102    [0.01, 0.1]
# 18                0.9      16    [0.01, 0.1]
# 19                0.9      16    [0.01, 0.1]
# 20                0.9     102    [0.01, 1.0]
# 21                0.9     102    [0.01, 1.0]
# 22                0.9     102    [1.0, 0.01]
# 23                0.9     102    [1.0, 0.01]
# 24                1.0      16    [0.01, 1.0]
# 25                1.0      16    [0.01, 1.0]
# 26                0.9     255    [0.01, 0.1]
# 27                0.9     255    [0.01, 0.1]
# 28                1.0      16    [0.01, 0.1]
# 29                1.0      16    [0.01, 0.1]
# 30                1.0      16  [0.001, 0.01]
# 31                1.0      16  [0.001, 0.01]
# 32                0.9      16    [0.01, 1.0]
# 33                0.9      16    [0.01, 1.0]
# 34                0.9     255    [0.01, 0.1]
# 35                0.9     255    [0.01, 0.1]
# 36                0.9      16    [1.0, 0.01]
# ...
# 365     0.496547     0.497385     0.498038
# 366     0.497511     0.496218     0.498035
# 367     0.498658     0.495036     0.498022
# 368     0.499679     0.495819     0.498021
# 369     0.495470     0.499409     0.498020
# 370     0.495174     0.496213     0.498017
# 371     0.500270     0.495877     0.498007
# 372     0.495479     0.498282     0.498001
# 373     0.497691     0.497260     0.497993
# 374     0.496634     0.500666     0.497990
# 375     0.497925     0.497402     0.497986
# 376     0.495697     0.498586     0.497964
# 377     0.497056     0.496724     0.497927
# 378     0.498012     0.496398     0.497923
# 379     0.498117     0.496642     0.497922
# 380     0.493702     0.502227     0.497860
# 381     0.497057     0.497080     0.497859
# 382     0.498349     0.498777     0.497859
# 383     0.496953     0.497716     0.497807
# 384     0.497928     0.496507     0.497794
# 385     0.498893     0.497502     0.497794
# 386     0.497902     0.496416     0.497762
# 387     0.497585     0.496992     0.497762
# 388     0.497269     0.492599     0.497756
# 389     0.496651     0.496601     0.497743
# 390     0.502060     0.498650     0.497737
# 391     0.497483     0.496729     0.497728
# 392     0.497236     0.492937     0.497726
# 393     0.496955     0.492487     0.497705
# 394     0.493565     0.500872     0.497702
# 395     0.495479     0.497201     0.497700
# 396     0.496958     0.499849     0.497682
# 397     0.492433     0.498468     0.497655
# 398     0.496212     0.495130     0.497648
# 399     0.496981     0.495556     0.497639
# 400     0.494517     0.495456     0.497606
# 401     0.497393     0.495212     0.497526
# 402     0.499509     0.497254     0.497523
# 403     0.498220     0.497327     0.497514
# 404     0.495064     0.497276     0.497501
# 405     0.498435     0.496233     0.497479
# 406     0.496018     0.497175     0.497474
# 407     0.497815     0.494585     0.497452
# 408     0.496028     0.497839     0.497452
# 409     0.494845     0.497502     0.497450
# 410     0.497586     0.496121     0.497440
# 411     0.496528     0.492699     0.497429
# 412     0.495172     0.493426     0.497427
# 413     0.498432     0.492710     0.497415
# 414     0.495258     0.495831     0.497401
# 415     0.496638     0.495130     0.497373
# 416     0.500666     0.492387     0.497354
# 417     0.500967     0.494542     0.497335
# 418     0.498536     0.496857     0.497325
# 419     0.496529     0.495149     0.497306
# 420     0.502423     0.498090     0.497294
# 421     0.497800     0.494341     0.497293
# 422     0.495583     0.493673     0.497289
# 423     0.495895     0.495249     0.497282
# 424     0.494550     0.498019     0.497274
# 425     0.498612     0.494044     0.497262
# 426     0.497179     0.495627     0.497255
# 427     0.496633     0.493347     0.497248
# 428     0.496859     0.495137     0.497238
# 429     0.499276     0.496761     0.497217
# 430     0.501407     0.497278     0.497217
# 431     0.493988     0.495929     0.497213
# 432     0.493670     0.498628     0.497201
# 433     0.496114     0.496237     0.497188
# 434     0.497482     0.494870     0.497178
# 435     0.493053     0.495247     0.497166
# 436     0.496847     0.490047     0.497156
# 437     0.499066     0.492290     0.497140
# 438     0.497480     0.496217     0.497139
# 439     0.496105     0.492411     0.497135
# 440     0.496739     0.494290     0.497128
# 441     0.497831     0.490952     0.497123
# 442     0.495576     0.497999     0.497105
# 443     0.496951     0.497175     0.497104
# 444     0.494413     0.496443     0.497099
# 445     0.497058     0.494107     0.497098
# 446     0.495365     0.495837     0.497088
# 447     0.493459     0.497213     0.497084
# 448     0.494542     0.493724     0.497078
# 449     0.496848     0.492912     0.497070
# 450     0.499065     0.500460     0.497063
# 451     0.498861     0.494525     0.497062
# 452     0.494308     0.494341     0.497054
# 453     0.496746     0.496022     0.497040
# 454     0.496316     0.498464     0.497024
# 455     0.500024     0.498174     0.497023
# 456     0.495579     0.496366     0.497013
# 457     0.494735     0.497839     0.497002
# 458     0.497374     0.496781     0.496968
# 459     0.498539     0.497828     0.496954
# 460     0.500439     0.499555     0.496949
# 461     0.494732     0.496766     0.496941
# 462     0.496859     0.493882     0.496921
# 463     0.500547     0.496793     0.496920
# 464     0.495471     0.493882     0.496846
# 465     0.495051     0.497094     0.496830
# 466     0.501087     0.495571     0.496830
# 467     0.495154     0.492196     0.496824
# 468     0.499173     0.490899     0.496823
# 469     0.500755     0.494617     0.496811
# 470     0.496000     0.491531     0.496768
# 471     0.496422     0.497497     0.496757
# 472     0.494790     0.495570     0.496757
# 473     0.498009     0.500083     0.496753
# 474     0.496006     0.499460     0.496730
# 475     0.496957     0.494444     0.496720
# 476     0.495049     0.495615     0.496712
# 477     0.498220     0.498137     0.496674
# 478     0.496027     0.497868     0.496671
# 479     0.493253     0.494299     0.496667
# 480     0.498325     0.493919     0.496666
# 481     0.492299     0.494626     0.496637
# 482     0.499383     0.495676     0.496632
# 483     0.494786     0.496713     0.496601
# 484     0.496528     0.495488     0.496576
# 485     0.500860     0.493882     0.496563
# 486     0.495690     0.493293     0.496545
# 487     0.493670     0.494887     0.496525
# 488     0.495152     0.493943     0.496508
# 489     0.495593     0.495532     0.496507
# 490     0.498008     0.492820     0.496500
# 491     0.491443     0.497722     0.496488
# 492     0.497374     0.491531     0.496483
# 493     0.499171     0.493570     0.496477
# 494     0.497164     0.498506     0.496472
# 495     0.494943     0.494574     0.496472
# 496     0.494209     0.496345     0.496462
# 497     0.496533     0.495086     0.496460
# 498     0.496214     0.491974     0.496423
# 499     0.496316     0.496787     0.496409
# 500     0.497694     0.492384     0.496391
# 501     0.493776     0.495985     0.496387
# 502     0.491203     0.495899     0.496385
# 503     0.496847     0.493554     0.496371
# 504     0.495480     0.499952     0.496371
# 505     0.499506     0.493665     0.496371
# 506     0.498554     0.495826     0.496350
# 507     0.494941     0.493685     0.496346
# 508     0.492003     0.497305     0.496335
# 509     0.497587     0.495799     0.496334
# 510     0.490324     0.493973     0.496323
# 511     0.497903     0.493125     0.496322
# 512     0.493884     0.495103     0.496310
# 513     0.498647     0.492592     0.496306
# 514     0.495153     0.496453     0.496297
# 515     0.491958     0.495736     0.496256
# 516     0.493251     0.498919     0.496246
# 517     0.495681     0.494107     0.496229
# 518     0.498225     0.494090     0.496221
# 519     0.497805     0.490200     0.496217
# 520     0.491999     0.495269     0.496206
# 521     0.492837     0.496937     0.496193
# 522     0.496105     0.494426     0.496169
# 523     0.495047     0.493488     0.496155
# 524     0.494419     0.496992     0.496145
# 525     0.496742     0.497659     0.496128
# 526     0.494835     0.496654     0.496118
# 527     0.495366     0.494513     0.496099
# 528     0.497380     0.494418     0.496093
# 529     0.493680     0.494617     0.496068
# 530     0.491673     0.493714     0.496055
# 531     0.495682     0.492245     0.496017
# 532     0.499488     0.495159     0.496009
# 533     0.501813     0.496957     0.496008
# 534     0.491764     0.496764     0.495988
# 535     0.495692     0.495269     0.495967
# 536     0.494729     0.492069     0.495950
# 537     0.499813     0.491864     0.495935
# 538     0.499490     0.494819     0.495904
# 539     0.497480     0.495889     0.495891
# 540     0.494623     0.494676     0.495876
# 541     0.498326     0.495092     0.495860
# 542     0.498008     0.494415     0.495858
# 543     0.490959     0.497171     0.495832
# 544     0.497163     0.496258     0.495768
# 545     0.491033     0.495934     0.495767
# 546     0.495682     0.491854     0.495758
# 547     0.486808     0.493108     0.495725
# 548     0.494204     0.493570     0.495698
# 549     0.493798     0.493227     0.495678
# 550     0.498011     0.492514     0.495668
# 551     0.494416     0.488143     0.495646
# 552     0.491372     0.497305     0.495641
# 553     0.498644     0.493133     0.495606
# 554     0.494520     0.494331     0.495587
# 555     0.496112     0.491107     0.495559
# 556     0.495386     0.496997     0.495531
# 557     0.493575     0.493762     0.495519
# 558     0.497480     0.492708     0.495508
# 559     0.496742     0.494762     0.495506
# 560     0.494627     0.496258     0.495505
# 561     0.494442     0.492713     0.495486
# 562     0.494634     0.491977     0.495470
# 563     0.493249     0.493141     0.495458
# 564     0.494211     0.493793     0.495428
# 565     0.496853     0.494004     0.495402
# 566     0.490846     0.495465     0.495389
# 567     0.493892     0.492914     0.495370
# 568     0.496105     0.495179     0.495320
# 569     0.491689     0.494740     0.495292
# 570     0.494941     0.491265     0.495282
# 571     0.494630     0.496350     0.495278
# 572     0.493255     0.497334     0.495276
# 573     0.497196     0.494744     0.495241
# 574     0.498952     0.490422     0.495236
# 575     0.495152     0.492738     0.495189
# 576     0.498114     0.491447     0.495176
# 577     0.493464     0.495358     0.495140
# 578     0.496337     0.492296     0.495136
# 579     0.492945     0.494017     0.495103
# 580     0.495787     0.492722     0.495041
# 581     0.495895     0.491535     0.495039
# 582     0.500973     0.488377     0.495010
# 583     0.495152     0.489940     0.495006
# 584     0.498758     0.493144     0.494996
# 585     0.493780     0.494633     0.494981
# 586     0.485422     0.494275     0.494947
# 587     0.494851     0.497260     0.494918
# 588     0.494338     0.493996     0.494882
# 589     0.492724     0.490471     0.494843
# 590     0.493265     0.493785     0.494837
# 591     0.491480     0.494856     0.494818
# 592     0.495389     0.492909     0.494812
# 593     0.493990     0.493127     0.494785
# 594     0.494531     0.494331     0.494775
# 595     0.494867     0.495999     0.494742
# 596     0.493260     0.496879     0.494724
# 597     0.492762     0.495147     0.494715
# 598     0.490334     0.496009     0.494689
# 599     0.493301     0.494944     0.494664
# 600     0.494867     0.497931     0.494662
# 601     0.491935     0.494290     0.494654
# 602     0.492742     0.495723     0.494649
# 603     0.493174     0.494008     0.494627
# 604     0.492408     0.494537     0.494626
# 605     0.493152     0.493763     0.494622
# 606     0.491559     0.493989     0.494617
# 607     0.493287     0.496378     0.494600
# 608     0.493093     0.491969     0.494594
# 609     0.493179     0.498021     0.494591
# 610     0.491598     0.494454     0.494587
# 611     0.492995     0.495149     0.494562
# 612     0.494439     0.493550     0.494556
# 613     0.493376     0.494660     0.494545
# 614     0.492762     0.494844     0.494531
# 615     0.491319     0.497361     0.494530
# 616     0.491706     0.495477     0.494522
# 617     0.492733     0.495256     0.494511
# 618     0.493809     0.496757     0.494506
# 619     0.493062     0.496340     0.494470
# 620     0.492742     0.494978     0.494459
# 621     0.493700     0.495473     0.494449
# 622     0.491722     0.492697     0.494442
# 623     0.493935     0.494730     0.494432
# 624     0.493509     0.493359     0.494431
# 625     0.495155     0.491873     0.494426
# 626     0.491399     0.495484     0.494380
# 627     0.494252     0.495051     0.494377
# 628     0.494956     0.494299     0.494370
# 629     0.492875     0.493466     0.494308
# 630     0.491662     0.494719     0.494296
# 631     0.488764     0.494719     0.494271
# 632     0.494867     0.492380     0.494270
# 633     0.492019     0.495788     0.494268
# 634     0.491410     0.495152     0.494251
# 635     0.493921     0.495910     0.494240
# 636     0.495746     0.491955     0.494230
# 637     0.498643     0.492933     0.494226
# 638     0.493623     0.494426     0.494197
# 639     0.491682     0.497628     0.494162
# 640     0.493174     0.494964     0.494143
# 641     0.491820     0.494522     0.494111
# 642     0.491999     0.496576     0.494094
# 643     0.493088     0.493229     0.494094
# 644     0.492137     0.493135     0.494058
# 645     0.488945     0.492489     0.494054
# 646     0.491878     0.491881     0.494043
# 647     0.494010     0.494077     0.494031
# 648     0.491301     0.493789     0.494029
# 649     0.493700     0.495899     0.494004
# 650     0.494252     0.493347     0.493984
# 651     0.495501     0.492490     0.493983
# 652     0.492940     0.496576     0.493981
# 653     0.493831     0.491966     0.493960
# 654     0.494559     0.495249     0.493954
# 655     0.494450     0.493141     0.493940
# 656     0.493940     0.490792     0.493939
# 657     0.493785     0.490494     0.493938
# 658     0.493093     0.491969     0.493934
# 659     0.494551     0.492820     0.493922
# 660     0.492237     0.493233     0.493920
# 661     0.497405     0.493240     0.493912
# 662     0.495576     0.490908     0.493911
# 663     0.494655     0.491558     0.493904
# 664     0.492766     0.495783     0.493883
# 665     0.491899     0.492820     0.493875
# 666     0.491697     0.492492     0.493864
# 667     0.492880     0.490365     0.493855
# 668     0.494890     0.493549     0.493852
# 669     0.490880     0.494396     0.493848
# 670     0.493405     0.495253     0.493842
# 671     0.497168     0.492713     0.493833
# 672     0.490875     0.493885     0.493820
# 673     0.494230     0.492924     0.493818
# 674     0.494034     0.492389     0.493806
# 675     0.490264     0.495807     0.493804
# 676     0.493894     0.493574     0.493804
# 677     0.490478     0.494085     0.493799
# 678     0.490033     0.496121     0.493784
# 679     0.493142     0.493347     0.493748
# 680     0.494442     0.493449     0.493743
# 681     0.493917     0.490792     0.493729
# 682     0.495482     0.492933     0.493728
# 683     0.491953     0.493349     0.493718
# 684     0.492979     0.491867     0.493709
# 685     0.491826     0.492833     0.493686
# 686     0.494857     0.492823     0.493615
# 687     0.490334     0.493868     0.493598
# 688     0.494017     0.493127     0.493587
# 689     0.491072     0.492603     0.493529
# 690     0.490088     0.491743     0.493519
# 691     0.492984     0.495467     0.493517
# 692     0.492148     0.490684     0.493515
# 693     0.495478     0.492595     0.493478
# 694     0.493047     0.492940     0.493467
# 695     0.490569     0.494116     0.493464
# 696     0.492263     0.493347     0.493438
# 697     0.490795     0.493466     0.493418
# 698     0.492367     0.490810     0.493404
# 699     0.494460     0.495247     0.493400
# 700     0.493093     0.491760     0.493386
# 701     0.489666     0.491639     0.493367
# 702     0.490039     0.492592     0.493361
# 703     0.493481     0.492595     0.493355
# 704     0.497482     0.488032     0.493325
# 705     0.495471     0.491763     0.493307
# 706     0.490271     0.492910     0.493252
# 707     0.494346     0.493148     0.493234
# 708     0.493059     0.491325     0.493226
# 709     0.493192     0.489948     0.493180
# 710     0.492529     0.493561     0.493134
# 711     0.496538     0.492296     0.493075
# 712     0.491325     0.493789     0.493022
# 713     0.490898     0.490799     0.493013
# 714     0.494573     0.492826     0.492894
# 715     0.490485     0.491539     0.492812
# 716     0.493220     0.489326     0.492650
# 717     0.491307     0.489944     0.492492
# 718     0.492533     0.490057     0.492376
# 719     0.493600     0.490157     0.492061

# %%
pd.set_option('display.max_row', 10)

# %%
from sklearn.metrics import classification_report, f1_score, confusion_matrix, precision_score, matthews_corrcoef

def predict(X, mode='best_mean'):
    if mode == 'best_mode':
        y_preds = []
        for i in range(sum(K)):
            y_preds.append(df_model.loc[0, f'model_{i}'].predict(X))
        y_preds = np.array(y_preds)
        y_preds = scipy.stats.mode(y_preds)
        y_preds = y_preds[0]
        y_preds = y_preds.reshape(-1)
    elif mode == 'best_mean':
        y_preds = []
        for i in range(sum(K)):
            y_preds.append(df_model.loc[0, f'model_{i}'].predict_proba(X))
        y_preds = np.mean(np.array(y_preds), axis=0)
        y_preds = np.argmax(y_preds, axis=-1)
    elif mode == 'ensemble_mode':
        y_preds = []
        for i in df_model.index:
            for j in range(sum(K)):
                y_preds.append(df_model.loc[i, f'model_{j}'].predict(X))
        y_preds = np.array(y_preds)
        y_preds = scipy.stats.mode(y_preds)
        y_preds = y_preds[0]
        y_preds = y_preds.reshape(-1)
    elif mode == 'ensemble_mean':
        y_preds = []
        for i in df_model.index:
            for j in range(sum(K)):
                y_preds.append(df_model.loc[i, f'model_{j}'].predict_proba(X))
        y_preds = np.mean(np.array(y_preds), axis=0)
        y_preds = np.argmax(y_preds, axis=-1)
    elif mode == 'weighted_ensemble_mean':
        y_preds = []
#         model_weight = df_model['average_mcc'].apply(lambda a: a/df_model['average_mcc'].sum())
        model_weight = []
        for i in df_model.index:
            model_weight.append(1 + np.log10(df_model.shape[0] - i + 1))
        print(model_weight[:10])
        for i in df_model.index:
            for j in range(sum(K)):
                y_preds.append(
                    df_model.loc[i, f'model_{j}'].predict_proba(X) *
                    model_weight[i]
                )
        y_preds = np.array(y_preds)
        y_preds = np.mean(y_preds, axis=0)
        y_preds = np.argmax(y_preds, axis=-1)
    else:
        raise ValueError("Mode isn't supported")
    
    return y_preds

def metrics(y_true, y_pred):
    print('Weighted F1 Score :', f1_score(y_true, y_pred, average='weighted'))
    print('MCC Score :', matthews_corrcoef(y_true, y_pred))
    cm = confusion_matrix(y_true, y_pred)
    cm = pd.DataFrame(cm, [0, 1], [0, 1])

    sns.heatmap(cm, annot=True, cmap="YlGnBu", fmt="d")
    plt.show()

# %%
y_train_pred = predict(X_train, mode='best_mode')
metrics(y_train, y_train_pred)
# Out:
# Weighted F1 Score : 0.8757335448075203
# MCC Score : 0.5311657205047589

# %%
y_train_pred2 = predict(X_train, mode='best_mean')
metrics(y_train, y_train_pred2)
# Out:
# Weighted F1 Score : 0.8755781887001687
# MCC Score : 0.531428308117599

# %%
y_train_pred3 = predict(X_train, mode='ensemble_mode')
metrics(y_train, y_train_pred3)
# Out:
# Weighted F1 Score : 0.8586140956011632
# MCC Score : 0.5409790552245658

# %%
y_train_pred4 = predict(X_train, mode='ensemble_mean')
metrics(y_train, y_train_pred4)
# Out:
# Weighted F1 Score : 0.8598820170129756
# MCC Score : 0.5419519963890341

# %%
y_train_pred5 = predict(X_train, mode='weighted_ensemble_mean')
metrics(y_train, y_train_pred5)
# Out:
# [3.857935264719429, 3.8573324964312685, 3.8567288903828825, 3.8561244442423, 3.8555191556678, 3.8549130223078554, 3.8543060418010806, 3.8536982117761744, 3.8530895298518657, 3.8524799936368566]
# Weighted F1 Score : 0.8612786572997144
# MCC Score : 0.5437966146568364

# %% [markdown]
# # Test

# %%
y_test_pred = predict(X_test, mode='best_mode')

df_submission = pd.concat([pd.Series(list(range(0, len(X_test))), name='row_id', dtype=np.int32), pd.Series(y_test_pred, name='open_flag')], axis=1)
df_submission.to_csv('submission_best_mode.csv', index=False)

df_submission
# Out:
#        row_id  open_flag
# 0           0          0
# 1           1          0
# 2           2          0
# 3           3          0
# 4           4          0
# ...       ...        ...
# 55965   55965          0
# 55966   55966          0
# 55967   55967          0
# 55968   55968          0
# 55969   55969          1
#
# [55970 rows x 2 columns]

# %%
y_test_pred2 = predict(X_test, mode='best_mean')

df_submission = pd.concat([pd.Series(list(range(0, len(X_test))), name='row_id', dtype=np.int32), pd.Series(y_test_pred2, name='open_flag')], axis=1)
df_submission.to_csv('submission_best_mean.csv', index=False)

df_submission
# Out:
#        row_id  open_flag
# 0           0          0
# 1           1          0
# 2           2          0
# 3           3          0
# 4           4          0
# ...       ...        ...
# 55965   55965          0
# 55966   55966          0
# 55967   55967          0
# 55968   55968          0
# 55969   55969          1
#
# [55970 rows x 2 columns]

# %%
y_test_pred3 = predict(X_test, mode='ensemble_mode')

df_submission = pd.concat([pd.Series(list(range(0, len(X_test))), name='row_id', dtype=np.int32), pd.Series(y_test_pred3, name='open_flag')], axis=1)
df_submission.to_csv('submission_ensemble_mode.csv', index=False)

df_submission
# Out:
#        row_id  open_flag
# 0           0          1
# 1           1          0
# 2           2          0
# 3           3          0
# 4           4          0
# ...       ...        ...
# 55965   55965          0
# 55966   55966          0
# 55967   55967          0
# 55968   55968          1
# 55969   55969          1
#
# [55970 rows x 2 columns]

# %%
y_test_pred4 = predict(X_test, mode='ensemble_mean')

df_submission = pd.concat([pd.Series(list(range(0, len(X_test))), name='row_id', dtype=np.int32), pd.Series(y_test_pred4, name='open_flag')], axis=1)
df_submission.to_csv('submission_ensemble_mean.csv', index=False)

df_submission
# Out:
#        row_id  open_flag
# 0           0          1
# 1           1          0
# 2           2          0
# 3           3          0
# 4           4          0
# ...       ...        ...
# 55965   55965          0
# 55966   55966          0
# 55967   55967          0
# 55968   55968          1
# 55969   55969          1
#
# [55970 rows x 2 columns]

# %%
y_test_pred5 = predict(X_test, mode='weighted_ensemble_mean')

df_submission = pd.concat([pd.Series(list(range(0, len(X_test))), name='row_id', dtype=np.int32), pd.Series(y_test_pred5, name='open_flag')], axis=1)
df_submission.to_csv('submission_weighted_ensemble_mean.csv', index=False)

df_submission
# Out:
# [3.857935264719429, 3.8573324964312685, 3.8567288903828825, 3.8561244442423, 3.8555191556678, 3.8549130223078554, 3.8543060418010806, 3.8536982117761744, 3.8530895298518657, 3.8524799936368566]
#        row_id  open_flag
# 0           0          1
# 1           1          0
# 2           2          0
# 3           3          0
# 4           4          0
# ...       ...        ...
# 55965   55965          0
# 55966   55966          0
# 55967   55967          0
# 55968   55968          1
# 55969   55969          1
#
# [55970 rows x 2 columns]

# %% [markdown]
# # Visualize
#
# * Feature importance
# * Tree shape

# %%
lgbm.plot_importance(df_model.loc[0, 'model_0'], ignore_zero=False, figsize=(16,9))

# %%
lgbm.plot_split_value_histogram(df_model.loc[0, 'model_0'], 2)
